# %%
import pandas as pd
import pymongo
from psycopg2 import sql
import psycopg2

# %%
renewable_client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
renewable_db = renewable_client["co2_renew_life_db"]

# %%
print(renewable_db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'co2_renew_life_db')

# %%
renewable_collection = renewable_db["renewable_energy"]

# %%
renewable_all_records = renewable_collection.find()

# %%
print(renewable_all_records)
# Out:
# <pymongo.synchronous.cursor.Cursor object at 0x15f9dcf10>

# %%
for record in renewable_all_records:
    print(record)
# Out:
# {'_id': ObjectId('6804d79bbace469554c9a5a6'), 'Entity': 'Africa', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 5.7402806}
# {'_id': ObjectId('6804d79bbace469554c9a5a7'), 'Entity': 'Africa', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 6.1139693}
# {'_id': ObjectId('6804d79bbace469554c9a5a8'), 'Entity': 'Africa', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.31658}
# {'_id': ObjectId('6804d79bbace469554c9a5a9'), 'Entity': 'Africa', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.994845}
# {'_id': ObjectId('6804d79bbace469554c9a5aa'), 'Entity': 'Africa', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 7.9439163}
# {'_id': ObjectId('6804d79bbace469554c9a5ab'), 'Entity': 'Africa', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 9.148895}
# {'_id': ObjectId('6804d79bbace469554c9a5ac'), 'Entity': 'Africa', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 8.124994}
# {'_id': ObjectId('6804d79bbace469554c9a5ad'), 'Entity': 'Africa', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 8.747272}
# {'_id': ObjectId('6804d79bbace469554c9a5ae'), 'Entity': 'Africa', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 8.54162}
# {'_id': ObjectId('6804d79bbace469554c9a5af'), 'Entity': 'Africa', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 9.252387}
# {'_id': ObjectId('6804d79bbace469554c9a5b0'), 'Entity': 'Africa', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 9.228769}
# {'_id': ObjectId('6804d79bbace469554c9a5b1'), 'Entity': 'Africa', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 9.41638}
# {'_id': ObjectId('6804d79bbace469554c9a5b2'), 'Entity': 'Africa', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 9.803094}
# {'_id': ObjectId('6804d79bbace469554c9a5b3'), 'Entity': 'Africa', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 9.518462}
# {'_id': ObjectId('6804d79bbace469554c9a5b4'), 'Entity': 'Africa', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 9.349527}
# {'_id': ObjectId('6804d79bbace469554c9a5b5'), 'Entity': 'Africa', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 8.481442}
# {'_id': ObjectId('6804d79bbace469554c9a5b6'), 'Entity': 'Africa', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 7.8527517}
# {'_id': ObjectId('6804d79bbace469554c9a5b7'), 'Entity': 'Africa', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 7.3734274}
# {'_id': ObjectId('6804d79bbace469554c9a5b8'), 'Entity': 'Africa', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 6.456112}
# {'_id': ObjectId('6804d79bbace469554c9a5b9'), 'Entity': 'Africa', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 6.1585774}
# {'_id': ObjectId('6804d79bbace469554c9a5ba'), 'Entity': 'Africa', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 6.5793424}
# {'_id': ObjectId('6804d79bbace469554c9a5bb'), 'Entity': 'Africa', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 6.7159667}
# {'_id': ObjectId('6804d79bbace469554c9a5bc'), 'Entity': 'Africa', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 6.243963}
# {'_id': ObjectId('6804d79bbace469554c9a5bd'), 'Entity': 'Africa', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 6.3621163}
# {'_id': ObjectId('6804d79bbace469554c9a5be'), 'Entity': 'Africa', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 6.66546}
# {'_id': ObjectId('6804d79bbace469554c9a5bf'), 'Entity': 'Africa', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 6.5857716}
# {'_id': ObjectId('6804d79bbace469554c9a5c0'), 'Entity': 'Africa', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 6.9810143}
# {'_id': ObjectId('6804d79bbace469554c9a5c1'), 'Entity': 'Africa', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 6.5694675}
# {'_id': ObjectId('6804d79bbace469554c9a5c2'), 'Entity': 'Africa', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 6.43179}
# {'_id': ObjectId('6804d79bbace469554c9a5c3'), 'Entity': 'Africa', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 6.3092456}
# {'_id': ObjectId('6804d79bbace469554c9a5c4'), 'Entity': 'Africa', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 6.306244}
# {'_id': ObjectId('6804d79bbace469554c9a5c5'), 'Entity': 'Africa', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 6.4332542}
# {'_id': ObjectId('6804d79bbace469554c9a5c6'), 'Entity': 'Africa', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 6.465725}
# {'_id': ObjectId('6804d79bbace469554c9a5c7'), 'Entity': 'Africa', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 6.676159}
# {'_id': ObjectId('6804d79bbace469554c9a5c8'), 'Entity': 'Africa', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 6.858631}
# {'_id': ObjectId('6804d79bbace469554c9a5c9'), 'Entity': 'Africa', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 7.2029395}
# {'_id': ObjectId('6804d79bbace469554c9a5ca'), 'Entity': 'Africa', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 7.4362373}
# {'_id': ObjectId('6804d79bbace469554c9a5cb'), 'Entity': 'Africa', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 7.671944}
# {'_id': ObjectId('6804d79bbace469554c9a5cc'), 'Entity': 'Africa', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 7.105203}
# {'_id': ObjectId('6804d79bbace469554c9a5cd'), 'Entity': 'Africa', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 6.980063}
# {'_id': ObjectId('6804d79bbace469554c9a5ce'), 'Entity': 'Africa', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 7.0285006}
# {'_id': ObjectId('6804d79bbace469554c9a5cf'), 'Entity': 'Africa', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 7.1611776}
# {'_id': ObjectId('6804d79bbace469554c9a5d0'), 'Entity': 'Africa', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 7.0572457}
# {'_id': ObjectId('6804d79bbace469554c9a5d1'), 'Entity': 'Africa', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 6.761787}
# {'_id': ObjectId('6804d79bbace469554c9a5d2'), 'Entity': 'Africa', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 6.810709}
# {'_id': ObjectId('6804d79bbace469554c9a5d3'), 'Entity': 'Africa', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 7.1290402}
# {'_id': ObjectId('6804d79bbace469554c9a5d4'), 'Entity': 'Africa', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 7.2594023}
# {'_id': ObjectId('6804d79bbace469554c9a5d5'), 'Entity': 'Africa', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 6.9972486}
# {'_id': ObjectId('6804d79bbace469554c9a5d6'), 'Entity': 'Africa', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 7.189637}
# {'_id': ObjectId('6804d79bbace469554c9a5d7'), 'Entity': 'Africa', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 7.5156765}
# {'_id': ObjectId('6804d79bbace469554c9a5d8'), 'Entity': 'Africa', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.527505}
# {'_id': ObjectId('6804d79bbace469554c9a5d9'), 'Entity': 'Africa', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 7.404274}
# {'_id': ObjectId('6804d79bbace469554c9a5da'), 'Entity': 'Africa', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 7.6419463}
# {'_id': ObjectId('6804d79bbace469554c9a5db'), 'Entity': 'Africa', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 8.005552}
# {'_id': ObjectId('6804d79bbace469554c9a5dc'), 'Entity': 'Africa', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 8.356321}
# {'_id': ObjectId('6804d79bbace469554c9a5dd'), 'Entity': 'Africa', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 9.415897}
# {'_id': ObjectId('6804d79bbace469554c9a5de'), 'Entity': 'Africa', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 9.152215}
# {'_id': ObjectId('6804d79bbace469554c9a5df'), 'Entity': 'Africa', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 9.298186}
# {'_id': ObjectId('6804d79bbace469554c9a5e0'), 'Entity': 'Africa', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 9.826173}
# {'_id': ObjectId('6804d79bbace469554c9a5e1'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 5.7402806}
# {'_id': ObjectId('6804d79bbace469554c9a5e2'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 6.113969}
# {'_id': ObjectId('6804d79bbace469554c9a5e3'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.31658}
# {'_id': ObjectId('6804d79bbace469554c9a5e4'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.994845}
# {'_id': ObjectId('6804d79bbace469554c9a5e5'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 7.9439154}
# {'_id': ObjectId('6804d79bbace469554c9a5e6'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 9.148896}
# {'_id': ObjectId('6804d79bbace469554c9a5e7'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 8.124996}
# {'_id': ObjectId('6804d79bbace469554c9a5e8'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 8.7472725}
# {'_id': ObjectId('6804d79bbace469554c9a5e9'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 8.54162}
# {'_id': ObjectId('6804d79bbace469554c9a5ea'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 9.252388}
# {'_id': ObjectId('6804d79bbace469554c9a5eb'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 9.228768}
# {'_id': ObjectId('6804d79bbace469554c9a5ec'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 9.416379}
# {'_id': ObjectId('6804d79bbace469554c9a5ed'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 9.803097}
# {'_id': ObjectId('6804d79bbace469554c9a5ee'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 9.518462}
# {'_id': ObjectId('6804d79bbace469554c9a5ef'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 9.349527}
# {'_id': ObjectId('6804d79bbace469554c9a5f0'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 8.481442}
# {'_id': ObjectId('6804d79bbace469554c9a5f1'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 7.8527517}
# {'_id': ObjectId('6804d79bbace469554c9a5f2'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 7.3734274}
# {'_id': ObjectId('6804d79bbace469554c9a5f3'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 6.456112}
# {'_id': ObjectId('6804d79bbace469554c9a5f4'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 6.1585774}
# {'_id': ObjectId('6804d79bbace469554c9a5f5'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 6.5793424}
# {'_id': ObjectId('6804d79bbace469554c9a5f6'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 6.7159667}
# {'_id': ObjectId('6804d79bbace469554c9a5f7'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 6.243963}
# {'_id': ObjectId('6804d79bbace469554c9a5f8'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 6.3621163}
# {'_id': ObjectId('6804d79bbace469554c9a5f9'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 6.6654606}
# {'_id': ObjectId('6804d79bbace469554c9a5fa'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 6.5857716}
# {'_id': ObjectId('6804d79bbace469554c9a5fb'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 6.9810143}
# {'_id': ObjectId('6804d79bbace469554c9a5fc'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 6.5694675}
# {'_id': ObjectId('6804d79bbace469554c9a5fd'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 6.43179}
# {'_id': ObjectId('6804d79bbace469554c9a5fe'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 6.3092456}
# {'_id': ObjectId('6804d79bbace469554c9a5ff'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 6.306244}
# {'_id': ObjectId('6804d79bbace469554c9a600'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 6.433255}
# {'_id': ObjectId('6804d79bbace469554c9a601'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 6.465725}
# {'_id': ObjectId('6804d79bbace469554c9a602'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 6.6761603}
# {'_id': ObjectId('6804d79bbace469554c9a603'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 6.8586307}
# {'_id': ObjectId('6804d79bbace469554c9a604'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 7.2029395}
# {'_id': ObjectId('6804d79bbace469554c9a605'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 7.436237}
# {'_id': ObjectId('6804d79bbace469554c9a606'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 7.671944}
# {'_id': ObjectId('6804d79bbace469554c9a607'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 7.105202}
# {'_id': ObjectId('6804d79bbace469554c9a608'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 6.980063}
# {'_id': ObjectId('6804d79bbace469554c9a609'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 7.0285006}
# {'_id': ObjectId('6804d79bbace469554c9a60a'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 7.161177}
# {'_id': ObjectId('6804d79bbace469554c9a60b'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 7.0572457}
# {'_id': ObjectId('6804d79bbace469554c9a60c'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 6.761787}
# {'_id': ObjectId('6804d79bbace469554c9a60d'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 6.8107085}
# {'_id': ObjectId('6804d79bbace469554c9a60e'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 7.12904}
# {'_id': ObjectId('6804d79bbace469554c9a60f'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 7.2594023}
# {'_id': ObjectId('6804d79bbace469554c9a610'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 6.9972486}
# {'_id': ObjectId('6804d79bbace469554c9a611'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 7.189637}
# {'_id': ObjectId('6804d79bbace469554c9a612'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 7.5156765}
# {'_id': ObjectId('6804d79bbace469554c9a613'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.527505}
# {'_id': ObjectId('6804d79bbace469554c9a614'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 7.404273}
# {'_id': ObjectId('6804d79bbace469554c9a615'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 7.6419473}
# {'_id': ObjectId('6804d79bbace469554c9a616'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 8.005553}
# {'_id': ObjectId('6804d79bbace469554c9a617'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 8.356321}
# {'_id': ObjectId('6804d79bbace469554c9a618'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 9.415897}
# {'_id': ObjectId('6804d79bbace469554c9a619'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 9.152214}
# {'_id': ObjectId('6804d79bbace469554c9a61a'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 9.298185}
# {'_id': ObjectId('6804d79bbace469554c9a61b'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 9.826172}
# {'_id': ObjectId('6804d79bbace469554c9a61c'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1965, 'Renewables (% equivalent primary energy)': 4.7630677}
# {'_id': ObjectId('6804d79bbace469554c9a61d'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1966, 'Renewables (% equivalent primary energy)': 3.518747}
# {'_id': ObjectId('6804d79bbace469554c9a61e'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1967, 'Renewables (% equivalent primary energy)': 4.291954}
# {'_id': ObjectId('6804d79bbace469554c9a61f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1968, 'Renewables (% equivalent primary energy)': 5.4861946}
# {'_id': ObjectId('6804d79bbace469554c9a620'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1969, 'Renewables (% equivalent primary energy)': 3.1827633}
# {'_id': ObjectId('6804d79bbace469554c9a621'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1970, 'Renewables (% equivalent primary energy)': 4.6656837}
# {'_id': ObjectId('6804d79bbace469554c9a622'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1971, 'Renewables (% equivalent primary energy)': 2.4559188}
# {'_id': ObjectId('6804d79bbace469554c9a623'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1972, 'Renewables (% equivalent primary energy)': 3.278343}
# {'_id': ObjectId('6804d79bbace469554c9a624'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1973, 'Renewables (% equivalent primary energy)': 4.175826}
# {'_id': ObjectId('6804d79bbace469554c9a625'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1974, 'Renewables (% equivalent primary energy)': 2.494738}
# {'_id': ObjectId('6804d79bbace469554c9a626'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1975, 'Renewables (% equivalent primary energy)': 1.3782818}
# {'_id': ObjectId('6804d79bbace469554c9a627'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1976, 'Renewables (% equivalent primary energy)': 1.4010222}
# {'_id': ObjectId('6804d79bbace469554c9a628'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1977, 'Renewables (% equivalent primary energy)': 0.8817282}
# {'_id': ObjectId('6804d79bbace469554c9a629'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1978, 'Renewables (% equivalent primary energy)': 0.6521151}
# {'_id': ObjectId('6804d79bbace469554c9a62a'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1979, 'Renewables (% equivalent primary energy)': 0.5792936}
# {'_id': ObjectId('6804d79bbace469554c9a62b'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1980, 'Renewables (% equivalent primary energy)': 0.4290016}
# {'_id': ObjectId('6804d79bbace469554c9a62c'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1981, 'Renewables (% equivalent primary energy)': 0.50294036}
# {'_id': ObjectId('6804d79bbace469554c9a62d'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1982, 'Renewables (% equivalent primary energy)': 0.5708701}
# {'_id': ObjectId('6804d79bbace469554c9a62e'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1983, 'Renewables (% equivalent primary energy)': 0.25644946}
# {'_id': ObjectId('6804d79bbace469554c9a62f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1984, 'Renewables (% equivalent primary energy)': 0.5136736}
# {'_id': ObjectId('6804d79bbace469554c9a630'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1985, 'Renewables (% equivalent primary energy)': 0.72826535}
# {'_id': ObjectId('6804d79bbace469554c9a631'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1986, 'Renewables (% equivalent primary energy)': 0.2664045}
# {'_id': ObjectId('6804d79bbace469554c9a632'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1987, 'Renewables (% equivalent primary energy)': 0.5174274}
# {'_id': ObjectId('6804d79bbace469554c9a633'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1988, 'Renewables (% equivalent primary energy)': 0.17717436}
# {'_id': ObjectId('6804d79bbace469554c9a634'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1989, 'Renewables (% equivalent primary energy)': 0.2249582}
# {'_id': ObjectId('6804d79bbace469554c9a635'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1990, 'Renewables (% equivalent primary energy)': 0.1267387}
# {'_id': ObjectId('6804d79bbace469554c9a636'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1991, 'Renewables (% equivalent primary energy)': 0.277607}
# {'_id': ObjectId('6804d79bbace469554c9a637'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1992, 'Renewables (% equivalent primary energy)': 0.18375748}
# {'_id': ObjectId('6804d79bbace469554c9a638'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1993, 'Renewables (% equivalent primary energy)': 0.35028014}
# {'_id': ObjectId('6804d79bbace469554c9a639'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1994, 'Renewables (% equivalent primary energy)': 0.16257899}
# {'_id': ObjectId('6804d79bbace469554c9a63a'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1995, 'Renewables (% equivalent primary energy)': 0.18224756}
# {'_id': ObjectId('6804d79bbace469554c9a63b'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1996, 'Renewables (% equivalent primary energy)': 0.1288034}
# {'_id': ObjectId('6804d79bbace469554c9a63c'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1997, 'Renewables (% equivalent primary energy)': 0.074455895}
# {'_id': ObjectId('6804d79bbace469554c9a63d'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1998, 'Renewables (% equivalent primary energy)': 0.20617963}
# {'_id': ObjectId('6804d79bbace469554c9a63e'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1999, 'Renewables (% equivalent primary energy)': 0.1927434}
# {'_id': ObjectId('6804d79bbace469554c9a63f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2000, 'Renewables (% equivalent primary energy)': 0.053235486}
# {'_id': ObjectId('6804d79bbace469554c9a640'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2001, 'Renewables (% equivalent primary energy)': 0.065218486}
# {'_id': ObjectId('6804d79bbace469554c9a641'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2002, 'Renewables (% equivalent primary energy)': 0.05167676}
# {'_id': ObjectId('6804d79bbace469554c9a642'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2003, 'Renewables (% equivalent primary energy)': 0.228104}
# {'_id': ObjectId('6804d79bbace469554c9a643'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2004, 'Renewables (% equivalent primary energy)': 0.2067869}
# {'_id': ObjectId('6804d79bbace469554c9a644'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2005, 'Renewables (% equivalent primary energy)': 0.43411884}
# {'_id': ObjectId('6804d79bbace469554c9a645'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2006, 'Renewables (% equivalent primary energy)': 0.16327195}
# {'_id': ObjectId('6804d79bbace469554c9a646'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2007, 'Renewables (% equivalent primary energy)': 0.15990457}
# {'_id': ObjectId('6804d79bbace469554c9a647'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2008, 'Renewables (% equivalent primary energy)': 0.1877543}
# {'_id': ObjectId('6804d79bbace469554c9a648'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2009, 'Renewables (% equivalent primary energy)': 0.21278548}
# {'_id': ObjectId('6804d79bbace469554c9a649'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2010, 'Renewables (% equivalent primary energy)': 0.11513415}
# {'_id': ObjectId('6804d79bbace469554c9a64a'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2011, 'Renewables (% equivalent primary energy)': 0.23525994}
# {'_id': ObjectId('6804d79bbace469554c9a64b'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2012, 'Renewables (% equivalent primary energy)': 0.22453195}
# {'_id': ObjectId('6804d79bbace469554c9a64c'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2013, 'Renewables (% equivalent primary energy)': 0.06476319}
# {'_id': ObjectId('6804d79bbace469554c9a64d'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2014, 'Renewables (% equivalent primary energy)': 0.11750259}
# {'_id': ObjectId('6804d79bbace469554c9a64e'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2015, 'Renewables (% equivalent primary energy)': 0.09681336}
# {'_id': ObjectId('6804d79bbace469554c9a64f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2016, 'Renewables (% equivalent primary energy)': 0.14580713}
# {'_id': ObjectId('6804d79bbace469554c9a650'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2017, 'Renewables (% equivalent primary energy)': 0.24701828}
# {'_id': ObjectId('6804d79bbace469554c9a651'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2018, 'Renewables (% equivalent primary energy)': 0.28842947}
# {'_id': ObjectId('6804d79bbace469554c9a652'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2019, 'Renewables (% equivalent primary energy)': 0.29497427}
# {'_id': ObjectId('6804d79bbace469554c9a653'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2020, 'Renewables (% equivalent primary energy)': 0.30043116}
# {'_id': ObjectId('6804d79bbace469554c9a654'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2021, 'Renewables (% equivalent primary energy)': 0.25285673}
# {'_id': ObjectId('6804d79bbace469554c9a655'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2022, 'Renewables (% equivalent primary energy)': 0.24182516}
# {'_id': ObjectId('6804d79bbace469554c9a656'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2023, 'Renewables (% equivalent primary energy)': 0.27036947}
# {'_id': ObjectId('6804d79bbace469554c9a657'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1965, 'Renewables (% equivalent primary energy)': 1.1026944}
# {'_id': ObjectId('6804d79bbace469554c9a658'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1966, 'Renewables (% equivalent primary energy)': 1.0818663}
# {'_id': ObjectId('6804d79bbace469554c9a659'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1967, 'Renewables (% equivalent primary energy)': 1.0765308}
# {'_id': ObjectId('6804d79bbace469554c9a65a'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1968, 'Renewables (% equivalent primary energy)': 1.2272897}
# {'_id': ObjectId('6804d79bbace469554c9a65b'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1969, 'Renewables (% equivalent primary energy)': 1.0651326}
# {'_id': ObjectId('6804d79bbace469554c9a65c'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1970, 'Renewables (% equivalent primary energy)': 1.3533598}
# {'_id': ObjectId('6804d79bbace469554c9a65d'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1971, 'Renewables (% equivalent primary energy)': 1.2702763}
# {'_id': ObjectId('6804d79bbace469554c9a65e'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1972, 'Renewables (% equivalent primary energy)': 1.2349532}
# {'_id': ObjectId('6804d79bbace469554c9a65f'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1973, 'Renewables (% equivalent primary energy)': 2.2839267}
# {'_id': ObjectId('6804d79bbace469554c9a660'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1974, 'Renewables (% equivalent primary energy)': 3.629566}
# {'_id': ObjectId('6804d79bbace469554c9a661'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1975, 'Renewables (% equivalent primary energy)': 3.8664374}
# {'_id': ObjectId('6804d79bbace469554c9a662'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1976, 'Renewables (% equivalent primary energy)': 3.5540857}
# {'_id': ObjectId('6804d79bbace469554c9a663'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1977, 'Renewables (% equivalent primary energy)': 3.9090023}
# {'_id': ObjectId('6804d79bbace469554c9a664'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1978, 'Renewables (% equivalent primary energy)': 5.227204}
# {'_id': ObjectId('6804d79bbace469554c9a665'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1979, 'Renewables (% equivalent primary energy)': 6.702873}
# {'_id': ObjectId('6804d79bbace469554c9a666'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1980, 'Renewables (% equivalent primary energy)': 9.552048}
# {'_id': ObjectId('6804d79bbace469554c9a667'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1981, 'Renewables (% equivalent primary energy)': 9.542367}
# {'_id': ObjectId('6804d79bbace469554c9a668'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1982, 'Renewables (% equivalent primary energy)': 11.229478}
# {'_id': ObjectId('6804d79bbace469554c9a669'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1983, 'Renewables (% equivalent primary energy)': 11.313745}
# {'_id': ObjectId('6804d79bbace469554c9a66a'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1984, 'Renewables (% equivalent primary energy)': 12.136334}
# {'_id': ObjectId('6804d79bbace469554c9a66b'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1985, 'Renewables (% equivalent primary energy)': 12.759911}
# {'_id': ObjectId('6804d79bbace469554c9a66c'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1986, 'Renewables (% equivalent primary energy)': 12.297877}
# {'_id': ObjectId('6804d79bbace469554c9a66d'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1987, 'Renewables (% equivalent primary energy)': 12.24687}
# {'_id': ObjectId('6804d79bbace469554c9a66e'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1988, 'Renewables (% equivalent primary energy)': 8.416951}
# {'_id': ObjectId('6804d79bbace469554c9a66f'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1989, 'Renewables (% equivalent primary energy)': 7.543206}
# {'_id': ObjectId('6804d79bbace469554c9a670'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1990, 'Renewables (% equivalent primary energy)': 10.29241}
# {'_id': ObjectId('6804d79bbace469554c9a671'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1991, 'Renewables (% equivalent primary energy)': 9.080978}
# {'_id': ObjectId('6804d79bbace469554c9a672'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1992, 'Renewables (% equivalent primary energy)': 10.2065}
# {'_id': ObjectId('6804d79bbace469554c9a673'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1993, 'Renewables (% equivalent primary energy)': 12.215968}
# {'_id': ObjectId('6804d79bbace469554c9a674'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1994, 'Renewables (% equivalent primary energy)': 13.306112}
# {'_id': ObjectId('6804d79bbace469554c9a675'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1995, 'Renewables (% equivalent primary energy)': 12.535252}
# {'_id': ObjectId('6804d79bbace469554c9a676'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1996, 'Renewables (% equivalent primary energy)': 10.224623}
# {'_id': ObjectId('6804d79bbace469554c9a677'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1997, 'Renewables (% equivalent primary energy)': 12.513889}
# {'_id': ObjectId('6804d79bbace469554c9a678'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1998, 'Renewables (% equivalent primary energy)': 11.481932}
# {'_id': ObjectId('6804d79bbace469554c9a679'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1999, 'Renewables (% equivalent primary energy)': 9.2246065}
# {'_id': ObjectId('6804d79bbace469554c9a67a'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2000, 'Renewables (% equivalent primary energy)': 12.283152}
# {'_id': ObjectId('6804d79bbace469554c9a67b'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2001, 'Renewables (% equivalent primary energy)': 15.93624}
# {'_id': ObjectId('6804d79bbace469554c9a67c'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2002, 'Renewables (% equivalent primary energy)': 16.247978}
# {'_id': ObjectId('6804d79bbace469554c9a67d'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2003, 'Renewables (% equivalent primary energy)': 14.40661}
# {'_id': ObjectId('6804d79bbace469554c9a67e'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2004, 'Renewables (% equivalent primary energy)': 12.185576}
# {'_id': ObjectId('6804d79bbace469554c9a67f'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2005, 'Renewables (% equivalent primary energy)': 12.790038}
# {'_id': ObjectId('6804d79bbace469554c9a680'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2006, 'Renewables (% equivalent primary energy)': 13.449896}
# {'_id': ObjectId('6804d79bbace469554c9a681'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2007, 'Renewables (% equivalent primary energy)': 10.613073}
# {'_id': ObjectId('6804d79bbace469554c9a682'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2008, 'Renewables (% equivalent primary energy)': 10.447249}
# {'_id': ObjectId('6804d79bbace469554c9a683'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2009, 'Renewables (% equivalent primary energy)': 11.797741}
# {'_id': ObjectId('6804d79bbace469554c9a684'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2010, 'Renewables (% equivalent primary energy)': 11.650168}
# {'_id': ObjectId('6804d79bbace469554c9a685'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2011, 'Renewables (% equivalent primary energy)': 10.914268}
# {'_id': ObjectId('6804d79bbace469554c9a686'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2012, 'Renewables (% equivalent primary energy)': 10.176803}
# {'_id': ObjectId('6804d79bbace469554c9a687'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2013, 'Renewables (% equivalent primary energy)': 10.940409}
# {'_id': ObjectId('6804d79bbace469554c9a688'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2014, 'Renewables (% equivalent primary energy)': 11.038969}
# {'_id': ObjectId('6804d79bbace469554c9a689'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2015, 'Renewables (% equivalent primary energy)': 10.89336}
# {'_id': ObjectId('6804d79bbace469554c9a68a'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2016, 'Renewables (% equivalent primary energy)': 10.17179}
# {'_id': ObjectId('6804d79bbace469554c9a68b'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2017, 'Renewables (% equivalent primary energy)': 10.979133}
# {'_id': ObjectId('6804d79bbace469554c9a68c'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2018, 'Renewables (% equivalent primary energy)': 11.331651}
# {'_id': ObjectId('6804d79bbace469554c9a68d'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2019, 'Renewables (% equivalent primary energy)': 11.911147}
# {'_id': ObjectId('6804d79bbace469554c9a68e'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2020, 'Renewables (% equivalent primary energy)': 12.310073}
# {'_id': ObjectId('6804d79bbace469554c9a68f'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2021, 'Renewables (% equivalent primary energy)': 11.335143}
# {'_id': ObjectId('6804d79bbace469554c9a690'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2022, 'Renewables (% equivalent primary energy)': 12.188763}
# {'_id': ObjectId('6804d79bbace469554c9a691'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2023, 'Renewables (% equivalent primary energy)': 14.102216}
# {'_id': ObjectId('6804d79bbace469554c9a692'), 'Entity': 'Asia', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 7.8735447}
# {'_id': ObjectId('6804d79bbace469554c9a693'), 'Entity': 'Asia', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 7.4938087}
# {'_id': ObjectId('6804d79bbace469554c9a694'), 'Entity': 'Asia', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.7346387}
# {'_id': ObjectId('6804d79bbace469554c9a695'), 'Entity': 'Asia', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.963028}
# {'_id': ObjectId('6804d79bbace469554c9a696'), 'Entity': 'Asia', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 6.3012996}
# {'_id': ObjectId('6804d79bbace469554c9a697'), 'Entity': 'Asia', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 5.661888}
# {'_id': ObjectId('6804d79bbace469554c9a698'), 'Entity': 'Asia', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 5.6825113}
# {'_id': ObjectId('6804d79bbace469554c9a699'), 'Entity': 'Asia', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 5.4817533}
# {'_id': ObjectId('6804d79bbace469554c9a69a'), 'Entity': 'Asia', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 4.7254024}
# {'_id': ObjectId('6804d79bbace469554c9a69b'), 'Entity': 'Asia', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 5.289435}
# {'_id': ObjectId('6804d79bbace469554c9a69c'), 'Entity': 'Asia', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 5.432976}
# {'_id': ObjectId('6804d79bbace469554c9a69d'), 'Entity': 'Asia', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 5.272847}
# {'_id': ObjectId('6804d79bbace469554c9a69e'), 'Entity': 'Asia', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 4.885452}
# {'_id': ObjectId('6804d79bbace469554c9a69f'), 'Entity': 'Asia', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 4.842396}
# {'_id': ObjectId('6804d79bbace469554c9a6a0'), 'Entity': 'Asia', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 5.0050187}
# {'_id': ObjectId('6804d79bbace469554c9a6a1'), 'Entity': 'Asia', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 5.387261}
# {'_id': ObjectId('6804d79bbace469554c9a6a2'), 'Entity': 'Asia', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 5.6962633}
# {'_id': ObjectId('6804d79bbace469554c9a6a3'), 'Entity': 'Asia', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 5.688111}
# {'_id': ObjectId('6804d79bbace469554c9a6a4'), 'Entity': 'Asia', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 5.652118}
# {'_id': ObjectId('6804d79bbace469554c9a6a5'), 'Entity': 'Asia', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 5.339281}
# {'_id': ObjectId('6804d79bbace469554c9a6a6'), 'Entity': 'Asia', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 5.351906}
# {'_id': ObjectId('6804d79bbace469554c9a6a7'), 'Entity': 'Asia', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 5.190978}
# {'_id': ObjectId('6804d79bbace469554c9a6a8'), 'Entity': 'Asia', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 5.0590653}
# {'_id': ObjectId('6804d79bbace469554c9a6a9'), 'Entity': 'Asia', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 5.4249687}
# {'_id': ObjectId('6804d79bbace469554c9a6aa'), 'Entity': 'Asia', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 5.319675}
# {'_id': ObjectId('6804d79bbace469554c9a6ab'), 'Entity': 'Asia', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 5.339282}
# {'_id': ObjectId('6804d79bbace469554c9a6ac'), 'Entity': 'Asia', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 5.1891055}
# {'_id': ObjectId('6804d79bbace469554c9a6ad'), 'Entity': 'Asia', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 5.0055637}
# {'_id': ObjectId('6804d79bbace469554c9a6ae'), 'Entity': 'Asia', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 5.3127103}
# {'_id': ObjectId('6804d79bbace469554c9a6af'), 'Entity': 'Asia', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 5.0516157}
# {'_id': ObjectId('6804d79bbace469554c9a6b0'), 'Entity': 'Asia', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 5.271553}
# {'_id': ObjectId('6804d79bbace469554c9a6b1'), 'Entity': 'Asia', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 5.018597}
# {'_id': ObjectId('6804d79bbace469554c9a6b2'), 'Entity': 'Asia', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 4.8939986}
# {'_id': ObjectId('6804d79bbace469554c9a6b3'), 'Entity': 'Asia', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 5.178817}
# {'_id': ObjectId('6804d79bbace469554c9a6b4'), 'Entity': 'Asia', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 4.9296236}
# {'_id': ObjectId('6804d79bbace469554c9a6b5'), 'Entity': 'Asia', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 4.9015436}
# {'_id': ObjectId('6804d79bbace469554c9a6b6'), 'Entity': 'Asia', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 5.0736527}
# {'_id': ObjectId('6804d79bbace469554c9a6b7'), 'Entity': 'Asia', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 4.9854317}
# {'_id': ObjectId('6804d79bbace469554c9a6b8'), 'Entity': 'Asia', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 4.7931614}
# {'_id': ObjectId('6804d79bbace469554c9a6b9'), 'Entity': 'Asia', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 5.0985446}
# {'_id': ObjectId('6804d79bbace469554c9a6ba'), 'Entity': 'Asia', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 4.9199796}
# {'_id': ObjectId('6804d79bbace469554c9a6bb'), 'Entity': 'Asia', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 5.117429}
# {'_id': ObjectId('6804d79bbace469554c9a6bc'), 'Entity': 'Asia', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 5.0853057}
# {'_id': ObjectId('6804d79bbace469554c9a6bd'), 'Entity': 'Asia', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 5.605236}
# {'_id': ObjectId('6804d79bbace469554c9a6be'), 'Entity': 'Asia', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 5.458485}
# {'_id': ObjectId('6804d79bbace469554c9a6bf'), 'Entity': 'Asia', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 5.9468226}
# {'_id': ObjectId('6804d79bbace469554c9a6c0'), 'Entity': 'Asia', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 5.8778787}
# {'_id': ObjectId('6804d79bbace469554c9a6c1'), 'Entity': 'Asia', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 6.4778247}
# {'_id': ObjectId('6804d79bbace469554c9a6c2'), 'Entity': 'Asia', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 6.987413}
# {'_id': ObjectId('6804d79bbace469554c9a6c3'), 'Entity': 'Asia', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 7.551866}
# {'_id': ObjectId('6804d79bbace469554c9a6c4'), 'Entity': 'Asia', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.908183}
# {'_id': ObjectId('6804d79bbace469554c9a6c5'), 'Entity': 'Asia', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 8.438702}
# {'_id': ObjectId('6804d79bbace469554c9a6c6'), 'Entity': 'Asia', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 8.845372}
# {'_id': ObjectId('6804d79bbace469554c9a6c7'), 'Entity': 'Asia', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 9.349624}
# {'_id': ObjectId('6804d79bbace469554c9a6c8'), 'Entity': 'Asia', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 10.002659}
# {'_id': ObjectId('6804d79bbace469554c9a6c9'), 'Entity': 'Asia', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 10.741154}
# {'_id': ObjectId('6804d79bbace469554c9a6ca'), 'Entity': 'Asia', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 11.2254095}
# {'_id': ObjectId('6804d79bbace469554c9a6cb'), 'Entity': 'Asia', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 11.969987}
# {'_id': ObjectId('6804d79bbace469554c9a6cc'), 'Entity': 'Asia', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 12.191386}
# {'_id': ObjectId('6804d79bbace469554c9a6cd'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 8.879346}
# {'_id': ObjectId('6804d79bbace469554c9a6ce'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 8.41833}
# {'_id': ObjectId('6804d79bbace469554c9a6cf'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 7.6206317}
# {'_id': ObjectId('6804d79bbace469554c9a6d0'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 7.814885}
# {'_id': ObjectId('6804d79bbace469554c9a6d1'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 7.0542545}
# {'_id': ObjectId('6804d79bbace469554c9a6d2'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 6.39634}
# {'_id': ObjectId('6804d79bbace469554c9a6d3'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 6.486787}
# {'_id': ObjectId('6804d79bbace469554c9a6d4'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 6.238836}
# {'_id': ObjectId('6804d79bbace469554c9a6d5'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 5.4947343}
# {'_id': ObjectId('6804d79bbace469554c9a6d6'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 6.09481}
# {'_id': ObjectId('6804d79bbace469554c9a6d7'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 6.1902494}
# {'_id': ObjectId('6804d79bbace469554c9a6d8'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 5.912254}
# {'_id': ObjectId('6804d79bbace469554c9a6d9'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 5.47068}
# {'_id': ObjectId('6804d79bbace469554c9a6da'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 5.3867373}
# {'_id': ObjectId('6804d79bbace469554c9a6db'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 5.630934}
# {'_id': ObjectId('6804d79bbace469554c9a6dc'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 5.9968095}
# {'_id': ObjectId('6804d79bbace469554c9a6dd'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 6.3445344}
# {'_id': ObjectId('6804d79bbace469554c9a6de'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 6.3195252}
# {'_id': ObjectId('6804d79bbace469554c9a6df'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 6.4025097}
# {'_id': ObjectId('6804d79bbace469554c9a6e0'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 6.0936494}
# {'_id': ObjectId('6804d79bbace469554c9a6e1'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 6.1765556}
# {'_id': ObjectId('6804d79bbace469554c9a6e2'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 6.0954514}
# {'_id': ObjectId('6804d79bbace469554c9a6e3'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 5.7225227}
# ...
# {'_id': ObjectId('6804d79bbace469554c9b867'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 12.494397}
# {'_id': ObjectId('6804d79bbace469554c9b868'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 11.68581}
# {'_id': ObjectId('6804d79bbace469554c9b869'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 7.7634754}
# {'_id': ObjectId('6804d79bbace469554c9b86a'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 7.5681634}
# {'_id': ObjectId('6804d79bbace469554c9b86b'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 11.242959}
# {'_id': ObjectId('6804d79bbace469554c9b86c'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 13.811244}
# {'_id': ObjectId('6804d79bbace469554c9b86d'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 12.9425125}
# {'_id': ObjectId('6804d79bbace469554c9b86e'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 13.430492}
# {'_id': ObjectId('6804d79bbace469554c9b86f'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 13.813509}
# {'_id': ObjectId('6804d79bbace469554c9b870'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 14.452316}
# {'_id': ObjectId('6804d79bbace469554c9b871'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 15.77723}
# {'_id': ObjectId('6804d79bbace469554c9b872'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 15.0170355}
# {'_id': ObjectId('6804d79bbace469554c9b873'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 14.30466}
# {'_id': ObjectId('6804d79bbace469554c9b874'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 14.307501}
# {'_id': ObjectId('6804d79bbace469554c9b875'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 14.58253}
# {'_id': ObjectId('6804d79bbace469554c9b876'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 13.991099}
# {'_id': ObjectId('6804d79bbace469554c9b877'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 14.335823}
# {'_id': ObjectId('6804d79bbace469554c9b878'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 11.193091}
# {'_id': ObjectId('6804d79bbace469554c9b879'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 13.094856}
# {'_id': ObjectId('6804d79bbace469554c9b87a'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 13.095548}
# {'_id': ObjectId('6804d79bbace469554c9b87b'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 12.301518}
# {'_id': ObjectId('6804d79bbace469554c9b87c'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 11.809273}
# {'_id': ObjectId('6804d79bbace469554c9b87d'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 10.583202}
# {'_id': ObjectId('6804d79bbace469554c9b87e'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 11.762157}
# {'_id': ObjectId('6804d79bbace469554c9b87f'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 11.003373}
# {'_id': ObjectId('6804d79bbace469554c9b880'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 10.950638}
# {'_id': ObjectId('6804d79bbace469554c9b881'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 9.16278}
# {'_id': ObjectId('6804d79bbace469554c9b882'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 9.841228}
# {'_id': ObjectId('6804d79bbace469554c9b883'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 10.236668}
# {'_id': ObjectId('6804d79bbace469554c9b884'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 10.912234}
# {'_id': ObjectId('6804d79bbace469554c9b885'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 10.084756}
# {'_id': ObjectId('6804d79bbace469554c9b886'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 9.786942}
# {'_id': ObjectId('6804d79bbace469554c9b887'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 9.337499}
# {'_id': ObjectId('6804d79bbace469554c9b888'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 9.446895}
# {'_id': ObjectId('6804d79bbace469554c9b889'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.3576255}
# {'_id': ObjectId('6804d79bbace469554c9b88a'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 8.244503}
# {'_id': ObjectId('6804d79bbace469554c9b88b'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 7.833715}
# {'_id': ObjectId('6804d79bbace469554c9b88c'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 7.440964}
# {'_id': ObjectId('6804d79bbace469554c9b88d'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 8.164477}
# {'_id': ObjectId('6804d79bbace469554c9b88e'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 8.095408}
# {'_id': ObjectId('6804d79bbace469554c9b88f'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 7.4288955}
# {'_id': ObjectId('6804d79bbace469554c9b890'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 7.8159766}
# {'_id': ObjectId('6804d79bbace469554c9b891'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 8.792076}
# {'_id': ObjectId('6804d79bbace469554c9b892'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1965, 'Renewables (% equivalent primary energy)': 6.445519}
# {'_id': ObjectId('6804d79bbace469554c9b893'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1966, 'Renewables (% equivalent primary energy)': 6.516204}
# {'_id': ObjectId('6804d79bbace469554c9b894'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.423987}
# {'_id': ObjectId('6804d79bbace469554c9b895'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.3901453}
# {'_id': ObjectId('6804d79bbace469554c9b896'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1969, 'Renewables (% equivalent primary energy)': 6.32996}
# {'_id': ObjectId('6804d79bbace469554c9b897'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1970, 'Renewables (% equivalent primary energy)': 6.2402315}
# {'_id': ObjectId('6804d79bbace469554c9b898'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1971, 'Renewables (% equivalent primary energy)': 6.2751184}
# {'_id': ObjectId('6804d79bbace469554c9b899'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1972, 'Renewables (% equivalent primary energy)': 6.231038}
# {'_id': ObjectId('6804d79bbace469554c9b89a'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1973, 'Renewables (% equivalent primary energy)': 5.98148}
# {'_id': ObjectId('6804d79bbace469554c9b89b'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1974, 'Renewables (% equivalent primary energy)': 6.527657}
# {'_id': ObjectId('6804d79bbace469554c9b89c'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1975, 'Renewables (% equivalent primary energy)': 6.5613737}
# {'_id': ObjectId('6804d79bbace469554c9b89d'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1976, 'Renewables (% equivalent primary energy)': 6.2220235}
# {'_id': ObjectId('6804d79bbace469554c9b89e'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1977, 'Renewables (% equivalent primary energy)': 6.216026}
# {'_id': ObjectId('6804d79bbace469554c9b89f'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1978, 'Renewables (% equivalent primary energy)': 6.4746337}
# {'_id': ObjectId('6804d79bbace469554c9b8a0'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1979, 'Renewables (% equivalent primary energy)': 6.5883255}
# {'_id': ObjectId('6804d79bbace469554c9b8a1'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1980, 'Renewables (% equivalent primary energy)': 6.8036585}
# {'_id': ObjectId('6804d79bbace469554c9b8a2'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1981, 'Renewables (% equivalent primary energy)': 6.9859357}
# {'_id': ObjectId('6804d79bbace469554c9b8a3'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1982, 'Renewables (% equivalent primary energy)': 7.1871624}
# {'_id': ObjectId('6804d79bbace469554c9b8a4'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1983, 'Renewables (% equivalent primary energy)': 7.3960943}
# {'_id': ObjectId('6804d79bbace469554c9b8a5'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1984, 'Renewables (% equivalent primary energy)': 7.3479614}
# {'_id': ObjectId('6804d79bbace469554c9b8a6'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1985, 'Renewables (% equivalent primary energy)': 7.309479}
# {'_id': ObjectId('6804d79bbace469554c9b8a7'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1986, 'Renewables (% equivalent primary energy)': 7.2850266}
# {'_id': ObjectId('6804d79bbace469554c9b8a8'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1987, 'Renewables (% equivalent primary energy)': 7.1429477}
# {'_id': ObjectId('6804d79bbace469554c9b8a9'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1988, 'Renewables (% equivalent primary energy)': 7.10847}
# {'_id': ObjectId('6804d79bbace469554c9b8aa'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1989, 'Renewables (% equivalent primary energy)': 6.9876184}
# {'_id': ObjectId('6804d79bbace469554c9b8ab'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1990, 'Renewables (% equivalent primary energy)': 7.182692}
# {'_id': ObjectId('6804d79bbace469554c9b8ac'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1991, 'Renewables (% equivalent primary energy)': 7.301195}
# {'_id': ObjectId('6804d79bbace469554c9b8ad'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1992, 'Renewables (% equivalent primary energy)': 7.2864876}
# {'_id': ObjectId('6804d79bbace469554c9b8ae'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1993, 'Renewables (% equivalent primary energy)': 7.6539183}
# {'_id': ObjectId('6804d79bbace469554c9b8af'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1994, 'Renewables (% equivalent primary energy)': 7.6321683}
# {'_id': ObjectId('6804d79bbace469554c9b8b0'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1995, 'Renewables (% equivalent primary energy)': 7.8718243}
# {'_id': ObjectId('6804d79bbace469554c9b8b1'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1996, 'Renewables (% equivalent primary energy)': 7.755703}
# {'_id': ObjectId('6804d79bbace469554c9b8b2'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1997, 'Renewables (% equivalent primary energy)': 7.847491}
# {'_id': ObjectId('6804d79bbace469554c9b8b3'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1998, 'Renewables (% equivalent primary energy)': 7.890869}
# {'_id': ObjectId('6804d79bbace469554c9b8b4'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1999, 'Renewables (% equivalent primary energy)': 7.8530593}
# {'_id': ObjectId('6804d79bbace469554c9b8b5'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2000, 'Renewables (% equivalent primary energy)': 7.8158455}
# {'_id': ObjectId('6804d79bbace469554c9b8b6'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2001, 'Renewables (% equivalent primary energy)': 7.552836}
# {'_id': ObjectId('6804d79bbace469554c9b8b7'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2002, 'Renewables (% equivalent primary energy)': 7.5668545}
# {'_id': ObjectId('6804d79bbace469554c9b8b8'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2003, 'Renewables (% equivalent primary energy)': 7.3342075}
# {'_id': ObjectId('6804d79bbace469554c9b8b9'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2004, 'Renewables (% equivalent primary energy)': 7.518}
# {'_id': ObjectId('6804d79bbace469554c9b8ba'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2005, 'Renewables (% equivalent primary energy)': 7.5638204}
# {'_id': ObjectId('6804d79bbace469554c9b8bb'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2006, 'Renewables (% equivalent primary energy)': 7.705343}
# {'_id': ObjectId('6804d79bbace469554c9b8bc'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2007, 'Renewables (% equivalent primary energy)': 7.7473364}
# {'_id': ObjectId('6804d79bbace469554c9b8bd'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2008, 'Renewables (% equivalent primary energy)': 8.245706}
# {'_id': ObjectId('6804d79bbace469554c9b8be'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2009, 'Renewables (% equivalent primary energy)': 8.564856}
# {'_id': ObjectId('6804d79bbace469554c9b8bf'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2010, 'Renewables (% equivalent primary energy)': 8.797048}
# {'_id': ObjectId('6804d79bbace469554c9b8c0'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2011, 'Renewables (% equivalent primary energy)': 8.980997}
# {'_id': ObjectId('6804d79bbace469554c9b8c1'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2012, 'Renewables (% equivalent primary energy)': 9.414955}
# {'_id': ObjectId('6804d79bbace469554c9b8c2'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2013, 'Renewables (% equivalent primary energy)': 9.847355}
# {'_id': ObjectId('6804d79bbace469554c9b8c3'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2014, 'Renewables (% equivalent primary energy)': 10.218171}
# {'_id': ObjectId('6804d79bbace469554c9b8c4'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2015, 'Renewables (% equivalent primary energy)': 10.504495}
# {'_id': ObjectId('6804d79bbace469554c9b8c5'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2016, 'Renewables (% equivalent primary energy)': 10.980251}
# {'_id': ObjectId('6804d79bbace469554c9b8c6'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2017, 'Renewables (% equivalent primary energy)': 11.337292}
# {'_id': ObjectId('6804d79bbace469554c9b8c7'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2018, 'Renewables (% equivalent primary energy)': 11.743186}
# {'_id': ObjectId('6804d79bbace469554c9b8c8'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2019, 'Renewables (% equivalent primary energy)': 12.228147}
# {'_id': ObjectId('6804d79bbace469554c9b8c9'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2020, 'Renewables (% equivalent primary energy)': 13.404395}
# {'_id': ObjectId('6804d79bbace469554c9b8ca'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2021, 'Renewables (% equivalent primary energy)': 13.469198}
# {'_id': ObjectId('6804d79bbace469554c9b8cb'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2022, 'Renewables (% equivalent primary energy)': 14.119935}
# {'_id': ObjectId('6804d79bbace469554c9b8cc'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2023, 'Renewables (% equivalent primary energy)': 14.562141}

# %%
renewable_all_records = renewable_collection.find()

# %%
print(renewable_all_records)
# Out:
# <pymongo.synchronous.cursor.Cursor object at 0x15f9deb90>

# %%
renewable_list_cursor=list(renewable_all_records)

# %%
renewable_list_cursor
# Out:
# [{'_id': ObjectId('6804d79bbace469554c9a5a6'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 5.7402806},
#  {'_id': ObjectId('6804d79bbace469554c9a5a7'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 6.1139693},
#  {'_id': ObjectId('6804d79bbace469554c9a5a8'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.31658},
#  {'_id': ObjectId('6804d79bbace469554c9a5a9'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.994845},
#  {'_id': ObjectId('6804d79bbace469554c9a5aa'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 7.9439163},
#  {'_id': ObjectId('6804d79bbace469554c9a5ab'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 9.148895},
#  {'_id': ObjectId('6804d79bbace469554c9a5ac'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 8.124994},
#  {'_id': ObjectId('6804d79bbace469554c9a5ad'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 8.747272},
#  {'_id': ObjectId('6804d79bbace469554c9a5ae'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 8.54162},
#  {'_id': ObjectId('6804d79bbace469554c9a5af'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 9.252387},
#  {'_id': ObjectId('6804d79bbace469554c9a5b0'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 9.228769},
#  {'_id': ObjectId('6804d79bbace469554c9a5b1'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 9.41638},
#  {'_id': ObjectId('6804d79bbace469554c9a5b2'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 9.803094},
#  {'_id': ObjectId('6804d79bbace469554c9a5b3'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 9.518462},
#  {'_id': ObjectId('6804d79bbace469554c9a5b4'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 9.349527},
#  {'_id': ObjectId('6804d79bbace469554c9a5b5'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 8.481442},
#  {'_id': ObjectId('6804d79bbace469554c9a5b6'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 7.8527517},
#  {'_id': ObjectId('6804d79bbace469554c9a5b7'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 7.3734274},
#  {'_id': ObjectId('6804d79bbace469554c9a5b8'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 6.456112},
#  {'_id': ObjectId('6804d79bbace469554c9a5b9'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 6.1585774},
#  {'_id': ObjectId('6804d79bbace469554c9a5ba'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 6.5793424},
#  {'_id': ObjectId('6804d79bbace469554c9a5bb'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 6.7159667},
#  {'_id': ObjectId('6804d79bbace469554c9a5bc'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 6.243963},
#  {'_id': ObjectId('6804d79bbace469554c9a5bd'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 6.3621163},
#  {'_id': ObjectId('6804d79bbace469554c9a5be'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 6.66546},
#  {'_id': ObjectId('6804d79bbace469554c9a5bf'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 6.5857716},
#  {'_id': ObjectId('6804d79bbace469554c9a5c0'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 6.9810143},
#  {'_id': ObjectId('6804d79bbace469554c9a5c1'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 6.5694675},
#  {'_id': ObjectId('6804d79bbace469554c9a5c2'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 6.43179},
#  {'_id': ObjectId('6804d79bbace469554c9a5c3'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 6.3092456},
#  {'_id': ObjectId('6804d79bbace469554c9a5c4'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 6.306244},
#  {'_id': ObjectId('6804d79bbace469554c9a5c5'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 6.4332542},
#  {'_id': ObjectId('6804d79bbace469554c9a5c6'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 6.465725},
#  {'_id': ObjectId('6804d79bbace469554c9a5c7'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 6.676159},
#  {'_id': ObjectId('6804d79bbace469554c9a5c8'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 6.858631},
#  {'_id': ObjectId('6804d79bbace469554c9a5c9'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 7.2029395},
#  {'_id': ObjectId('6804d79bbace469554c9a5ca'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 7.4362373},
#  {'_id': ObjectId('6804d79bbace469554c9a5cb'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 7.671944},
#  {'_id': ObjectId('6804d79bbace469554c9a5cc'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 7.105203},
#  {'_id': ObjectId('6804d79bbace469554c9a5cd'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 6.980063},
#  {'_id': ObjectId('6804d79bbace469554c9a5ce'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 7.0285006},
#  {'_id': ObjectId('6804d79bbace469554c9a5cf'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 7.1611776},
#  {'_id': ObjectId('6804d79bbace469554c9a5d0'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 7.0572457},
#  {'_id': ObjectId('6804d79bbace469554c9a5d1'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 6.761787},
#  {'_id': ObjectId('6804d79bbace469554c9a5d2'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 6.810709},
#  {'_id': ObjectId('6804d79bbace469554c9a5d3'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 7.1290402},
#  {'_id': ObjectId('6804d79bbace469554c9a5d4'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 7.2594023},
#  {'_id': ObjectId('6804d79bbace469554c9a5d5'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.9972486},
#  {'_id': ObjectId('6804d79bbace469554c9a5d6'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 7.189637},
#  {'_id': ObjectId('6804d79bbace469554c9a5d7'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.5156765},
#  {'_id': ObjectId('6804d79bbace469554c9a5d8'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.527505},
#  {'_id': ObjectId('6804d79bbace469554c9a5d9'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 7.404274},
#  {'_id': ObjectId('6804d79bbace469554c9a5da'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 7.6419463},
#  {'_id': ObjectId('6804d79bbace469554c9a5db'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 8.005552},
#  {'_id': ObjectId('6804d79bbace469554c9a5dc'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 8.356321},
#  {'_id': ObjectId('6804d79bbace469554c9a5dd'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 9.415897},
#  {'_id': ObjectId('6804d79bbace469554c9a5de'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 9.152215},
#  {'_id': ObjectId('6804d79bbace469554c9a5df'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 9.298186},
#  {'_id': ObjectId('6804d79bbace469554c9a5e0'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 9.826173},
#  {'_id': ObjectId('6804d79bbace469554c9a5e1'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 5.7402806},
#  {'_id': ObjectId('6804d79bbace469554c9a5e2'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 6.113969},
#  {'_id': ObjectId('6804d79bbace469554c9a5e3'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.31658},
#  {'_id': ObjectId('6804d79bbace469554c9a5e4'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.994845},
#  {'_id': ObjectId('6804d79bbace469554c9a5e5'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 7.9439154},
#  {'_id': ObjectId('6804d79bbace469554c9a5e6'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 9.148896},
#  {'_id': ObjectId('6804d79bbace469554c9a5e7'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 8.124996},
#  {'_id': ObjectId('6804d79bbace469554c9a5e8'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 8.7472725},
#  {'_id': ObjectId('6804d79bbace469554c9a5e9'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 8.54162},
#  {'_id': ObjectId('6804d79bbace469554c9a5ea'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 9.252388},
#  {'_id': ObjectId('6804d79bbace469554c9a5eb'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 9.228768},
#  {'_id': ObjectId('6804d79bbace469554c9a5ec'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 9.416379},
#  {'_id': ObjectId('6804d79bbace469554c9a5ed'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 9.803097},
#  {'_id': ObjectId('6804d79bbace469554c9a5ee'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 9.518462},
#  {'_id': ObjectId('6804d79bbace469554c9a5ef'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 9.349527},
#  {'_id': ObjectId('6804d79bbace469554c9a5f0'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 8.481442},
#  {'_id': ObjectId('6804d79bbace469554c9a5f1'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 7.8527517},
#  {'_id': ObjectId('6804d79bbace469554c9a5f2'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 7.3734274},
#  {'_id': ObjectId('6804d79bbace469554c9a5f3'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 6.456112},
#  {'_id': ObjectId('6804d79bbace469554c9a5f4'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 6.1585774},
#  {'_id': ObjectId('6804d79bbace469554c9a5f5'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 6.5793424},
#  {'_id': ObjectId('6804d79bbace469554c9a5f6'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 6.7159667},
#  {'_id': ObjectId('6804d79bbace469554c9a5f7'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 6.243963},
#  {'_id': ObjectId('6804d79bbace469554c9a5f8'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 6.3621163},
#  {'_id': ObjectId('6804d79bbace469554c9a5f9'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 6.6654606},
#  {'_id': ObjectId('6804d79bbace469554c9a5fa'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 6.5857716},
#  {'_id': ObjectId('6804d79bbace469554c9a5fb'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 6.9810143},
#  {'_id': ObjectId('6804d79bbace469554c9a5fc'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 6.5694675},
#  {'_id': ObjectId('6804d79bbace469554c9a5fd'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 6.43179},
#  {'_id': ObjectId('6804d79bbace469554c9a5fe'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 6.3092456},
#  {'_id': ObjectId('6804d79bbace469554c9a5ff'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 6.306244},
#  {'_id': ObjectId('6804d79bbace469554c9a600'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 6.433255},
#  {'_id': ObjectId('6804d79bbace469554c9a601'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 6.465725},
#  {'_id': ObjectId('6804d79bbace469554c9a602'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 6.6761603},
#  {'_id': ObjectId('6804d79bbace469554c9a603'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 6.8586307},
#  {'_id': ObjectId('6804d79bbace469554c9a604'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 7.2029395},
#  {'_id': ObjectId('6804d79bbace469554c9a605'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 7.436237},
#  {'_id': ObjectId('6804d79bbace469554c9a606'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 7.671944},
#  {'_id': ObjectId('6804d79bbace469554c9a607'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 7.105202},
#  {'_id': ObjectId('6804d79bbace469554c9a608'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 6.980063},
#  {'_id': ObjectId('6804d79bbace469554c9a609'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 7.0285006},
#  {'_id': ObjectId('6804d79bbace469554c9a60a'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 7.161177},
#  {'_id': ObjectId('6804d79bbace469554c9a60b'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 7.0572457},
#  {'_id': ObjectId('6804d79bbace469554c9a60c'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 6.761787},
#  {'_id': ObjectId('6804d79bbace469554c9a60d'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 6.8107085},
#  {'_id': ObjectId('6804d79bbace469554c9a60e'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 7.12904},
#  {'_id': ObjectId('6804d79bbace469554c9a60f'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 7.2594023},
#  {'_id': ObjectId('6804d79bbace469554c9a610'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.9972486},
#  {'_id': ObjectId('6804d79bbace469554c9a611'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 7.189637},
#  {'_id': ObjectId('6804d79bbace469554c9a612'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.5156765},
#  {'_id': ObjectId('6804d79bbace469554c9a613'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.527505},
#  {'_id': ObjectId('6804d79bbace469554c9a614'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 7.404273},
#  {'_id': ObjectId('6804d79bbace469554c9a615'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 7.6419473},
#  {'_id': ObjectId('6804d79bbace469554c9a616'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 8.005553},
#  {'_id': ObjectId('6804d79bbace469554c9a617'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 8.356321},
#  {'_id': ObjectId('6804d79bbace469554c9a618'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 9.415897},
#  {'_id': ObjectId('6804d79bbace469554c9a619'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 9.152214},
#  {'_id': ObjectId('6804d79bbace469554c9a61a'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 9.298185},
#  {'_id': ObjectId('6804d79bbace469554c9a61b'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 9.826172},
#  {'_id': ObjectId('6804d79bbace469554c9a61c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 4.7630677},
#  {'_id': ObjectId('6804d79bbace469554c9a61d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 3.518747},
#  {'_id': ObjectId('6804d79bbace469554c9a61e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 4.291954},
#  {'_id': ObjectId('6804d79bbace469554c9a61f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 5.4861946},
#  {'_id': ObjectId('6804d79bbace469554c9a620'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 3.1827633},
#  {'_id': ObjectId('6804d79bbace469554c9a621'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 4.6656837},
#  {'_id': ObjectId('6804d79bbace469554c9a622'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 2.4559188},
#  {'_id': ObjectId('6804d79bbace469554c9a623'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 3.278343},
#  {'_id': ObjectId('6804d79bbace469554c9a624'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 4.175826},
#  {'_id': ObjectId('6804d79bbace469554c9a625'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 2.494738},
#  {'_id': ObjectId('6804d79bbace469554c9a626'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 1.3782818},
#  {'_id': ObjectId('6804d79bbace469554c9a627'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 1.4010222},
#  {'_id': ObjectId('6804d79bbace469554c9a628'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 0.8817282},
#  {'_id': ObjectId('6804d79bbace469554c9a629'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 0.6521151},
#  {'_id': ObjectId('6804d79bbace469554c9a62a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 0.5792936},
#  {'_id': ObjectId('6804d79bbace469554c9a62b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 0.4290016},
#  {'_id': ObjectId('6804d79bbace469554c9a62c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 0.50294036},
#  {'_id': ObjectId('6804d79bbace469554c9a62d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 0.5708701},
#  {'_id': ObjectId('6804d79bbace469554c9a62e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 0.25644946},
#  {'_id': ObjectId('6804d79bbace469554c9a62f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 0.5136736},
#  {'_id': ObjectId('6804d79bbace469554c9a630'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 0.72826535},
#  {'_id': ObjectId('6804d79bbace469554c9a631'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 0.2664045},
#  {'_id': ObjectId('6804d79bbace469554c9a632'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 0.5174274},
#  {'_id': ObjectId('6804d79bbace469554c9a633'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 0.17717436},
#  {'_id': ObjectId('6804d79bbace469554c9a634'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 0.2249582},
#  {'_id': ObjectId('6804d79bbace469554c9a635'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 0.1267387},
#  {'_id': ObjectId('6804d79bbace469554c9a636'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 0.277607},
#  {'_id': ObjectId('6804d79bbace469554c9a637'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 0.18375748},
#  {'_id': ObjectId('6804d79bbace469554c9a638'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 0.35028014},
#  {'_id': ObjectId('6804d79bbace469554c9a639'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 0.16257899},
#  {'_id': ObjectId('6804d79bbace469554c9a63a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 0.18224756},
#  {'_id': ObjectId('6804d79bbace469554c9a63b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 0.1288034},
#  {'_id': ObjectId('6804d79bbace469554c9a63c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 0.074455895},
#  {'_id': ObjectId('6804d79bbace469554c9a63d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 0.20617963},
#  {'_id': ObjectId('6804d79bbace469554c9a63e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 0.1927434},
#  {'_id': ObjectId('6804d79bbace469554c9a63f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 0.053235486},
#  {'_id': ObjectId('6804d79bbace469554c9a640'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 0.065218486},
#  {'_id': ObjectId('6804d79bbace469554c9a641'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 0.05167676},
#  {'_id': ObjectId('6804d79bbace469554c9a642'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 0.228104},
#  {'_id': ObjectId('6804d79bbace469554c9a643'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 0.2067869},
#  {'_id': ObjectId('6804d79bbace469554c9a644'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 0.43411884},
#  {'_id': ObjectId('6804d79bbace469554c9a645'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 0.16327195},
#  {'_id': ObjectId('6804d79bbace469554c9a646'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 0.15990457},
#  {'_id': ObjectId('6804d79bbace469554c9a647'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 0.1877543},
#  {'_id': ObjectId('6804d79bbace469554c9a648'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 0.21278548},
#  {'_id': ObjectId('6804d79bbace469554c9a649'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 0.11513415},
#  {'_id': ObjectId('6804d79bbace469554c9a64a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 0.23525994},
#  {'_id': ObjectId('6804d79bbace469554c9a64b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 0.22453195},
#  {'_id': ObjectId('6804d79bbace469554c9a64c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 0.06476319},
#  {'_id': ObjectId('6804d79bbace469554c9a64d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 0.11750259},
#  {'_id': ObjectId('6804d79bbace469554c9a64e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 0.09681336},
#  {'_id': ObjectId('6804d79bbace469554c9a64f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 0.14580713},
#  {'_id': ObjectId('6804d79bbace469554c9a650'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 0.24701828},
#  {'_id': ObjectId('6804d79bbace469554c9a651'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 0.28842947},
#  {'_id': ObjectId('6804d79bbace469554c9a652'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 0.29497427},
#  {'_id': ObjectId('6804d79bbace469554c9a653'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 0.30043116},
#  {'_id': ObjectId('6804d79bbace469554c9a654'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 0.25285673},
#  {'_id': ObjectId('6804d79bbace469554c9a655'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 0.24182516},
#  {'_id': ObjectId('6804d79bbace469554c9a656'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 0.27036947},
#  {'_id': ObjectId('6804d79bbace469554c9a657'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 1.1026944},
#  {'_id': ObjectId('6804d79bbace469554c9a658'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 1.0818663},
#  {'_id': ObjectId('6804d79bbace469554c9a659'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 1.0765308},
#  {'_id': ObjectId('6804d79bbace469554c9a65a'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 1.2272897},
#  {'_id': ObjectId('6804d79bbace469554c9a65b'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 1.0651326},
#  {'_id': ObjectId('6804d79bbace469554c9a65c'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 1.3533598},
#  {'_id': ObjectId('6804d79bbace469554c9a65d'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 1.2702763},
#  {'_id': ObjectId('6804d79bbace469554c9a65e'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 1.2349532},
#  {'_id': ObjectId('6804d79bbace469554c9a65f'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 2.2839267},
#  {'_id': ObjectId('6804d79bbace469554c9a660'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 3.629566},
#  {'_id': ObjectId('6804d79bbace469554c9a661'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 3.8664374},
#  {'_id': ObjectId('6804d79bbace469554c9a662'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 3.5540857},
#  {'_id': ObjectId('6804d79bbace469554c9a663'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 3.9090023},
#  {'_id': ObjectId('6804d79bbace469554c9a664'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 5.227204},
#  {'_id': ObjectId('6804d79bbace469554c9a665'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 6.702873},
#  {'_id': ObjectId('6804d79bbace469554c9a666'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 9.552048},
#  {'_id': ObjectId('6804d79bbace469554c9a667'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 9.542367},
#  {'_id': ObjectId('6804d79bbace469554c9a668'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 11.229478},
#  {'_id': ObjectId('6804d79bbace469554c9a669'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 11.313745},
#  {'_id': ObjectId('6804d79bbace469554c9a66a'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 12.136334},
#  {'_id': ObjectId('6804d79bbace469554c9a66b'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 12.759911},
#  {'_id': ObjectId('6804d79bbace469554c9a66c'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 12.297877},
#  {'_id': ObjectId('6804d79bbace469554c9a66d'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 12.24687},
#  {'_id': ObjectId('6804d79bbace469554c9a66e'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 8.416951},
#  {'_id': ObjectId('6804d79bbace469554c9a66f'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 7.543206},
#  {'_id': ObjectId('6804d79bbace469554c9a670'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 10.29241},
#  {'_id': ObjectId('6804d79bbace469554c9a671'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 9.080978},
#  {'_id': ObjectId('6804d79bbace469554c9a672'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 10.2065},
#  {'_id': ObjectId('6804d79bbace469554c9a673'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 12.215968},
#  {'_id': ObjectId('6804d79bbace469554c9a674'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 13.306112},
#  {'_id': ObjectId('6804d79bbace469554c9a675'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 12.535252},
#  {'_id': ObjectId('6804d79bbace469554c9a676'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 10.224623},
#  {'_id': ObjectId('6804d79bbace469554c9a677'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 12.513889},
#  {'_id': ObjectId('6804d79bbace469554c9a678'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 11.481932},
#  {'_id': ObjectId('6804d79bbace469554c9a679'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 9.2246065},
#  {'_id': ObjectId('6804d79bbace469554c9a67a'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 12.283152},
#  {'_id': ObjectId('6804d79bbace469554c9a67b'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 15.93624},
#  {'_id': ObjectId('6804d79bbace469554c9a67c'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 16.247978},
#  {'_id': ObjectId('6804d79bbace469554c9a67d'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 14.40661},
#  {'_id': ObjectId('6804d79bbace469554c9a67e'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 12.185576},
#  {'_id': ObjectId('6804d79bbace469554c9a67f'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 12.790038},
#  {'_id': ObjectId('6804d79bbace469554c9a680'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 13.449896},
#  {'_id': ObjectId('6804d79bbace469554c9a681'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 10.613073},
#  {'_id': ObjectId('6804d79bbace469554c9a682'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 10.447249},
#  {'_id': ObjectId('6804d79bbace469554c9a683'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 11.797741},
#  {'_id': ObjectId('6804d79bbace469554c9a684'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 11.650168},
#  {'_id': ObjectId('6804d79bbace469554c9a685'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 10.914268},
#  {'_id': ObjectId('6804d79bbace469554c9a686'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 10.176803},
#  {'_id': ObjectId('6804d79bbace469554c9a687'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 10.940409},
#  {'_id': ObjectId('6804d79bbace469554c9a688'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 11.038969},
#  {'_id': ObjectId('6804d79bbace469554c9a689'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 10.89336},
#  {'_id': ObjectId('6804d79bbace469554c9a68a'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 10.17179},
#  {'_id': ObjectId('6804d79bbace469554c9a68b'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 10.979133},
#  {'_id': ObjectId('6804d79bbace469554c9a68c'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 11.331651},
#  {'_id': ObjectId('6804d79bbace469554c9a68d'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 11.911147},
#  {'_id': ObjectId('6804d79bbace469554c9a68e'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 12.310073},
#  {'_id': ObjectId('6804d79bbace469554c9a68f'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 11.335143},
#  {'_id': ObjectId('6804d79bbace469554c9a690'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 12.188763},
#  {'_id': ObjectId('6804d79bbace469554c9a691'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 14.102216},
#  {'_id': ObjectId('6804d79bbace469554c9a692'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 7.8735447},
#  {'_id': ObjectId('6804d79bbace469554c9a693'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 7.4938087},
#  {'_id': ObjectId('6804d79bbace469554c9a694'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.7346387},
#  {'_id': ObjectId('6804d79bbace469554c9a695'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.963028},
#  {'_id': ObjectId('6804d79bbace469554c9a696'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 6.3012996},
#  {'_id': ObjectId('6804d79bbace469554c9a697'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 5.661888},
#  {'_id': ObjectId('6804d79bbace469554c9a698'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 5.6825113},
#  {'_id': ObjectId('6804d79bbace469554c9a699'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 5.4817533},
#  {'_id': ObjectId('6804d79bbace469554c9a69a'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 4.7254024},
#  {'_id': ObjectId('6804d79bbace469554c9a69b'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 5.289435},
#  {'_id': ObjectId('6804d79bbace469554c9a69c'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 5.432976},
#  {'_id': ObjectId('6804d79bbace469554c9a69d'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 5.272847},
#  {'_id': ObjectId('6804d79bbace469554c9a69e'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 4.885452},
#  {'_id': ObjectId('6804d79bbace469554c9a69f'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 4.842396},
#  {'_id': ObjectId('6804d79bbace469554c9a6a0'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 5.0050187},
#  {'_id': ObjectId('6804d79bbace469554c9a6a1'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 5.387261},
#  {'_id': ObjectId('6804d79bbace469554c9a6a2'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 5.6962633},
#  {'_id': ObjectId('6804d79bbace469554c9a6a3'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 5.688111},
#  {'_id': ObjectId('6804d79bbace469554c9a6a4'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 5.652118},
#  {'_id': ObjectId('6804d79bbace469554c9a6a5'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 5.339281},
#  {'_id': ObjectId('6804d79bbace469554c9a6a6'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 5.351906},
#  {'_id': ObjectId('6804d79bbace469554c9a6a7'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 5.190978},
#  {'_id': ObjectId('6804d79bbace469554c9a6a8'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 5.0590653},
#  {'_id': ObjectId('6804d79bbace469554c9a6a9'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 5.4249687},
#  {'_id': ObjectId('6804d79bbace469554c9a6aa'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 5.319675},
#  {'_id': ObjectId('6804d79bbace469554c9a6ab'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 5.339282},
#  {'_id': ObjectId('6804d79bbace469554c9a6ac'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 5.1891055},
#  {'_id': ObjectId('6804d79bbace469554c9a6ad'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 5.0055637},
#  {'_id': ObjectId('6804d79bbace469554c9a6ae'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 5.3127103},
#  {'_id': ObjectId('6804d79bbace469554c9a6af'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 5.0516157},
#  {'_id': ObjectId('6804d79bbace469554c9a6b0'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 5.271553},
#  {'_id': ObjectId('6804d79bbace469554c9a6b1'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 5.018597},
#  {'_id': ObjectId('6804d79bbace469554c9a6b2'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 4.8939986},
#  {'_id': ObjectId('6804d79bbace469554c9a6b3'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 5.178817},
#  {'_id': ObjectId('6804d79bbace469554c9a6b4'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 4.9296236},
#  {'_id': ObjectId('6804d79bbace469554c9a6b5'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 4.9015436},
#  {'_id': ObjectId('6804d79bbace469554c9a6b6'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 5.0736527},
#  {'_id': ObjectId('6804d79bbace469554c9a6b7'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 4.9854317},
#  {'_id': ObjectId('6804d79bbace469554c9a6b8'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 4.7931614},
#  {'_id': ObjectId('6804d79bbace469554c9a6b9'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 5.0985446},
#  {'_id': ObjectId('6804d79bbace469554c9a6ba'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 4.9199796},
#  {'_id': ObjectId('6804d79bbace469554c9a6bb'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 5.117429},
#  {'_id': ObjectId('6804d79bbace469554c9a6bc'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 5.0853057},
#  {'_id': ObjectId('6804d79bbace469554c9a6bd'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 5.605236},
#  {'_id': ObjectId('6804d79bbace469554c9a6be'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 5.458485},
#  {'_id': ObjectId('6804d79bbace469554c9a6bf'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 5.9468226},
#  {'_id': ObjectId('6804d79bbace469554c9a6c0'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 5.8778787},
#  {'_id': ObjectId('6804d79bbace469554c9a6c1'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.4778247},
#  {'_id': ObjectId('6804d79bbace469554c9a6c2'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 6.987413},
#  {'_id': ObjectId('6804d79bbace469554c9a6c3'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.551866},
#  {'_id': ObjectId('6804d79bbace469554c9a6c4'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.908183},
#  {'_id': ObjectId('6804d79bbace469554c9a6c5'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 8.438702},
#  {'_id': ObjectId('6804d79bbace469554c9a6c6'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 8.845372},
#  {'_id': ObjectId('6804d79bbace469554c9a6c7'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 9.349624},
#  {'_id': ObjectId('6804d79bbace469554c9a6c8'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 10.002659},
#  {'_id': ObjectId('6804d79bbace469554c9a6c9'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 10.741154},
#  {'_id': ObjectId('6804d79bbace469554c9a6ca'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 11.2254095},
#  {'_id': ObjectId('6804d79bbace469554c9a6cb'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 11.969987},
#  {'_id': ObjectId('6804d79bbace469554c9a6cc'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 12.191386},
#  {'_id': ObjectId('6804d79bbace469554c9a6cd'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 8.879346},
#  {'_id': ObjectId('6804d79bbace469554c9a6ce'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 8.41833},
#  {'_id': ObjectId('6804d79bbace469554c9a6cf'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 7.6206317},
#  {'_id': ObjectId('6804d79bbace469554c9a6d0'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 7.814885},
#  {'_id': ObjectId('6804d79bbace469554c9a6d1'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1969,
# ...
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 13.12191},
#  {'_id': ObjectId('6804d79bbace469554c9a92e'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 12.341241},
#  {'_id': ObjectId('6804d79bbace469554c9a92f'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 15.349611},
#  {'_id': ObjectId('6804d79bbace469554c9a930'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 17.265028},
#  {'_id': ObjectId('6804d79bbace469554c9a931'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 20.214928},
#  {'_id': ObjectId('6804d79bbace469554c9a932'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 22.399574},
#  {'_id': ObjectId('6804d79bbace469554c9a933'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 22.183714},
#  {'_id': ObjectId('6804d79bbace469554c9a934'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 23.578016},
#  {'_id': ObjectId('6804d79bbace469554c9a935'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 25.592047},
#  {'_id': ObjectId('6804d79bbace469554c9a936'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 26.786247},
#  {'_id': ObjectId('6804d79bbace469554c9a937'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 29.564842},
#  {'_id': ObjectId('6804d79bbace469554c9a938'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 28.886547},
#  {'_id': ObjectId('6804d79bbace469554c9a939'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 30.695482},
#  {'_id': ObjectId('6804d79bbace469554c9a93a'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 31.725052},
#  {'_id': ObjectId('6804d79bbace469554c9a93b'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 32.043663},
#  {'_id': ObjectId('6804d79bbace469554c9a93c'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 29.83178},
#  {'_id': ObjectId('6804d79bbace469554c9a93d'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 27.12252},
#  {'_id': ObjectId('6804d79bbace469554c9a93e'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 27.521982},
#  {'_id': ObjectId('6804d79bbace469554c9a93f'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 25.153784},
#  {'_id': ObjectId('6804d79bbace469554c9a940'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 23.175493},
#  {'_id': ObjectId('6804d79bbace469554c9a941'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 25.864536},
#  {'_id': ObjectId('6804d79bbace469554c9a942'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 24.05491},
#  {'_id': ObjectId('6804d79bbace469554c9a943'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 21.420517},
#  {'_id': ObjectId('6804d79bbace469554c9a944'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 24.960342},
#  {'_id': ObjectId('6804d79bbace469554c9a945'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 25.19626},
#  {'_id': ObjectId('6804d79bbace469554c9a946'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 22.390955},
#  {'_id': ObjectId('6804d79bbace469554c9a947'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 23.148567},
#  {'_id': ObjectId('6804d79bbace469554c9a948'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 23.086876},
#  {'_id': ObjectId('6804d79bbace469554c9a949'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 23.529451},
#  {'_id': ObjectId('6804d79bbace469554c9a94a'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 24.86708},
#  {'_id': ObjectId('6804d79bbace469554c9a94b'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 24.72052},
#  {'_id': ObjectId('6804d79bbace469554c9a94c'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 24.016212},
#  {'_id': ObjectId('6804d79bbace469554c9a94d'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 25.384161},
#  {'_id': ObjectId('6804d79bbace469554c9a94e'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 25.172054},
#  {'_id': ObjectId('6804d79bbace469554c9a94f'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 27.074661},
#  {'_id': ObjectId('6804d79bbace469554c9a950'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 26.338593},
#  {'_id': ObjectId('6804d79bbace469554c9a951'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 27.493683},
#  {'_id': ObjectId('6804d79bbace469554c9a952'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 27.202362},
#  {'_id': ObjectId('6804d79bbace469554c9a953'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 27.154976},
#  {'_id': ObjectId('6804d79bbace469554c9a954'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 26.713547},
#  {'_id': ObjectId('6804d79bbace469554c9a955'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 26.798523},
#  {'_id': ObjectId('6804d79bbace469554c9a956'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 28.610437},
#  {'_id': ObjectId('6804d79bbace469554c9a957'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 29.266819},
#  {'_id': ObjectId('6804d79bbace469554c9a958'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 25.451958},
#  {'_id': ObjectId('6804d79bbace469554c9a959'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 32.487274},
#  {'_id': ObjectId('6804d79bbace469554c9a95a'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 31.537489},
#  {'_id': ObjectId('6804d79bbace469554c9a95b'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 30.899012},
#  {'_id': ObjectId('6804d79bbace469554c9a95c'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 26.829386},
#  {'_id': ObjectId('6804d79bbace469554c9a95d'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 16.141762},
#  {'_id': ObjectId('6804d79bbace469554c9a95e'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 15.867013},
#  {'_id': ObjectId('6804d79bbace469554c9a95f'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 15.8887},
#  {'_id': ObjectId('6804d79bbace469554c9a960'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 13.367759},
#  {'_id': ObjectId('6804d79bbace469554c9a961'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 13.999327},
#  {'_id': ObjectId('6804d79bbace469554c9a962'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 14.19122},
#  {'_id': ObjectId('6804d79bbace469554c9a963'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 14.860414},
#  {'_id': ObjectId('6804d79bbace469554c9a964'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 17.308092},
#  {'_id': ObjectId('6804d79bbace469554c9a965'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 17.450201},
#  {'_id': ObjectId('6804d79bbace469554c9a966'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 19.770317},
#  {'_id': ObjectId('6804d79bbace469554c9a967'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 21.942268},
#  {'_id': ObjectId('6804d79bbace469554c9a968'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 21.900364},
#  {'_id': ObjectId('6804d79bbace469554c9a969'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 22.105398},
#  {'_id': ObjectId('6804d79bbace469554c9a96a'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 22.151817},
#  {'_id': ObjectId('6804d79bbace469554c9a96b'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 21.552887},
#  {'_id': ObjectId('6804d79bbace469554c9a96c'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 22.069942},
#  {'_id': ObjectId('6804d79bbace469554c9a96d'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 22.72726},
#  {'_id': ObjectId('6804d79bbace469554c9a96e'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 26.627869},
#  {'_id': ObjectId('6804d79bbace469554c9a96f'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 27.825817},
#  {'_id': ObjectId('6804d79bbace469554c9a970'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 27.770302},
#  {'_id': ObjectId('6804d79bbace469554c9a971'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 30.351582},
#  {'_id': ObjectId('6804d79bbace469554c9a972'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 31.423769},
#  {'_id': ObjectId('6804d79bbace469554c9a973'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 32.36392},
#  {'_id': ObjectId('6804d79bbace469554c9a974'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 28.551182},
#  {'_id': ObjectId('6804d79bbace469554c9a975'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 21.783056},
#  {'_id': ObjectId('6804d79bbace469554c9a976'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 18.957916},
#  {'_id': ObjectId('6804d79bbace469554c9a977'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 24.08466},
#  {'_id': ObjectId('6804d79bbace469554c9a978'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 28.355387},
#  {'_id': ObjectId('6804d79bbace469554c9a979'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 27.529266},
#  {'_id': ObjectId('6804d79bbace469554c9a97a'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 25.954521},
#  {'_id': ObjectId('6804d79bbace469554c9a97b'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 26.028479},
#  {'_id': ObjectId('6804d79bbace469554c9a97c'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 22.5519},
#  {'_id': ObjectId('6804d79bbace469554c9a97d'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 21.909548},
#  {'_id': ObjectId('6804d79bbace469554c9a97e'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 18.059258},
#  {'_id': ObjectId('6804d79bbace469554c9a97f'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 15.275814},
#  {'_id': ObjectId('6804d79bbace469554c9a980'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 19.783125},
#  {'_id': ObjectId('6804d79bbace469554c9a981'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 22.047363},
#  {'_id': ObjectId('6804d79bbace469554c9a982'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 22.87545},
#  {'_id': ObjectId('6804d79bbace469554c9a983'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 22.010805},
#  {'_id': ObjectId('6804d79bbace469554c9a984'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 19.43779},
#  {'_id': ObjectId('6804d79bbace469554c9a985'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 22.099463},
#  {'_id': ObjectId('6804d79bbace469554c9a986'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 22.957874},
#  {'_id': ObjectId('6804d79bbace469554c9a987'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 19.440195},
#  {'_id': ObjectId('6804d79bbace469554c9a988'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 21.59478},
#  {'_id': ObjectId('6804d79bbace469554c9a989'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 22.96064},
#  {'_id': ObjectId('6804d79bbace469554c9a98a'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 19.835663},
#  {'_id': ObjectId('6804d79bbace469554c9a98b'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 18.481121},
#  {'_id': ObjectId('6804d79bbace469554c9a98c'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 18.747072},
#  {'_id': ObjectId('6804d79bbace469554c9a98d'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 18.79665},
#  ...]

# %%
renewable_energy_df = pd.DataFrame(renewable_list_cursor)

# %%
renewable_energy_df
# Out:
#                            _id  Entity      Code  Year  \
# 0     6804d79bbace469554c9a5a6  Africa       NaN  1965
# 1     6804d79bbace469554c9a5a7  Africa       NaN  1966
# 2     6804d79bbace469554c9a5a8  Africa       NaN  1967
# 3     6804d79bbace469554c9a5a9  Africa       NaN  1968
# 4     6804d79bbace469554c9a5aa  Africa       NaN  1969
# ...                        ...     ...       ...   ...
# 4898  6804d79bbace469554c9b8c8   World  OWID_WRL  2019
# 4899  6804d79bbace469554c9b8c9   World  OWID_WRL  2020
# 4900  6804d79bbace469554c9b8ca   World  OWID_WRL  2021
# 4901  6804d79bbace469554c9b8cb   World  OWID_WRL  2022
# 4902  6804d79bbace469554c9b8cc   World  OWID_WRL  2023
#
#       Renewables (% equivalent primary energy)
# 0                                     5.740281
# 1                                     6.113969
# 2                                     6.316580
# 3                                     6.994845
# 4                                     7.943916
# ...                                        ...
# 4898                                 12.228147
# 4899                                 13.404395
# 4900                                 13.469198
# 4901                                 14.119935
# 4902                                 14.562141
#
# [4903 rows x 5 columns]

# %%
renewable_energy_df.drop(columns=["Code"], inplace=True, axis=1)

# %%
renewable_energy_df.drop(columns=["_id"], inplace=True, axis=1)

# %%
renewable_energy_df.rename(columns={"Entity": "Area"}, inplace=True)

# %%
renewable_energy_df.rename(columns={'Renewables (% equivalent primary energy)': 'Renewable_Energy_Share'}, inplace=True)

# %%
renewable_energy_df.head()
# Out:
#      Area  Year  Renewable_Energy_Share
# 0  Africa  1965                5.740281
# 1  Africa  1966                6.113969
# 2  Africa  1967                6.316580
# 3  Africa  1968                6.994845
# 4  Africa  1969                7.943916

# %%
pgconn=psycopg2.connect(host="localhost", database="co2_renew_life", user="postgres", password="4395")

# %%
pgcursor=pgconn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute("CREATE TABLE IF NOT EXISTS renewable_energy (Area TEXT, Year INT, Renewable_Energy_Share FLOAT);")

# %%
from psycopg2.extras import execute_values

execute_values(pgcursor, "INSERT INTO renewable_energy (Area, Year, Renewable_Energy_Share) VALUES %s", renewable_energy_df.values.tolist())

# %%
pgconn.commit()

# %%
def check_mongodb_collection(client, db_name, collection_name):
    try:
        db = client[db_name]
        print(f"Connected to database: {db_name}")
        collections = db.list_collection_names()
        print(f"Collections in {db_name}: {collections}")
        
        if collection_name not in collections:
            print(f"Collection '{collection_name}' does not exist in {db_name}")
            return False
        
        collection = db[collection_name]
        doc_count = collection.count_documents({})
        print(f"Number of documents in {collection_name}: {doc_count}")
        
        if doc_count == 0:
            print(f"Collection '{collection_name}' is empty")
            return False
        
        sample_doc = collection.find_one()
        print(f"Sample document from {collection_name}: {sample_doc}")
        return True
    except Exception as e:
        print(f"Error accessing {db_name}/{collection_name}: {e}")
        return False


print("--- Processing Carbon Emissions Data ---")

try:
    client = pymongo.MongoClient("mongodb://localhost:27017/")
    print("MongoDB connection successful")
    print("Available databases:", client.list_database_names())
except Exception as e:
    print(f"Failed to connect to MongoDB: {e}")
    client = None

if client:
    if check_mongodb_collection(client, "co2_renew_life_db", "carbon_emissions"):
        db = client["co2_renew_life_db"]
        emissions_collection = db["carbon_emissions"]

        emissions_all_records = emissions_collection.find()
        emissions_list_cursor = list(emissions_all_records)
        print(f"Retrieved {len(emissions_list_cursor)} records from carbon_emissions")

        emissions_df = pd.DataFrame(emissions_list_cursor)

        if emissions_df.empty:
            print("Emissions DataFrame is empty")
        else:
            print("Emissions DataFrame shape:", emissions_df.shape)
            print("Emissions DataFrame columns:", emissions_df.columns)
            print("Emissions DataFrame missing values:\n", emissions_df.isnull().sum())
            print("Emissions DataFrame head:\n", emissions_df.head())

            if '_id' in emissions_df.columns:
                emissions_df.drop(columns=["_id"], inplace=True)
            if 'Code' in emissions_df.columns:
                emissions_df.drop(columns=["Code"], inplace=True)

            emissions_df.rename(columns={
                "Entity": "Area",
                "Year": "Year",
                "Annual CO₂ emissions (per capita)": "CO2_Emissions_Per_Capita"
            }, inplace=True)

            print("Cleaned Emissions DataFrame head:\n", emissions_df.head())
    else:
        print("Skipping emissions data processing due to empty or missing collection")
else:
    print("Skipping emissions data processing due to connection failure")
# Out:
# --- Processing Carbon Emissions Data ---
# MongoDB connection successful
# Available databases: ['admin', 'co2_renew_life_db', 'config', 'local']
# Connected to database: co2_renew_life_db
# Collections in co2_renew_life_db: ['life_expectancy', 'carbon_emissions', 'renewable_energy']
# Number of documents in carbon_emissions: 26182
# Sample document from carbon_emissions: {'_id': ObjectId('6804d79bbace469554c93f60'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': 1949, 'Annual CO₂ emissions (per capita)': 0.0019921463}
# Retrieved 26182 records from carbon_emissions
# Emissions DataFrame shape: (26182, 5)
# Emissions DataFrame columns: Index(['_id', 'Entity', 'Code', 'Year', 'Annual CO₂ emissions (per capita)'], dtype='object')
# Emissions DataFrame missing values:
#  _id                                     0
# Entity                                  0
# Code                                 3287
# Year                                    0
# Annual CO₂ emissions (per capita)       0
# dtype: int64
# Emissions DataFrame head:
#                          _id       Entity Code  Year  \
# 0  6804d79bbace469554c93f60  Afghanistan  AFG  1949
# 1  6804d79bbace469554c93f61  Afghanistan  AFG  1950
# 2  6804d79bbace469554c93f62  Afghanistan  AFG  1951
# 3  6804d79bbace469554c93f63  Afghanistan  AFG  1952
# 4  6804d79bbace469554c93f64  Afghanistan  AFG  1953
#
#    Annual CO₂ emissions (per capita)
# 0                           0.001992
# 1                           0.010837
# 2                           0.011625
# 3                           0.011468
# 4                           0.013123
# Cleaned Emissions DataFrame head:
#            Area  Year  CO2_Emissions_Per_Capita
# 0  Afghanistan  1949                  0.001992
# 1  Afghanistan  1950                  0.010837
# 2  Afghanistan  1951                  0.011625
# 3  Afghanistan  1952                  0.011468
# 4  Afghanistan  1953                  0.013123

# %%
emissions_df.head()
# Out:
#           Area  Year  CO2_Emissions_Per_Capita
# 0  Afghanistan  1949                  0.001992
# 1  Afghanistan  1950                  0.010837
# 2  Afghanistan  1951                  0.011625
# 3  Afghanistan  1952                  0.011468
# 4  Afghanistan  1953                  0.013123

# %%
pgconn=psycopg2.connect(host="localhost", database="co2_renew_life", user="postgres", password="4395")

# %%
pgcursor=pgconn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute("CREATE TABLE IF NOT EXISTS carbon_emissions (Area TEXT, Year INT, CO2_Emissions_Per_Capita FLOAT);")

# %%
from psycopg2.extras import execute_values

execute_values(pgcursor, "INSERT INTO carbon_emissions (Area, Year, CO2_Emissions_Per_Capita) VALUES %s", emissions_df.values.tolist())

# %%
pgconn.commit()

# %%
if client:
    if check_mongodb_collection(client, "co2_renew_life_db", "life_expectancy"):
        db = client["co2_renew_life_db"]
        life_expectancy_collection = db["life_expectancy"]

        life_expectancy_all_records = life_expectancy_collection.find()
        life_expectancy_list_cursor = list(life_expectancy_all_records)
        print(f"Retrieved {len(life_expectancy_list_cursor)} records from life_expectancy")

        life_expectancy_df = pd.DataFrame(life_expectancy_list_cursor)

        if life_expectancy_df.empty:
            print("Life Expectancy DataFrame is empty")
        else:
            print("Life Expectancy DataFrame shape:", life_expectancy_df.shape)
            print("Life Expectancy DataFrame columns:", life_expectancy_df.columns)
            print("Life Expectancy DataFrame missing values:\n", life_expectancy_df.isnull().sum())
            print("Life Expectancy DataFrame head:\n", life_expectancy_df.head())

            if '_id' in life_expectancy_df.columns:
                life_expectancy_df.drop(columns=["_id"], inplace=True)
            if 'Code' in life_expectancy_df.columns:
                life_expectancy_df.drop(columns=["Code"], inplace=True)

            life_expectancy_df.rename(columns={
                "Entity": "Area",
                "Year": "Year",
                "Period life expectancy at birth - Sex: total - Age: 0": "Life_Expectancy"
            }, inplace=True)

            print("Cleaned Life Expectancy DataFrame head:\n", life_expectancy_df.head())
    else:
        print("Skipping life expectancy data processing due to empty or missing collection")
else:
    print("Skipping life expectancy data processing due to connection failure")
# Out:
# Connected to database: co2_renew_life_db
# Collections in co2_renew_life_db: ['life_expectancy', 'carbon_emissions', 'renewable_energy']
# Number of documents in life_expectancy: 21565
# Sample document from life_expectancy: {'_id': ObjectId('6804d79cbace469554c9b8cd'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': 1950, 'Period life expectancy at birth - Sex: total - Age: 0': 28.1563}
# Retrieved 21565 records from life_expectancy
# Life Expectancy DataFrame shape: (21565, 5)
# Life Expectancy DataFrame columns: Index(['_id', 'Entity', 'Code', 'Year',
#        'Period life expectancy at birth - Sex: total - Age: 0'],
#       dtype='object')
# Life Expectancy DataFrame missing values:
#  _id                                                         0
# Entity                                                      0
# Code                                                     1956
# Year                                                        0
# Period life expectancy at birth - Sex: total - Age: 0       0
# dtype: int64
# Life Expectancy DataFrame head:
#                          _id       Entity Code  Year  \
# 0  6804d79cbace469554c9b8cd  Afghanistan  AFG  1950
# 1  6804d79cbace469554c9b8ce  Afghanistan  AFG  1951
# 2  6804d79cbace469554c9b8cf  Afghanistan  AFG  1952
# 3  6804d79cbace469554c9b8d0  Afghanistan  AFG  1953
# 4  6804d79cbace469554c9b8d1  Afghanistan  AFG  1954
#
#    Period life expectancy at birth - Sex: total - Age: 0
# 0                                            28.1563
# 1                                            28.5836
# 2                                            29.0138
# 3                                            29.4521
# 4                                            29.6975
# Cleaned Life Expectancy DataFrame head:
#            Area  Year  Life_Expectancy
# 0  Afghanistan  1950          28.1563
# 1  Afghanistan  1951          28.5836
# 2  Afghanistan  1952          29.0138
# 3  Afghanistan  1953          29.4521
# 4  Afghanistan  1954          29.6975

# %%
life_expectancy_df.head()
# Out:
#           Area  Year  Life_Expectancy
# 0  Afghanistan  1950          28.1563
# 1  Afghanistan  1951          28.5836
# 2  Afghanistan  1952          29.0138
# 3  Afghanistan  1953          29.4521
# 4  Afghanistan  1954          29.6975

# %%
pgconn=psycopg2.connect(host="localhost", database="co2_renew_life", user="postgres", password="4395")

# %%
pgcursor=pgconn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute("CREATE TABLE IF NOT EXISTS life_expectancy (Area TEXT, Year INT, Life_Expectancy FLOAT);")

# %%
from psycopg2.extras import execute_values

execute_values(pgcursor, "INSERT INTO life_expectancy (Area, Year, Life_Expectancy) VALUES %s", life_expectancy_df.values.tolist())

# %%
pgconn.commit()
