# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import pymongo

# %% [markdown]
# ### Fetching Renewable Energy Data from MongoDB and Transformation

# %%
renewable_client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
renewable_db = renewable_client["co2_renew_life_db"]

# %%
print(renewable_db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'co2_renew_life_db')

# %%
renewable_collection = renewable_db["renewable_energy"]

# %%
renewable_all_records = renewable_collection.find()

# %%
print(renewable_all_records)
# Out:
# <pymongo.synchronous.cursor.Cursor object at 0x000001DC0FDDDF90>

# %%
for record in renewable_all_records:
    print(record)
# Out:
# {'_id': ObjectId('6802833438c21fda61b61c27'), 'Entity': 'Africa', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 5.7402806}
# {'_id': ObjectId('6802833438c21fda61b61c28'), 'Entity': 'Africa', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 6.1139693}
# {'_id': ObjectId('6802833438c21fda61b61c29'), 'Entity': 'Africa', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.31658}
# {'_id': ObjectId('6802833438c21fda61b61c2a'), 'Entity': 'Africa', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.994845}
# {'_id': ObjectId('6802833438c21fda61b61c2b'), 'Entity': 'Africa', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 7.9439163}
# {'_id': ObjectId('6802833438c21fda61b61c2c'), 'Entity': 'Africa', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 9.148895}
# {'_id': ObjectId('6802833438c21fda61b61c2d'), 'Entity': 'Africa', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 8.124994}
# {'_id': ObjectId('6802833438c21fda61b61c2e'), 'Entity': 'Africa', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 8.747272}
# {'_id': ObjectId('6802833438c21fda61b61c2f'), 'Entity': 'Africa', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 8.54162}
# {'_id': ObjectId('6802833438c21fda61b61c30'), 'Entity': 'Africa', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 9.252387}
# {'_id': ObjectId('6802833438c21fda61b61c31'), 'Entity': 'Africa', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 9.228769}
# {'_id': ObjectId('6802833438c21fda61b61c32'), 'Entity': 'Africa', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 9.41638}
# {'_id': ObjectId('6802833438c21fda61b61c33'), 'Entity': 'Africa', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 9.803094}
# {'_id': ObjectId('6802833438c21fda61b61c34'), 'Entity': 'Africa', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 9.518462}
# {'_id': ObjectId('6802833438c21fda61b61c35'), 'Entity': 'Africa', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 9.349527}
# {'_id': ObjectId('6802833438c21fda61b61c36'), 'Entity': 'Africa', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 8.481442}
# {'_id': ObjectId('6802833438c21fda61b61c37'), 'Entity': 'Africa', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 7.8527517}
# {'_id': ObjectId('6802833438c21fda61b61c38'), 'Entity': 'Africa', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 7.3734274}
# {'_id': ObjectId('6802833438c21fda61b61c39'), 'Entity': 'Africa', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 6.456112}
# {'_id': ObjectId('6802833438c21fda61b61c3a'), 'Entity': 'Africa', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 6.1585774}
# {'_id': ObjectId('6802833438c21fda61b61c3b'), 'Entity': 'Africa', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 6.5793424}
# {'_id': ObjectId('6802833438c21fda61b61c3c'), 'Entity': 'Africa', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 6.7159667}
# {'_id': ObjectId('6802833438c21fda61b61c3d'), 'Entity': 'Africa', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 6.243963}
# {'_id': ObjectId('6802833438c21fda61b61c3e'), 'Entity': 'Africa', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 6.3621163}
# {'_id': ObjectId('6802833438c21fda61b61c3f'), 'Entity': 'Africa', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 6.66546}
# {'_id': ObjectId('6802833438c21fda61b61c40'), 'Entity': 'Africa', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 6.5857716}
# {'_id': ObjectId('6802833438c21fda61b61c41'), 'Entity': 'Africa', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 6.9810143}
# {'_id': ObjectId('6802833438c21fda61b61c42'), 'Entity': 'Africa', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 6.5694675}
# {'_id': ObjectId('6802833438c21fda61b61c43'), 'Entity': 'Africa', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 6.43179}
# {'_id': ObjectId('6802833438c21fda61b61c44'), 'Entity': 'Africa', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 6.3092456}
# {'_id': ObjectId('6802833438c21fda61b61c45'), 'Entity': 'Africa', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 6.306244}
# {'_id': ObjectId('6802833438c21fda61b61c46'), 'Entity': 'Africa', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 6.4332542}
# {'_id': ObjectId('6802833438c21fda61b61c47'), 'Entity': 'Africa', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 6.465725}
# {'_id': ObjectId('6802833438c21fda61b61c48'), 'Entity': 'Africa', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 6.676159}
# {'_id': ObjectId('6802833438c21fda61b61c49'), 'Entity': 'Africa', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 6.858631}
# {'_id': ObjectId('6802833438c21fda61b61c4a'), 'Entity': 'Africa', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 7.2029395}
# {'_id': ObjectId('6802833438c21fda61b61c4b'), 'Entity': 'Africa', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 7.4362373}
# {'_id': ObjectId('6802833438c21fda61b61c4c'), 'Entity': 'Africa', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 7.671944}
# {'_id': ObjectId('6802833438c21fda61b61c4d'), 'Entity': 'Africa', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 7.105203}
# {'_id': ObjectId('6802833438c21fda61b61c4e'), 'Entity': 'Africa', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 6.980063}
# {'_id': ObjectId('6802833438c21fda61b61c4f'), 'Entity': 'Africa', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 7.0285006}
# {'_id': ObjectId('6802833438c21fda61b61c50'), 'Entity': 'Africa', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 7.1611776}
# {'_id': ObjectId('6802833438c21fda61b61c51'), 'Entity': 'Africa', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 7.0572457}
# {'_id': ObjectId('6802833438c21fda61b61c52'), 'Entity': 'Africa', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 6.761787}
# {'_id': ObjectId('6802833438c21fda61b61c53'), 'Entity': 'Africa', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 6.810709}
# {'_id': ObjectId('6802833438c21fda61b61c54'), 'Entity': 'Africa', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 7.1290402}
# {'_id': ObjectId('6802833438c21fda61b61c55'), 'Entity': 'Africa', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 7.2594023}
# {'_id': ObjectId('6802833438c21fda61b61c56'), 'Entity': 'Africa', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 6.9972486}
# {'_id': ObjectId('6802833438c21fda61b61c57'), 'Entity': 'Africa', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 7.189637}
# {'_id': ObjectId('6802833438c21fda61b61c58'), 'Entity': 'Africa', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 7.5156765}
# {'_id': ObjectId('6802833438c21fda61b61c59'), 'Entity': 'Africa', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.527505}
# {'_id': ObjectId('6802833438c21fda61b61c5a'), 'Entity': 'Africa', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 7.404274}
# {'_id': ObjectId('6802833438c21fda61b61c5b'), 'Entity': 'Africa', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 7.6419463}
# {'_id': ObjectId('6802833438c21fda61b61c5c'), 'Entity': 'Africa', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 8.005552}
# {'_id': ObjectId('6802833438c21fda61b61c5d'), 'Entity': 'Africa', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 8.356321}
# {'_id': ObjectId('6802833438c21fda61b61c5e'), 'Entity': 'Africa', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 9.415897}
# {'_id': ObjectId('6802833438c21fda61b61c5f'), 'Entity': 'Africa', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 9.152215}
# {'_id': ObjectId('6802833438c21fda61b61c60'), 'Entity': 'Africa', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 9.298186}
# {'_id': ObjectId('6802833438c21fda61b61c61'), 'Entity': 'Africa', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 9.826173}
# {'_id': ObjectId('6802833438c21fda61b61c62'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 5.7402806}
# {'_id': ObjectId('6802833438c21fda61b61c63'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 6.113969}
# {'_id': ObjectId('6802833438c21fda61b61c64'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.31658}
# {'_id': ObjectId('6802833438c21fda61b61c65'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.994845}
# {'_id': ObjectId('6802833438c21fda61b61c66'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 7.9439154}
# {'_id': ObjectId('6802833438c21fda61b61c67'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 9.148896}
# {'_id': ObjectId('6802833438c21fda61b61c68'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 8.124996}
# {'_id': ObjectId('6802833438c21fda61b61c69'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 8.7472725}
# {'_id': ObjectId('6802833438c21fda61b61c6a'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 8.54162}
# {'_id': ObjectId('6802833438c21fda61b61c6b'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 9.252388}
# {'_id': ObjectId('6802833438c21fda61b61c6c'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 9.228768}
# {'_id': ObjectId('6802833438c21fda61b61c6d'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 9.416379}
# {'_id': ObjectId('6802833438c21fda61b61c6e'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 9.803097}
# {'_id': ObjectId('6802833438c21fda61b61c6f'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 9.518462}
# {'_id': ObjectId('6802833438c21fda61b61c70'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 9.349527}
# {'_id': ObjectId('6802833438c21fda61b61c71'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 8.481442}
# {'_id': ObjectId('6802833438c21fda61b61c72'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 7.8527517}
# {'_id': ObjectId('6802833438c21fda61b61c73'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 7.3734274}
# {'_id': ObjectId('6802833438c21fda61b61c74'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 6.456112}
# {'_id': ObjectId('6802833438c21fda61b61c75'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 6.1585774}
# {'_id': ObjectId('6802833438c21fda61b61c76'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 6.5793424}
# {'_id': ObjectId('6802833438c21fda61b61c77'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 6.7159667}
# {'_id': ObjectId('6802833438c21fda61b61c78'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 6.243963}
# {'_id': ObjectId('6802833438c21fda61b61c79'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 6.3621163}
# {'_id': ObjectId('6802833438c21fda61b61c7a'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 6.6654606}
# {'_id': ObjectId('6802833438c21fda61b61c7b'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 6.5857716}
# {'_id': ObjectId('6802833438c21fda61b61c7c'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 6.9810143}
# {'_id': ObjectId('6802833438c21fda61b61c7d'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 6.5694675}
# {'_id': ObjectId('6802833438c21fda61b61c7e'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 6.43179}
# {'_id': ObjectId('6802833438c21fda61b61c7f'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 6.3092456}
# {'_id': ObjectId('6802833438c21fda61b61c80'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 6.306244}
# {'_id': ObjectId('6802833438c21fda61b61c81'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 6.433255}
# {'_id': ObjectId('6802833438c21fda61b61c82'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 6.465725}
# {'_id': ObjectId('6802833438c21fda61b61c83'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 6.6761603}
# {'_id': ObjectId('6802833438c21fda61b61c84'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 6.8586307}
# {'_id': ObjectId('6802833438c21fda61b61c85'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 7.2029395}
# {'_id': ObjectId('6802833438c21fda61b61c86'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 7.436237}
# {'_id': ObjectId('6802833438c21fda61b61c87'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 7.671944}
# {'_id': ObjectId('6802833438c21fda61b61c88'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 7.105202}
# {'_id': ObjectId('6802833438c21fda61b61c89'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 6.980063}
# {'_id': ObjectId('6802833438c21fda61b61c8a'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 7.0285006}
# {'_id': ObjectId('6802833438c21fda61b61c8b'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 7.161177}
# {'_id': ObjectId('6802833438c21fda61b61c8c'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 7.0572457}
# {'_id': ObjectId('6802833438c21fda61b61c8d'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 6.761787}
# {'_id': ObjectId('6802833438c21fda61b61c8e'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 6.8107085}
# {'_id': ObjectId('6802833438c21fda61b61c8f'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 7.12904}
# {'_id': ObjectId('6802833438c21fda61b61c90'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 7.2594023}
# {'_id': ObjectId('6802833438c21fda61b61c91'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 6.9972486}
# {'_id': ObjectId('6802833438c21fda61b61c92'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 7.189637}
# {'_id': ObjectId('6802833438c21fda61b61c93'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 7.5156765}
# {'_id': ObjectId('6802833438c21fda61b61c94'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.527505}
# {'_id': ObjectId('6802833438c21fda61b61c95'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 7.404273}
# {'_id': ObjectId('6802833438c21fda61b61c96'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 7.6419473}
# {'_id': ObjectId('6802833438c21fda61b61c97'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 8.005553}
# {'_id': ObjectId('6802833438c21fda61b61c98'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 8.356321}
# {'_id': ObjectId('6802833438c21fda61b61c99'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 9.415897}
# {'_id': ObjectId('6802833438c21fda61b61c9a'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 9.152214}
# {'_id': ObjectId('6802833438c21fda61b61c9b'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 9.298185}
# {'_id': ObjectId('6802833438c21fda61b61c9c'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 9.826172}
# {'_id': ObjectId('6802833438c21fda61b61c9d'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1965, 'Renewables (% equivalent primary energy)': 4.7630677}
# {'_id': ObjectId('6802833438c21fda61b61c9e'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1966, 'Renewables (% equivalent primary energy)': 3.518747}
# {'_id': ObjectId('6802833438c21fda61b61c9f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1967, 'Renewables (% equivalent primary energy)': 4.291954}
# {'_id': ObjectId('6802833438c21fda61b61ca0'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1968, 'Renewables (% equivalent primary energy)': 5.4861946}
# {'_id': ObjectId('6802833438c21fda61b61ca1'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1969, 'Renewables (% equivalent primary energy)': 3.1827633}
# {'_id': ObjectId('6802833438c21fda61b61ca2'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1970, 'Renewables (% equivalent primary energy)': 4.6656837}
# {'_id': ObjectId('6802833438c21fda61b61ca3'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1971, 'Renewables (% equivalent primary energy)': 2.4559188}
# {'_id': ObjectId('6802833438c21fda61b61ca4'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1972, 'Renewables (% equivalent primary energy)': 3.278343}
# {'_id': ObjectId('6802833438c21fda61b61ca5'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1973, 'Renewables (% equivalent primary energy)': 4.175826}
# {'_id': ObjectId('6802833438c21fda61b61ca6'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1974, 'Renewables (% equivalent primary energy)': 2.494738}
# {'_id': ObjectId('6802833438c21fda61b61ca7'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1975, 'Renewables (% equivalent primary energy)': 1.3782818}
# {'_id': ObjectId('6802833438c21fda61b61ca8'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1976, 'Renewables (% equivalent primary energy)': 1.4010222}
# {'_id': ObjectId('6802833438c21fda61b61ca9'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1977, 'Renewables (% equivalent primary energy)': 0.8817282}
# {'_id': ObjectId('6802833438c21fda61b61caa'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1978, 'Renewables (% equivalent primary energy)': 0.6521151}
# {'_id': ObjectId('6802833438c21fda61b61cab'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1979, 'Renewables (% equivalent primary energy)': 0.5792936}
# {'_id': ObjectId('6802833438c21fda61b61cac'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1980, 'Renewables (% equivalent primary energy)': 0.4290016}
# {'_id': ObjectId('6802833438c21fda61b61cad'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1981, 'Renewables (% equivalent primary energy)': 0.50294036}
# {'_id': ObjectId('6802833438c21fda61b61cae'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1982, 'Renewables (% equivalent primary energy)': 0.5708701}
# {'_id': ObjectId('6802833438c21fda61b61caf'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1983, 'Renewables (% equivalent primary energy)': 0.25644946}
# {'_id': ObjectId('6802833438c21fda61b61cb0'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1984, 'Renewables (% equivalent primary energy)': 0.5136736}
# {'_id': ObjectId('6802833438c21fda61b61cb1'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1985, 'Renewables (% equivalent primary energy)': 0.72826535}
# {'_id': ObjectId('6802833438c21fda61b61cb2'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1986, 'Renewables (% equivalent primary energy)': 0.2664045}
# {'_id': ObjectId('6802833438c21fda61b61cb3'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1987, 'Renewables (% equivalent primary energy)': 0.5174274}
# {'_id': ObjectId('6802833438c21fda61b61cb4'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1988, 'Renewables (% equivalent primary energy)': 0.17717436}
# {'_id': ObjectId('6802833438c21fda61b61cb5'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1989, 'Renewables (% equivalent primary energy)': 0.2249582}
# {'_id': ObjectId('6802833438c21fda61b61cb6'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1990, 'Renewables (% equivalent primary energy)': 0.1267387}
# {'_id': ObjectId('6802833438c21fda61b61cb7'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1991, 'Renewables (% equivalent primary energy)': 0.277607}
# {'_id': ObjectId('6802833438c21fda61b61cb8'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1992, 'Renewables (% equivalent primary energy)': 0.18375748}
# {'_id': ObjectId('6802833438c21fda61b61cb9'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1993, 'Renewables (% equivalent primary energy)': 0.35028014}
# {'_id': ObjectId('6802833438c21fda61b61cba'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1994, 'Renewables (% equivalent primary energy)': 0.16257899}
# {'_id': ObjectId('6802833438c21fda61b61cbb'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1995, 'Renewables (% equivalent primary energy)': 0.18224756}
# {'_id': ObjectId('6802833438c21fda61b61cbc'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1996, 'Renewables (% equivalent primary energy)': 0.1288034}
# {'_id': ObjectId('6802833438c21fda61b61cbd'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1997, 'Renewables (% equivalent primary energy)': 0.074455895}
# {'_id': ObjectId('6802833438c21fda61b61cbe'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1998, 'Renewables (% equivalent primary energy)': 0.20617963}
# {'_id': ObjectId('6802833438c21fda61b61cbf'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1999, 'Renewables (% equivalent primary energy)': 0.1927434}
# {'_id': ObjectId('6802833438c21fda61b61cc0'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2000, 'Renewables (% equivalent primary energy)': 0.053235486}
# {'_id': ObjectId('6802833438c21fda61b61cc1'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2001, 'Renewables (% equivalent primary energy)': 0.065218486}
# {'_id': ObjectId('6802833438c21fda61b61cc2'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2002, 'Renewables (% equivalent primary energy)': 0.05167676}
# {'_id': ObjectId('6802833438c21fda61b61cc3'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2003, 'Renewables (% equivalent primary energy)': 0.228104}
# {'_id': ObjectId('6802833438c21fda61b61cc4'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2004, 'Renewables (% equivalent primary energy)': 0.2067869}
# {'_id': ObjectId('6802833438c21fda61b61cc5'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2005, 'Renewables (% equivalent primary energy)': 0.43411884}
# {'_id': ObjectId('6802833438c21fda61b61cc6'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2006, 'Renewables (% equivalent primary energy)': 0.16327195}
# {'_id': ObjectId('6802833438c21fda61b61cc7'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2007, 'Renewables (% equivalent primary energy)': 0.15990457}
# {'_id': ObjectId('6802833438c21fda61b61cc8'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2008, 'Renewables (% equivalent primary energy)': 0.1877543}
# {'_id': ObjectId('6802833438c21fda61b61cc9'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2009, 'Renewables (% equivalent primary energy)': 0.21278548}
# {'_id': ObjectId('6802833438c21fda61b61cca'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2010, 'Renewables (% equivalent primary energy)': 0.11513415}
# {'_id': ObjectId('6802833438c21fda61b61ccb'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2011, 'Renewables (% equivalent primary energy)': 0.23525994}
# {'_id': ObjectId('6802833438c21fda61b61ccc'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2012, 'Renewables (% equivalent primary energy)': 0.22453195}
# {'_id': ObjectId('6802833438c21fda61b61ccd'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2013, 'Renewables (% equivalent primary energy)': 0.06476319}
# {'_id': ObjectId('6802833438c21fda61b61cce'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2014, 'Renewables (% equivalent primary energy)': 0.11750259}
# {'_id': ObjectId('6802833438c21fda61b61ccf'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2015, 'Renewables (% equivalent primary energy)': 0.09681336}
# {'_id': ObjectId('6802833438c21fda61b61cd0'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2016, 'Renewables (% equivalent primary energy)': 0.14580713}
# {'_id': ObjectId('6802833438c21fda61b61cd1'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2017, 'Renewables (% equivalent primary energy)': 0.24701828}
# {'_id': ObjectId('6802833438c21fda61b61cd2'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2018, 'Renewables (% equivalent primary energy)': 0.28842947}
# {'_id': ObjectId('6802833438c21fda61b61cd3'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2019, 'Renewables (% equivalent primary energy)': 0.29497427}
# {'_id': ObjectId('6802833438c21fda61b61cd4'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2020, 'Renewables (% equivalent primary energy)': 0.30043116}
# {'_id': ObjectId('6802833438c21fda61b61cd5'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2021, 'Renewables (% equivalent primary energy)': 0.25285673}
# {'_id': ObjectId('6802833438c21fda61b61cd6'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2022, 'Renewables (% equivalent primary energy)': 0.24182516}
# {'_id': ObjectId('6802833438c21fda61b61cd7'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2023, 'Renewables (% equivalent primary energy)': 0.27036947}
# {'_id': ObjectId('6802833438c21fda61b61cd8'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1965, 'Renewables (% equivalent primary energy)': 1.1026944}
# {'_id': ObjectId('6802833438c21fda61b61cd9'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1966, 'Renewables (% equivalent primary energy)': 1.0818663}
# {'_id': ObjectId('6802833438c21fda61b61cda'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1967, 'Renewables (% equivalent primary energy)': 1.0765308}
# {'_id': ObjectId('6802833438c21fda61b61cdb'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1968, 'Renewables (% equivalent primary energy)': 1.2272897}
# {'_id': ObjectId('6802833438c21fda61b61cdc'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1969, 'Renewables (% equivalent primary energy)': 1.0651326}
# {'_id': ObjectId('6802833438c21fda61b61cdd'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1970, 'Renewables (% equivalent primary energy)': 1.3533598}
# {'_id': ObjectId('6802833438c21fda61b61cde'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1971, 'Renewables (% equivalent primary energy)': 1.2702763}
# {'_id': ObjectId('6802833438c21fda61b61cdf'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1972, 'Renewables (% equivalent primary energy)': 1.2349532}
# {'_id': ObjectId('6802833438c21fda61b61ce0'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1973, 'Renewables (% equivalent primary energy)': 2.2839267}
# {'_id': ObjectId('6802833438c21fda61b61ce1'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1974, 'Renewables (% equivalent primary energy)': 3.629566}
# {'_id': ObjectId('6802833438c21fda61b61ce2'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1975, 'Renewables (% equivalent primary energy)': 3.8664374}
# {'_id': ObjectId('6802833438c21fda61b61ce3'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1976, 'Renewables (% equivalent primary energy)': 3.5540857}
# {'_id': ObjectId('6802833438c21fda61b61ce4'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1977, 'Renewables (% equivalent primary energy)': 3.9090023}
# {'_id': ObjectId('6802833438c21fda61b61ce5'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1978, 'Renewables (% equivalent primary energy)': 5.227204}
# {'_id': ObjectId('6802833438c21fda61b61ce6'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1979, 'Renewables (% equivalent primary energy)': 6.702873}
# {'_id': ObjectId('6802833438c21fda61b61ce7'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1980, 'Renewables (% equivalent primary energy)': 9.552048}
# {'_id': ObjectId('6802833438c21fda61b61ce8'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1981, 'Renewables (% equivalent primary energy)': 9.542367}
# {'_id': ObjectId('6802833438c21fda61b61ce9'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1982, 'Renewables (% equivalent primary energy)': 11.229478}
# {'_id': ObjectId('6802833438c21fda61b61cea'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1983, 'Renewables (% equivalent primary energy)': 11.313745}
# {'_id': ObjectId('6802833438c21fda61b61ceb'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1984, 'Renewables (% equivalent primary energy)': 12.136334}
# {'_id': ObjectId('6802833438c21fda61b61cec'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1985, 'Renewables (% equivalent primary energy)': 12.759911}
# {'_id': ObjectId('6802833438c21fda61b61ced'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1986, 'Renewables (% equivalent primary energy)': 12.297877}
# {'_id': ObjectId('6802833438c21fda61b61cee'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1987, 'Renewables (% equivalent primary energy)': 12.24687}
# {'_id': ObjectId('6802833438c21fda61b61cef'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1988, 'Renewables (% equivalent primary energy)': 8.416951}
# {'_id': ObjectId('6802833438c21fda61b61cf0'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1989, 'Renewables (% equivalent primary energy)': 7.543206}
# {'_id': ObjectId('6802833438c21fda61b61cf1'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1990, 'Renewables (% equivalent primary energy)': 10.29241}
# {'_id': ObjectId('6802833438c21fda61b61cf2'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1991, 'Renewables (% equivalent primary energy)': 9.080978}
# {'_id': ObjectId('6802833438c21fda61b61cf3'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1992, 'Renewables (% equivalent primary energy)': 10.2065}
# {'_id': ObjectId('6802833438c21fda61b61cf4'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1993, 'Renewables (% equivalent primary energy)': 12.215968}
# {'_id': ObjectId('6802833438c21fda61b61cf5'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1994, 'Renewables (% equivalent primary energy)': 13.306112}
# {'_id': ObjectId('6802833438c21fda61b61cf6'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1995, 'Renewables (% equivalent primary energy)': 12.535252}
# {'_id': ObjectId('6802833438c21fda61b61cf7'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1996, 'Renewables (% equivalent primary energy)': 10.224623}
# {'_id': ObjectId('6802833438c21fda61b61cf8'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1997, 'Renewables (% equivalent primary energy)': 12.513889}
# {'_id': ObjectId('6802833438c21fda61b61cf9'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1998, 'Renewables (% equivalent primary energy)': 11.481932}
# {'_id': ObjectId('6802833438c21fda61b61cfa'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1999, 'Renewables (% equivalent primary energy)': 9.2246065}
# {'_id': ObjectId('6802833438c21fda61b61cfb'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2000, 'Renewables (% equivalent primary energy)': 12.283152}
# {'_id': ObjectId('6802833438c21fda61b61cfc'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2001, 'Renewables (% equivalent primary energy)': 15.93624}
# {'_id': ObjectId('6802833438c21fda61b61cfd'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2002, 'Renewables (% equivalent primary energy)': 16.247978}
# {'_id': ObjectId('6802833438c21fda61b61cfe'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2003, 'Renewables (% equivalent primary energy)': 14.40661}
# {'_id': ObjectId('6802833438c21fda61b61cff'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2004, 'Renewables (% equivalent primary energy)': 12.185576}
# {'_id': ObjectId('6802833438c21fda61b61d00'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2005, 'Renewables (% equivalent primary energy)': 12.790038}
# {'_id': ObjectId('6802833438c21fda61b61d01'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2006, 'Renewables (% equivalent primary energy)': 13.449896}
# {'_id': ObjectId('6802833438c21fda61b61d02'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2007, 'Renewables (% equivalent primary energy)': 10.613073}
# {'_id': ObjectId('6802833438c21fda61b61d03'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2008, 'Renewables (% equivalent primary energy)': 10.447249}
# {'_id': ObjectId('6802833438c21fda61b61d04'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2009, 'Renewables (% equivalent primary energy)': 11.797741}
# {'_id': ObjectId('6802833438c21fda61b61d05'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2010, 'Renewables (% equivalent primary energy)': 11.650168}
# {'_id': ObjectId('6802833438c21fda61b61d06'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2011, 'Renewables (% equivalent primary energy)': 10.914268}
# {'_id': ObjectId('6802833438c21fda61b61d07'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2012, 'Renewables (% equivalent primary energy)': 10.176803}
# {'_id': ObjectId('6802833438c21fda61b61d08'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2013, 'Renewables (% equivalent primary energy)': 10.940409}
# {'_id': ObjectId('6802833438c21fda61b61d09'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2014, 'Renewables (% equivalent primary energy)': 11.038969}
# {'_id': ObjectId('6802833438c21fda61b61d0a'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2015, 'Renewables (% equivalent primary energy)': 10.89336}
# {'_id': ObjectId('6802833438c21fda61b61d0b'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2016, 'Renewables (% equivalent primary energy)': 10.17179}
# {'_id': ObjectId('6802833438c21fda61b61d0c'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2017, 'Renewables (% equivalent primary energy)': 10.979133}
# {'_id': ObjectId('6802833438c21fda61b61d0d'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2018, 'Renewables (% equivalent primary energy)': 11.331651}
# {'_id': ObjectId('6802833438c21fda61b61d0e'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2019, 'Renewables (% equivalent primary energy)': 11.911147}
# {'_id': ObjectId('6802833438c21fda61b61d0f'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2020, 'Renewables (% equivalent primary energy)': 12.310073}
# {'_id': ObjectId('6802833438c21fda61b61d10'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2021, 'Renewables (% equivalent primary energy)': 11.335143}
# {'_id': ObjectId('6802833438c21fda61b61d11'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2022, 'Renewables (% equivalent primary energy)': 12.188763}
# {'_id': ObjectId('6802833438c21fda61b61d12'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2023, 'Renewables (% equivalent primary energy)': 14.102216}
# {'_id': ObjectId('6802833438c21fda61b61d13'), 'Entity': 'Asia', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 7.8735447}
# {'_id': ObjectId('6802833438c21fda61b61d14'), 'Entity': 'Asia', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 7.4938087}
# {'_id': ObjectId('6802833438c21fda61b61d15'), 'Entity': 'Asia', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.7346387}
# {'_id': ObjectId('6802833438c21fda61b61d16'), 'Entity': 'Asia', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.963028}
# {'_id': ObjectId('6802833438c21fda61b61d17'), 'Entity': 'Asia', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 6.3012996}
# {'_id': ObjectId('6802833438c21fda61b61d18'), 'Entity': 'Asia', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 5.661888}
# {'_id': ObjectId('6802833438c21fda61b61d19'), 'Entity': 'Asia', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 5.6825113}
# {'_id': ObjectId('6802833438c21fda61b61d1a'), 'Entity': 'Asia', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 5.4817533}
# {'_id': ObjectId('6802833438c21fda61b61d1b'), 'Entity': 'Asia', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 4.7254024}
# {'_id': ObjectId('6802833438c21fda61b61d1c'), 'Entity': 'Asia', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 5.289435}
# {'_id': ObjectId('6802833438c21fda61b61d1d'), 'Entity': 'Asia', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 5.432976}
# {'_id': ObjectId('6802833438c21fda61b61d1e'), 'Entity': 'Asia', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 5.272847}
# {'_id': ObjectId('6802833438c21fda61b61d1f'), 'Entity': 'Asia', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 4.885452}
# {'_id': ObjectId('6802833438c21fda61b61d20'), 'Entity': 'Asia', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 4.842396}
# {'_id': ObjectId('6802833438c21fda61b61d21'), 'Entity': 'Asia', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 5.0050187}
# {'_id': ObjectId('6802833438c21fda61b61d22'), 'Entity': 'Asia', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 5.387261}
# {'_id': ObjectId('6802833438c21fda61b61d23'), 'Entity': 'Asia', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 5.6962633}
# {'_id': ObjectId('6802833438c21fda61b61d24'), 'Entity': 'Asia', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 5.688111}
# {'_id': ObjectId('6802833438c21fda61b61d25'), 'Entity': 'Asia', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 5.652118}
# {'_id': ObjectId('6802833438c21fda61b61d26'), 'Entity': 'Asia', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 5.339281}
# {'_id': ObjectId('6802833438c21fda61b61d27'), 'Entity': 'Asia', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 5.351906}
# {'_id': ObjectId('6802833438c21fda61b61d28'), 'Entity': 'Asia', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 5.190978}
# {'_id': ObjectId('6802833438c21fda61b61d29'), 'Entity': 'Asia', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 5.0590653}
# {'_id': ObjectId('6802833438c21fda61b61d2a'), 'Entity': 'Asia', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 5.4249687}
# {'_id': ObjectId('6802833438c21fda61b61d2b'), 'Entity': 'Asia', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 5.319675}
# {'_id': ObjectId('6802833438c21fda61b61d2c'), 'Entity': 'Asia', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 5.339282}
# {'_id': ObjectId('6802833438c21fda61b61d2d'), 'Entity': 'Asia', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 5.1891055}
# {'_id': ObjectId('6802833438c21fda61b61d2e'), 'Entity': 'Asia', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 5.0055637}
# {'_id': ObjectId('6802833438c21fda61b61d2f'), 'Entity': 'Asia', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 5.3127103}
# {'_id': ObjectId('6802833438c21fda61b61d30'), 'Entity': 'Asia', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 5.0516157}
# {'_id': ObjectId('6802833438c21fda61b61d31'), 'Entity': 'Asia', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 5.271553}
# {'_id': ObjectId('6802833438c21fda61b61d32'), 'Entity': 'Asia', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 5.018597}
# {'_id': ObjectId('6802833438c21fda61b61d33'), 'Entity': 'Asia', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 4.8939986}
# {'_id': ObjectId('6802833438c21fda61b61d34'), 'Entity': 'Asia', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 5.178817}
# {'_id': ObjectId('6802833438c21fda61b61d35'), 'Entity': 'Asia', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 4.9296236}
# {'_id': ObjectId('6802833438c21fda61b61d36'), 'Entity': 'Asia', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 4.9015436}
# {'_id': ObjectId('6802833438c21fda61b61d37'), 'Entity': 'Asia', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 5.0736527}
# {'_id': ObjectId('6802833438c21fda61b61d38'), 'Entity': 'Asia', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 4.9854317}
# {'_id': ObjectId('6802833438c21fda61b61d39'), 'Entity': 'Asia', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 4.7931614}
# {'_id': ObjectId('6802833438c21fda61b61d3a'), 'Entity': 'Asia', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 5.0985446}
# {'_id': ObjectId('6802833438c21fda61b61d3b'), 'Entity': 'Asia', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 4.9199796}
# {'_id': ObjectId('6802833438c21fda61b61d3c'), 'Entity': 'Asia', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 5.117429}
# {'_id': ObjectId('6802833438c21fda61b61d3d'), 'Entity': 'Asia', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 5.0853057}
# {'_id': ObjectId('6802833438c21fda61b61d3e'), 'Entity': 'Asia', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 5.605236}
# {'_id': ObjectId('6802833438c21fda61b61d3f'), 'Entity': 'Asia', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 5.458485}
# {'_id': ObjectId('6802833438c21fda61b61d40'), 'Entity': 'Asia', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 5.9468226}
# {'_id': ObjectId('6802833438c21fda61b61d41'), 'Entity': 'Asia', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 5.8778787}
# {'_id': ObjectId('6802833438c21fda61b61d42'), 'Entity': 'Asia', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 6.4778247}
# {'_id': ObjectId('6802833438c21fda61b61d43'), 'Entity': 'Asia', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 6.987413}
# {'_id': ObjectId('6802833438c21fda61b61d44'), 'Entity': 'Asia', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 7.551866}
# {'_id': ObjectId('6802833438c21fda61b61d45'), 'Entity': 'Asia', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.908183}
# {'_id': ObjectId('6802833438c21fda61b61d46'), 'Entity': 'Asia', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 8.438702}
# {'_id': ObjectId('6802833438c21fda61b61d47'), 'Entity': 'Asia', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 8.845372}
# {'_id': ObjectId('6802833438c21fda61b61d48'), 'Entity': 'Asia', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 9.349624}
# {'_id': ObjectId('6802833438c21fda61b61d49'), 'Entity': 'Asia', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 10.002659}
# {'_id': ObjectId('6802833438c21fda61b61d4a'), 'Entity': 'Asia', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 10.741154}
# {'_id': ObjectId('6802833438c21fda61b61d4b'), 'Entity': 'Asia', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 11.2254095}
# {'_id': ObjectId('6802833438c21fda61b61d4c'), 'Entity': 'Asia', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 11.969987}
# {'_id': ObjectId('6802833438c21fda61b61d4d'), 'Entity': 'Asia', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 12.191386}
# {'_id': ObjectId('6802833438c21fda61b61d4e'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 8.879346}
# {'_id': ObjectId('6802833438c21fda61b61d4f'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 8.41833}
# {'_id': ObjectId('6802833438c21fda61b61d50'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 7.6206317}
# {'_id': ObjectId('6802833438c21fda61b61d51'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 7.814885}
# {'_id': ObjectId('6802833438c21fda61b61d52'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 7.0542545}
# {'_id': ObjectId('6802833438c21fda61b61d53'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 6.39634}
# {'_id': ObjectId('6802833438c21fda61b61d54'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 6.486787}
# {'_id': ObjectId('6802833438c21fda61b61d55'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 6.238836}
# {'_id': ObjectId('6802833438c21fda61b61d56'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 5.4947343}
# {'_id': ObjectId('6802833438c21fda61b61d57'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 6.09481}
# {'_id': ObjectId('6802833438c21fda61b61d58'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 6.1902494}
# {'_id': ObjectId('6802833438c21fda61b61d59'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 5.912254}
# {'_id': ObjectId('6802833438c21fda61b61d5a'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 5.47068}
# {'_id': ObjectId('6802833438c21fda61b61d5b'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 5.3867373}
# {'_id': ObjectId('6802833438c21fda61b61d5c'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 5.630934}
# {'_id': ObjectId('6802833438c21fda61b61d5d'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 5.9968095}
# {'_id': ObjectId('6802833438c21fda61b61d5e'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 6.3445344}
# {'_id': ObjectId('6802833438c21fda61b61d5f'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 6.3195252}
# {'_id': ObjectId('6802833438c21fda61b61d60'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 6.4025097}
# {'_id': ObjectId('6802833438c21fda61b61d61'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 6.0936494}
# {'_id': ObjectId('6802833438c21fda61b61d62'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 6.1765556}
# {'_id': ObjectId('6802833438c21fda61b61d63'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 6.0954514}
# {'_id': ObjectId('6802833438c21fda61b61d64'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 5.7225227}
# ...
# {'_id': ObjectId('6802833438c21fda61b62ee8'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 12.494397}
# {'_id': ObjectId('6802833438c21fda61b62ee9'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 11.68581}
# {'_id': ObjectId('6802833438c21fda61b62eea'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 7.7634754}
# {'_id': ObjectId('6802833438c21fda61b62eeb'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 7.5681634}
# {'_id': ObjectId('6802833438c21fda61b62eec'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 11.242959}
# {'_id': ObjectId('6802833438c21fda61b62eed'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 13.811244}
# {'_id': ObjectId('6802833438c21fda61b62eee'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 12.9425125}
# {'_id': ObjectId('6802833438c21fda61b62eef'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 13.430492}
# {'_id': ObjectId('6802833438c21fda61b62ef0'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 13.813509}
# {'_id': ObjectId('6802833438c21fda61b62ef1'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 14.452316}
# {'_id': ObjectId('6802833438c21fda61b62ef2'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 15.77723}
# {'_id': ObjectId('6802833438c21fda61b62ef3'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 15.0170355}
# {'_id': ObjectId('6802833438c21fda61b62ef4'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 14.30466}
# {'_id': ObjectId('6802833438c21fda61b62ef5'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 14.307501}
# {'_id': ObjectId('6802833438c21fda61b62ef6'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 14.58253}
# {'_id': ObjectId('6802833438c21fda61b62ef7'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 13.991099}
# {'_id': ObjectId('6802833438c21fda61b62ef8'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 14.335823}
# {'_id': ObjectId('6802833438c21fda61b62ef9'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 11.193091}
# {'_id': ObjectId('6802833438c21fda61b62efa'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 13.094856}
# {'_id': ObjectId('6802833438c21fda61b62efb'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 13.095548}
# {'_id': ObjectId('6802833438c21fda61b62efc'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 12.301518}
# {'_id': ObjectId('6802833438c21fda61b62efd'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 11.809273}
# {'_id': ObjectId('6802833438c21fda61b62efe'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 10.583202}
# {'_id': ObjectId('6802833438c21fda61b62eff'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 11.762157}
# {'_id': ObjectId('6802833438c21fda61b62f00'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 11.003373}
# {'_id': ObjectId('6802833438c21fda61b62f01'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 10.950638}
# {'_id': ObjectId('6802833438c21fda61b62f02'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 9.16278}
# {'_id': ObjectId('6802833438c21fda61b62f03'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 9.841228}
# {'_id': ObjectId('6802833438c21fda61b62f04'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 10.236668}
# {'_id': ObjectId('6802833438c21fda61b62f05'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 10.912234}
# {'_id': ObjectId('6802833438c21fda61b62f06'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 10.084756}
# {'_id': ObjectId('6802833438c21fda61b62f07'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 9.786942}
# {'_id': ObjectId('6802833438c21fda61b62f08'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 9.337499}
# {'_id': ObjectId('6802833438c21fda61b62f09'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 9.446895}
# {'_id': ObjectId('6802833438c21fda61b62f0a'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.3576255}
# {'_id': ObjectId('6802833438c21fda61b62f0b'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 8.244503}
# {'_id': ObjectId('6802833438c21fda61b62f0c'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 7.833715}
# {'_id': ObjectId('6802833438c21fda61b62f0d'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 7.440964}
# {'_id': ObjectId('6802833438c21fda61b62f0e'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 8.164477}
# {'_id': ObjectId('6802833438c21fda61b62f0f'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 8.095408}
# {'_id': ObjectId('6802833438c21fda61b62f10'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 7.4288955}
# {'_id': ObjectId('6802833438c21fda61b62f11'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 7.8159766}
# {'_id': ObjectId('6802833438c21fda61b62f12'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 8.792076}
# {'_id': ObjectId('6802833438c21fda61b62f13'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1965, 'Renewables (% equivalent primary energy)': 6.445519}
# {'_id': ObjectId('6802833438c21fda61b62f14'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1966, 'Renewables (% equivalent primary energy)': 6.516204}
# {'_id': ObjectId('6802833438c21fda61b62f15'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.423987}
# {'_id': ObjectId('6802833438c21fda61b62f16'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.3901453}
# {'_id': ObjectId('6802833438c21fda61b62f17'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1969, 'Renewables (% equivalent primary energy)': 6.32996}
# {'_id': ObjectId('6802833438c21fda61b62f18'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1970, 'Renewables (% equivalent primary energy)': 6.2402315}
# {'_id': ObjectId('6802833438c21fda61b62f19'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1971, 'Renewables (% equivalent primary energy)': 6.2751184}
# {'_id': ObjectId('6802833438c21fda61b62f1a'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1972, 'Renewables (% equivalent primary energy)': 6.231038}
# {'_id': ObjectId('6802833438c21fda61b62f1b'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1973, 'Renewables (% equivalent primary energy)': 5.98148}
# {'_id': ObjectId('6802833438c21fda61b62f1c'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1974, 'Renewables (% equivalent primary energy)': 6.527657}
# {'_id': ObjectId('6802833438c21fda61b62f1d'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1975, 'Renewables (% equivalent primary energy)': 6.5613737}
# {'_id': ObjectId('6802833438c21fda61b62f1e'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1976, 'Renewables (% equivalent primary energy)': 6.2220235}
# {'_id': ObjectId('6802833438c21fda61b62f1f'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1977, 'Renewables (% equivalent primary energy)': 6.216026}
# {'_id': ObjectId('6802833438c21fda61b62f20'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1978, 'Renewables (% equivalent primary energy)': 6.4746337}
# {'_id': ObjectId('6802833438c21fda61b62f21'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1979, 'Renewables (% equivalent primary energy)': 6.5883255}
# {'_id': ObjectId('6802833438c21fda61b62f22'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1980, 'Renewables (% equivalent primary energy)': 6.8036585}
# {'_id': ObjectId('6802833438c21fda61b62f23'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1981, 'Renewables (% equivalent primary energy)': 6.9859357}
# {'_id': ObjectId('6802833438c21fda61b62f24'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1982, 'Renewables (% equivalent primary energy)': 7.1871624}
# {'_id': ObjectId('6802833438c21fda61b62f25'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1983, 'Renewables (% equivalent primary energy)': 7.3960943}
# {'_id': ObjectId('6802833438c21fda61b62f26'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1984, 'Renewables (% equivalent primary energy)': 7.3479614}
# {'_id': ObjectId('6802833438c21fda61b62f27'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1985, 'Renewables (% equivalent primary energy)': 7.309479}
# {'_id': ObjectId('6802833438c21fda61b62f28'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1986, 'Renewables (% equivalent primary energy)': 7.2850266}
# {'_id': ObjectId('6802833438c21fda61b62f29'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1987, 'Renewables (% equivalent primary energy)': 7.1429477}
# {'_id': ObjectId('6802833438c21fda61b62f2a'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1988, 'Renewables (% equivalent primary energy)': 7.10847}
# {'_id': ObjectId('6802833438c21fda61b62f2b'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1989, 'Renewables (% equivalent primary energy)': 6.9876184}
# {'_id': ObjectId('6802833438c21fda61b62f2c'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1990, 'Renewables (% equivalent primary energy)': 7.182692}
# {'_id': ObjectId('6802833438c21fda61b62f2d'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1991, 'Renewables (% equivalent primary energy)': 7.301195}
# {'_id': ObjectId('6802833438c21fda61b62f2e'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1992, 'Renewables (% equivalent primary energy)': 7.2864876}
# {'_id': ObjectId('6802833438c21fda61b62f2f'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1993, 'Renewables (% equivalent primary energy)': 7.6539183}
# {'_id': ObjectId('6802833438c21fda61b62f30'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1994, 'Renewables (% equivalent primary energy)': 7.6321683}
# {'_id': ObjectId('6802833438c21fda61b62f31'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1995, 'Renewables (% equivalent primary energy)': 7.8718243}
# {'_id': ObjectId('6802833438c21fda61b62f32'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1996, 'Renewables (% equivalent primary energy)': 7.755703}
# {'_id': ObjectId('6802833438c21fda61b62f33'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1997, 'Renewables (% equivalent primary energy)': 7.847491}
# {'_id': ObjectId('6802833438c21fda61b62f34'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1998, 'Renewables (% equivalent primary energy)': 7.890869}
# {'_id': ObjectId('6802833438c21fda61b62f35'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1999, 'Renewables (% equivalent primary energy)': 7.8530593}
# {'_id': ObjectId('6802833438c21fda61b62f36'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2000, 'Renewables (% equivalent primary energy)': 7.8158455}
# {'_id': ObjectId('6802833438c21fda61b62f37'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2001, 'Renewables (% equivalent primary energy)': 7.552836}
# {'_id': ObjectId('6802833438c21fda61b62f38'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2002, 'Renewables (% equivalent primary energy)': 7.5668545}
# {'_id': ObjectId('6802833438c21fda61b62f39'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2003, 'Renewables (% equivalent primary energy)': 7.3342075}
# {'_id': ObjectId('6802833438c21fda61b62f3a'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2004, 'Renewables (% equivalent primary energy)': 7.518}
# {'_id': ObjectId('6802833438c21fda61b62f3b'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2005, 'Renewables (% equivalent primary energy)': 7.5638204}
# {'_id': ObjectId('6802833438c21fda61b62f3c'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2006, 'Renewables (% equivalent primary energy)': 7.705343}
# {'_id': ObjectId('6802833438c21fda61b62f3d'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2007, 'Renewables (% equivalent primary energy)': 7.7473364}
# {'_id': ObjectId('6802833438c21fda61b62f3e'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2008, 'Renewables (% equivalent primary energy)': 8.245706}
# {'_id': ObjectId('6802833438c21fda61b62f3f'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2009, 'Renewables (% equivalent primary energy)': 8.564856}
# {'_id': ObjectId('6802833438c21fda61b62f40'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2010, 'Renewables (% equivalent primary energy)': 8.797048}
# {'_id': ObjectId('6802833438c21fda61b62f41'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2011, 'Renewables (% equivalent primary energy)': 8.980997}
# {'_id': ObjectId('6802833438c21fda61b62f42'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2012, 'Renewables (% equivalent primary energy)': 9.414955}
# {'_id': ObjectId('6802833438c21fda61b62f43'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2013, 'Renewables (% equivalent primary energy)': 9.847355}
# {'_id': ObjectId('6802833438c21fda61b62f44'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2014, 'Renewables (% equivalent primary energy)': 10.218171}
# {'_id': ObjectId('6802833438c21fda61b62f45'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2015, 'Renewables (% equivalent primary energy)': 10.504495}
# {'_id': ObjectId('6802833438c21fda61b62f46'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2016, 'Renewables (% equivalent primary energy)': 10.980251}
# {'_id': ObjectId('6802833438c21fda61b62f47'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2017, 'Renewables (% equivalent primary energy)': 11.337292}
# {'_id': ObjectId('6802833438c21fda61b62f48'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2018, 'Renewables (% equivalent primary energy)': 11.743186}
# {'_id': ObjectId('6802833438c21fda61b62f49'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2019, 'Renewables (% equivalent primary energy)': 12.228147}
# {'_id': ObjectId('6802833438c21fda61b62f4a'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2020, 'Renewables (% equivalent primary energy)': 13.404395}
# {'_id': ObjectId('6802833438c21fda61b62f4b'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2021, 'Renewables (% equivalent primary energy)': 13.469198}
# {'_id': ObjectId('6802833438c21fda61b62f4c'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2022, 'Renewables (% equivalent primary energy)': 14.119935}
# {'_id': ObjectId('6802833438c21fda61b62f4d'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2023, 'Renewables (% equivalent primary energy)': 14.562141}

# %%
renewable_all_records = renewable_collection.find()

# %%
print(renewable_all_records)
# Out:
# <pymongo.synchronous.cursor.Cursor object at 0x000001DC0F586F10>

# %%
renewable_list_cursor=list(renewable_all_records)

# %%
renewable_list_cursor
# Out:
# [{'_id': ObjectId('6802833438c21fda61b61c27'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 5.7402806},
#  {'_id': ObjectId('6802833438c21fda61b61c28'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 6.1139693},
#  {'_id': ObjectId('6802833438c21fda61b61c29'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.31658},
#  {'_id': ObjectId('6802833438c21fda61b61c2a'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.994845},
#  {'_id': ObjectId('6802833438c21fda61b61c2b'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 7.9439163},
#  {'_id': ObjectId('6802833438c21fda61b61c2c'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 9.148895},
#  {'_id': ObjectId('6802833438c21fda61b61c2d'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 8.124994},
#  {'_id': ObjectId('6802833438c21fda61b61c2e'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 8.747272},
#  {'_id': ObjectId('6802833438c21fda61b61c2f'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 8.54162},
#  {'_id': ObjectId('6802833438c21fda61b61c30'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)':
),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 18.79665},
#  ...]

# %%
renewable_energy_df = pd.DataFrame(renewable_list_cursor)

# %%
renewable_energy_df
# Out:
#                            _id  Entity      Code  Year  \
# 0     6802833438c21fda61b61c27  Africa       NaN  1965
# 1     6802833438c21fda61b61c28  Africa       NaN  1966
# 2     6802833438c21fda61b61c29  Africa       NaN  1967
# 3     6802833438c21fda61b61c2a  Africa       NaN  1968
# 4     6802833438c21fda61b61c2b  Africa       NaN  1969
# ...                        ...     ...       ...   ...
# 4898  6802833438c21fda61b62f49   World  OWID_WRL  2019
# 4899  6802833438c21fda61b62f4a   World  OWID_WRL  2020
# 4900  6802833438c21fda61b62f4b   World  OWID_WRL  2021
# 4901  6802833438c21fda61b62f4c   World  OWID_WRL  2022
# 4902  6802833438c21fda61b62f4d   World  OWID_WRL  2023
#
#       Renewables (% equivalent primary energy)
# 0                                     5.740281
# 1                                     6.113969
# 2                                     6.316580
# 3                                     6.994845
# 4                                     7.943916
# ...                                        ...
# 4898                                 12.228147
# 4899                                 13.404395
# 4900                                 13.469198
# 4901                                 14.119935
# 4902                                 14.562141
#
# [4903 rows x 5 columns]

# %%
renewable_energy_df.shape
# Out:
# (4903, 5)

# %%
renewable_energy_df.columns
# Out:
# Index(['_id', 'Entity', 'Code', 'Year',
#        'Renewables (% equivalent primary energy)'],
#       dtype='object')

# %%
renewable_energy_df.isnull().sum()
# Out:
# _id                                            0
# Entity                                         0
# Code                                        1350
# Year                                           0
# Renewables (% equivalent primary energy)       0
# dtype: int64

# %%
renewable_energy_df.drop(columns=["Code"], inplace=True, axis=1)

# %%
renewable_energy_df.drop(columns=["_id"], inplace=True, axis=1)

# %%
renewable_energy_df.rename(columns={"Entity": "Area"}, inplace=True)

# %%
renewable_energy_df.rename(columns={'Renewables (% equivalent primary energy)': 'Renewable_Energy_Share'}, inplace=True)

# %%
renewable_energy_df.head()
# Out:
#      Area  Year  Renewable_Energy_Share
# 0  Africa  1965                5.740281
# 1  Africa  1966                6.113969
# 2  Africa  1967                6.316580
# 3  Africa  1968                6.994845
# 4  Africa  1969                7.943916

# %% [markdown]
# ### Fetching Carbon Emissions Data from MongoDB and Transformation

# %%
def check_mongodb_collection(client, db_name, collection_name):
    try:
        db = client[db_name]
        print(f"Connected to database: {db_name}")
        collections = db.list_collection_names()
        print(f"Collections in {db_name}: {collections}")
        
        if collection_name not in collections:
            print(f"Collection '{collection_name}' does not exist in {db_name}")
            return False
        
        collection = db[collection_name]
        doc_count = collection.count_documents({})
        print(f"Number of documents in {collection_name}: {doc_count}")
        
        if doc_count == 0:
            print(f"Collection '{collection_name}' is empty")
            return False
        
        sample_doc = collection.find_one()
        print(f"Sample document from {collection_name}: {sample_doc}")
        return True
    except Exception as e:
        print(f"Error accessing {db_name}/{collection_name}: {e}")
        return False


print("--- Processing Carbon Emissions Data ---")

try:
    client = pymongo.MongoClient("mongodb://localhost:27017/")
    print("MongoDB connection successful")
    print("Available databases:", client.list_database_names())
except Exception as e:
    print(f"Failed to connect to MongoDB: {e}")
    client = None

if client:
    if check_mongodb_collection(client, "co2_renew_life_db", "carbon_emissions"):
        db = client["co2_renew_life_db"]
        emissions_collection = db["carbon_emissions"]

        emissions_all_records = emissions_collection.find()
        emissions_list_cursor = list(emissions_all_records)
        print(f"Retrieved {len(emissions_list_cursor)} records from carbon_emissions")

        emissions_df = pd.DataFrame(emissions_list_cursor)

        if emissions_df.empty:
            print("Emissions DataFrame is empty")
        else:
            print("Emissions DataFrame shape:", emissions_df.shape)
            print("Emissions DataFrame columns:", emissions_df.columns)
            print("Emissions DataFrame missing values:\n", emissions_df.isnull().sum())
            print("Emissions DataFrame head:\n", emissions_df.head())

            if '_id' in emissions_df.columns:
                emissions_df.drop(columns=["_id"], inplace=True)
            if 'Code' in emissions_df.columns:
                emissions_df.drop(columns=["Code"], inplace=True)

            emissions_df.rename(columns={
                "Entity": "Area",
                "Year": "Year",
                "Annual CO₂ emissions (per capita)": "CO2_Emissions_Per_Capita"
            }, inplace=True)

            print("Cleaned Emissions DataFrame head:\n", emissions_df.head())
    else:
        print("Skipping emissions data processing due to empty or missing collection")
else:
    print("Skipping emissions data processing due to connection failure")
# Out:
# --- Processing Carbon Emissions Data ---
# MongoDB connection successful
# Available databases: ['admin', 'co2_renew_life_db', 'config', 'local']
# Connected to database: co2_renew_life_db
# Collections in co2_renew_life_db: ['renewable_energy', 'life_expectancy', 'carbon_emissions']
# Number of documents in carbon_emissions: 26182
# Sample document from carbon_emissions: {'_id': ObjectId('6802833338c21fda61b5b5e1'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': 1949, 'Annual CO₂ emissions (per capita)': 0.0019921463}
# Retrieved 26182 records from carbon_emissions
# Emissions DataFrame shape: (26182, 5)
# Emissions DataFrame columns: Index(['_id', 'Entity', 'Code', 'Year', 'Annual CO₂ emissions (per capita)'], dtype='object')
# Emissions DataFrame missing values:
#  _id                                     0
# Entity                                  0
# Code                                 3287
# Year                                    0
# Annual CO₂ emissions (per capita)       0
# dtype: int64
# Emissions DataFrame head:
#                          _id       Entity Code  Year  \
# 0  6802833338c21fda61b5b5e1  Afghanistan  AFG  1949
# 1  6802833338c21fda61b5b5e2  Afghanistan  AFG  1950
# 2  6802833338c21fda61b5b5e3  Afghanistan  AFG  1951
# 3  6802833338c21fda61b5b5e4  Afghanistan  AFG  1952
# 4  6802833338c21fda61b5b5e5  Afghanistan  AFG  1953
#
#    Annual CO₂ emissions (per capita)
# 0                           0.001992
# 1                           0.010837
# 2                           0.011625
# 3                           0.011468
# 4                           0.013123
# Cleaned Emissions DataFrame head:
#            Area  Year  CO2_Emissions_Per_Capita
# 0  Afghanistan  1949                  0.001992
# 1  Afghanistan  1950                  0.010837
# 2  Afghanistan  1951                  0.011625
# 3  Afghanistan  1952                  0.011468
# 4  Afghanistan  1953                  0.013123

# %%
emissions_df.head()
# Out:
#           Area  Year  CO2_Emissions_Per_Capita
# 0  Afghanistan  1949                  0.001992
# 1  Afghanistan  1950                  0.010837
# 2  Afghanistan  1951                  0.011625
# 3  Afghanistan  1952                  0.011468
# 4  Afghanistan  1953                  0.013123

# %% [markdown]
# ### Fetching Life Expectancy Data from MongoDB and Transformation

# %%
if client:
    if check_mongodb_collection(client, "co2_renew_life_db", "life_expectancy"):
        db = client["co2_renew_life_db"]
        life_expectancy_collection = db["life_expectancy"]

        life_expectancy_all_records = life_expectancy_collection.find()
        life_expectancy_list_cursor = list(life_expectancy_all_records)
        print(f"Retrieved {len(life_expectancy_list_cursor)} records from life_expectancy")

        life_expectancy_df = pd.DataFrame(life_expectancy_list_cursor)

        if life_expectancy_df.empty:
            print("Life Expectancy DataFrame is empty")
        else:
            print("Life Expectancy DataFrame shape:", life_expectancy_df.shape)
            print("Life Expectancy DataFrame columns:", life_expectancy_df.columns)
            print("Life Expectancy DataFrame missing values:\n", life_expectancy_df.isnull().sum())
            print("Life Expectancy DataFrame head:\n", life_expectancy_df.head())

            if '_id' in life_expectancy_df.columns:
                life_expectancy_df.drop(columns=["_id"], inplace=True)
            if 'Code' in life_expectancy_df.columns:
                life_expectancy_df.drop(columns=["Code"], inplace=True)

            life_expectancy_df.rename(columns={
                "Entity": "Area",
                "Year": "Year",
                "Period life expectancy at birth - Sex: total - Age: 0": "Life_Expectancy"
            }, inplace=True)

            print("Cleaned Life Expectancy DataFrame head:\n", life_expectancy_df.head())
    else:
        print("Skipping life expectancy data processing due to empty or missing collection")
else:
    print("Skipping life expectancy data processing due to connection failure")
# Out:
# Connected to database: co2_renew_life_db
# Collections in co2_renew_life_db: ['renewable_energy', 'life_expectancy', 'carbon_emissions']
# Number of documents in life_expectancy: 21565
# Sample document from life_expectancy: {'_id': ObjectId('6802833438c21fda61b62f4e'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': 1950, 'Period life expectancy at birth - Sex: total - Age: 0': 28.1563}
# Retrieved 21565 records from life_expectancy
# Life Expectancy DataFrame shape: (21565, 5)
# Life Expectancy DataFrame columns: Index(['_id', 'Entity', 'Code', 'Year',
#        'Period life expectancy at birth - Sex: total - Age: 0'],
#       dtype='object')
# Life Expectancy DataFrame missing values:
#  _id                                                         0
# Entity                                                      0
# Code                                                     1956
# Year                                                        0
# Period life expectancy at birth - Sex: total - Age: 0       0
# dtype: int64
# Life Expectancy DataFrame head:
#                          _id       Entity Code  Year  \
# 0  6802833438c21fda61b62f4e  Afghanistan  AFG  1950
# 1  6802833438c21fda61b62f4f  Afghanistan  AFG  1951
# 2  6802833438c21fda61b62f50  Afghanistan  AFG  1952
# 3  6802833438c21fda61b62f51  Afghanistan  AFG  1953
# 4  6802833438c21fda61b62f52  Afghanistan  AFG  1954
#
#    Period life expectancy at birth - Sex: total - Age: 0
# 0                                            28.1563
# 1                                            28.5836
# 2                                            29.0138
# 3                                            29.4521
# 4                                            29.6975
# Cleaned Life Expectancy DataFrame head:
#            Area  Year  Life_Expectancy
# 0  Afghanistan  1950          28.1563
# 1  Afghanistan  1951          28.5836
# 2  Afghanistan  1952          29.0138
# 3  Afghanistan  1953          29.4521
# 4  Afghanistan  1954          29.6975

# %%
life_expectancy_df.head()
# Out:
#           Area  Year  Life_Expectancy
# 0  Afghanistan  1950          28.1563
# 1  Afghanistan  1951          28.5836
# 2  Afghanistan  1952          29.0138
# 3  Afghanistan  1953          29.4521
# 4  Afghanistan  1954          29.6975
