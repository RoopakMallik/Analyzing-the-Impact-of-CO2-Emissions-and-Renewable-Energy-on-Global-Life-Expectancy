# %% [markdown]
# ### Importing Libraries

# %%
import pymongo
import pandas as pd
import json

# %% [markdown]
# ### Connecting to MongoDB Server

# %%
carbon_emissions_client = pymongo.MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# ### Loading Data for Carbon Emissions

# %%
carbon_emissions_df = pd.read_csv("per-capita-co-emissions.csv")

# %%
carbon_emissions_df.shape
# Out:
# (26182, 3)

# %%
carbon_emissions_df.head()
# Out:
#         Entity  Year  Annual CO₂ emissions (per capita)
# 0  Afghanistan  1949                           0.001992
# 1  Afghanistan  1950                           0.010837
# 2  Afghanistan  1951                           0.011625
# 3  Afghanistan  1952                           0.011468
# 4  Afghanistan  1953                           0.013123

# %%
carbon_emissions_df.tail()
# Out:
#          Entity  Year  Annual CO₂ emissions (per capita)
# 26177  Zimbabwe  2019                           0.672038
# 26178  Zimbabwe  2020                           0.547083
# 26179  Zimbabwe  2021                           0.645913
# 26180  Zimbabwe  2022                           0.648759
# 26181  Zimbabwe  2023                           0.683199

# %%
carbon_emissions_data = carbon_emissions_df.to_dict(orient="records")

# %%
carbon_emissions_data
# Out:
# [{'Entity': 'Afghanistan',
#   'Year': 1949,
#   'Annual CO₂ emissions (per capita)': 0.0019921463},
#  {'Entity': 'Afghanistan',
#   'Year': 1950,
#   'Annual CO₂ emissions (per capita)': 0.0108371945},
#  {'Entity': 'Afghanistan',
#   'Year': 1951,
#   'Annual CO₂ emissions (per capita)': 0.011625335},
#  {'Entity': 'Afghanistan',
#   'Year': 1952,
#   'Annual CO₂ emissions (per capita)': 0.011467513},
#  {'Entity': 'Afghanistan',
#   'Year': 1953,
#   'Annual CO₂ emissions (per capita)': 0.013123366},
#  {'Entity': 'Afghanistan',
#   'Year': 1954,
#   'Annual CO₂ emissions (per capita)': 0.012945494},
#  {'Entity': 'Afghanistan',
#   'Year': 1955,
#   'Annual CO₂ emissions (per capita)': 0.018480647},
#  {'Entity': 'Afghanistan',
#   'Year': 1956,
#   'Annual CO₂ emissions (per capita)': 0.021669442},
#  {'Entity': 'Afghanistan',
#   'Year': 1957,
#   'Annual CO₂ emissions (per capita)': 0.034129996},
#  {'Entity': 'Afghanistan',
#   'Year': 1958,
#   'Annual CO₂ emissions (per capita)': 0.037801724},
#  {'Entity': 'Afghanistan',
#   'Year': 1959,
#   'Annual CO₂ emissions (per capita)': 0.04335993},
#  {'Entity': 'Afghanistan',
#   'Year': 1960,
#   'Annual CO₂ emissions (per capita)': 0.045808833},
#  {'Entity': 'Afghanistan',
#   'Year': 1961,
#   'Annual CO₂ emissions (per capita)': 0.05326608},
#  {'Entity': 'Afghanistan',
#   'Year': 1962,
#   'Annual CO₂ emissions (per capita)': 0.07322032},
#  {'Entity': 'Afghanistan',
#   'Year': 1963,
#   'Annual CO₂ emissions (per capita)': 0.07358391},
#  {'Entity': 'Afghanistan',
#   'Year': 1964,
#   'Annual CO₂ emissions (per capita)': 0.0854416},
#  {'Entity': 'Afghanistan',
#   'Year': 1965,
#   'Annual CO₂ emissions (per capita)': 0.10033048},
#  {'Entity': 'Afghanistan',
#   'Year': 1966,
#   'Annual CO₂ emissions (per capita)': 0.106284514},
#  {'Entity': 'Afghanistan',
#   'Year': 1967,
#   'Annual CO₂ emissions (per capita)': 0.122013114},
#  {'Entity': 'Afghanistan',
#   'Year': 1968,
#   'Annual CO₂ emissions (per capita)': 0.11373056},
#  {'Entity': 'Afghanistan',
#   'Year': 1969,
#   'Annual CO₂ emissions (per capita)': 0.08543128},
#  {'Entity': 'Afghanistan',
#   'Year': 1970,
#   'Annual CO₂ emissions (per capita)': 0.1479519},
#  {'Entity': 'Afghanistan',
#   'Year': 1971,
#   'Annual CO₂ emissions (per capita)': 0.1636936},
#  {'Entity': 'Afghanistan',
#   'Year': 1972,
#   'Annual CO₂ emissions (per capita)': 0.12910293},
#  {'Entity': 'Afghanistan',
#   'Year': 1973,
#   'Annual CO₂ emissions (per capita)': 0.1345167},
#  {'Entity': 'Afghanistan',
#   'Year': 1974,
#   'Annual CO₂ emissions (per capita)': 0.15343112},
#  {'Entity': 'Afghanistan',
#   'Year': 1975,
#   'Annual CO₂ emissions (per capita)': 0.1660708},
#  {'Entity': 'Afghanistan',
#   'Year': 1976,
#   'Annual CO₂ emissions (per capita)': 0.15167534},
#  {'Entity': 'Afghanistan',
#   'Year': 1977,
#   'Annual CO₂ emissions (per capita)': 0.1787136},
#  {'Entity': 'Afghanistan',
#   'Year': 1978,
#   'Annual CO₂ emissions (per capita)': 0.15819775},
#  {'Entity': 'Afghanistan',
#   'Year': 1979,
#   'Annual CO₂ emissions (per capita)': 0.16350497},
#  {'Entity': 'Afghanistan',
#   'Year': 1980,
#   'Annual CO₂ emissions (per capita)': 0.13336323},
#  {'Entity': 'Afghanistan',
#   'Year': 1981,
#   'Annual CO₂ emissions (per capita)': 0.16573392},
#  {'Entity': 'Afghanistan',
#   'Year': 1982,
#   'Annual CO₂ emissions (per capita)': 0.19056575},
#  {'Entity': 'Afghanistan',
#   'Year': 1983,
#   'Annual CO₂ emissions (per capita)': 0.23080759},
#  {'Entity': 'Afghanistan',
#   'Year': 1984,
#   'Annual CO₂ emissions (per capita)': 0.25214338},
#  {'Entity': 'Afghanistan',
#   'Year': 1985,
#   'Annual CO₂ emissions (per capita)': 0.30642045},
#  {'Entity': 'Afghanistan',
#   'Year': 1986,
#   'Annual CO₂ emissions (per capita)': 0.27439797},
#  {'Entity': 'Afghanistan',
#   'Year': 1987,
#   'Annual CO₂ emissions (per capita)': 0.27343467},
#  {'Entity': 'Afghanistan',
#   'Year': 1988,
#   'Annual CO₂ emissions (per capita)': 0.24792345},
#  {'Entity': 'Afghanistan',
#   'Year': 1989,
#   'Annual CO₂ emissions (per capita)': 0.23284778},
#  {'Entity': 'Afghanistan',
#   'Year': 1990,
#   'Annual CO₂ emissions (per capita)': 0.16805434},
#  {'Entity': 'Afghanistan',
#   'Year': 1991,
#   'Annual CO₂ emissions (per capita)': 0.15641147},
#  {'Entity': 'Afghanistan',
#   'Year': 1992,
#   'Annual CO₂ emissions (per capita)': 0.111609004},
#  {'Entity': 'Afghanistan',
#   'Year': 1993,
#   'Annual CO₂ emissions (per capita)': 0.099506505},
#  {'Entity': 'Afghanistan',
#   'Year': 1994,
#   'Annual CO₂ emissions (per capita)': 0.089462005},
#  {'Entity': 'Afghanistan',
#   'Year': 1995,
#   'Annual CO₂ emissions (per capita)': 0.08305055},
#  {'Entity': 'Afghanistan',
#   'Year': 1996,
#   'Annual CO₂ emissions (per capita)': 0.077131316},
#  {'Entity': 'Afghanistan',
#   'Year': 1997,
#   'Annual CO₂ emissions (per capita)': 0.0706777},
#  {'Entity': 'Afghanistan',
#   'Year': 1998,
#   'Annual CO₂ emissions (per capita)': 0.06672778},
#  {'Entity': 'Afghanistan',
#   'Year': 1999,
#   'Annual CO₂ emissions (per capita)': 0.05488996},
#  {'Entity': 'Afghanistan',
#   'Year': 2000,
#   'Annual CO₂ emissions (per capita)': 0.052017417},
#  {'Entity': 'Afghanistan',
#   'Year': 2001,
#   'Annual CO₂ emissions (per capita)': 0.05270568},
#  {'Entity': 'Afghanistan',
#   'Year': 2002,
#   'Annual CO₂ emissions (per capita)': 0.062727444},
#  {'Entity': 'Afghanistan',
#   'Year': 2003,
#   'Annual CO₂ emissions (per capita)': 0.068605036},
#  {'Entity': 'Afghanistan',
#   'Year': 2004,
#   'Annual CO₂ emissions (per capita)': 0.052513268},
#  {'Entity': 'Afghanistan',
#   'Year': 2005,
#   'Annual CO₂ emissions (per capita)': 0.077424295},
#  {'Entity': 'Afghanistan',
#   'Year': 2006,
#   'Annual CO₂ emissions (per capita)': 0.08493193},
#  {'Entity': 'Afghanistan',
#   'Year': 2007,
#   'Annual CO₂ emissions (per capita)': 0.10806349},
#  {'Entity': 'Afghanistan',
#   'Year': 2008,
#   'Annual CO₂ emissions (per capita)': 0.16065161},
#  {'Entity': 'Afghanistan',
#   'Year': 2009,
#   'Annual CO₂ emissions (per capita)': 0.23271917},
#  {'Entity': 'Afghanistan',
#   'Year': 2010,
#   'Annual CO₂ emissions (per capita)': 0.2957424},
#  {'Entity': 'Afghanistan',
#   'Year': 2011,
#   'Annual CO₂ emissions (per capita)': 0.40338126},
#  {'Entity': 'Afghanistan',
#   'Year': 2012,
#   'Annual CO₂ emissions (per capita)': 0.32838032},
#  {'Entity': 'Afghanistan',
#   'Year': 2013,
#   'Annual CO₂ emissions (per capita)': 0.29183197},
#  {'Entity': 'Afghanistan',
#   'Year': 2014,
#   'Annual CO₂ emissions (per capita)': 0.27707645},
#  {'Entity': 'Afghanistan',
#   'Year': 2015,
#   'Annual CO₂ emissions (per capita)': 0.28583142},
#  {'Entity': 'Afghanistan',
#   'Year': 2016,
#   'Annual CO₂ emissions (per capita)': 0.25666347},
#  {'Entity': 'Afghanistan',
#   'Year': 2017,
#   'Annual CO₂ emissions (per capita)': 0.27116078},
#  {'Entity': 'Afghanistan',
#   'Year': 2018,
#   'Annual CO₂ emissions (per capita)': 0.2885413},
#  {'Entity': 'Afghanistan',
#   'Year': 2019,
#   'Annual CO₂ emissions (per capita)': 0.2859549},
#  {'Entity': 'Afghanistan',
#   'Year': 2020,
#   'Annual CO₂ emissions (per capita)': 0.29706252},
#  {'Entity': 'Afghanistan',
#   'Year': 2021,
#   'Annual CO₂ emissions (per capita)': 0.2567944},
#  {'Entity': 'Afghanistan',
#   'Year': 2022,
#   'Annual CO₂ emissions (per capita)': 0.26017997},
#  {'Entity': 'Afghanistan',
#   'Year': 2023,
#   'Annual CO₂ emissions (per capita)': 0.2658372},
#  {'Entity': 'Africa',
#   'Year': 1884,
#   'Annual CO₂ emissions (per capita)': 0.00016810493},
#  {'Entity': 'Africa',
#   'Year': 1885,
#   'Annual CO₂ emissions (per capita)': 0.00027865346},
#  {'Entity': 'Africa',
#   'Year': 1886,
#   'Annual CO₂ emissions (per capita)': 0.00036027696},
#  {'Entity': 'Africa',
#   'Year': 1887,
#   'Annual CO₂ emissions (per capita)': 0.00035830968},
#  {'Entity': 'Africa',
#   'Year': 1888,
#   'Annual CO₂ emissions (per capita)': 0.00060305005},
#  {'Entity': 'Africa',
#   'Year': 1889,
#   'Annual CO₂ emissions (per capita)': 0.0009820405},
#  {'Entity': 'Africa',
#   'Year': 1890,
#   'Annual CO₂ emissions (per capita)': 0.0022003131},
#  {'Entity': 'Africa',
#   'Year': 1891,
#   'Annual CO₂ emissions (per capita)': 0.0021923848},
#  {'Entity': 'Africa',
#   'Year': 1892,
#   'Annual CO₂ emissions (per capita)': 0.0035353242},
#  {'Entity': 'Africa',
#   'Year': 1893,
#   'Annual CO₂ emissions (per capita)': 0.013219625},
#  {'Entity': 'Africa',
#   'Year': 1894,
#   'Annual CO₂ emissions (per capita)': 0.017834708},
#  {'Entity': 'Africa',
#   'Year': 1895,
#   'Annual CO₂ emissions (per capita)': 0.024409406},
#  {'Entity': 'Africa',
#   'Year': 1896,
#   'Annual CO₂ emissions (per capita)': 0.031057494},
#  {'Entity': 'Africa',
#   'Year': 1897,
#   'Annual CO₂ emissions (per capita)': 0.034764815},
#  {'Entity': 'Africa',
#   'Year': 1898,
#   'Annual CO₂ emissions (per capita)': 0.043902785},
#  {'Entity': 'Africa',
#   'Year': 1899,
#   'Annual CO₂ emissions (per capita)': 0.039936516},
#  {'Entity': 'Africa',
#   'Year': 1900,
#   'Annual CO₂ emissions (per capita)': 0.016815761},
#  {'Entity': 'Africa',
#   'Year': 1901,
#   'Annual CO₂ emissions (per capita)': 0.028121473},
#  {'Entity': 'Africa',
#   'Year': 1902,
#   'Annual CO₂ emissions (per capita)': 0.04176499},
#  {'Entity': 'Africa',
#   'Year': 1903,
#   'Annual CO₂ emissions (per capita)': 0.056402333},
#  {'Entity': 'Africa',
#   'Year': 1904,
#   'Annual CO₂ emissions (per capita)': 0.06341765},
#  {'Entity': 'Africa',
#   'Year': 1905,
#   'Annual CO₂ emissions (per capita)': 0.07276437},
#  {'Entity': 'Africa',
#   'Year': 1906,
#   'Annual CO₂ emissions (per capita)': 0.08275714},
#  {'Entity': 'Africa',
#   'Year': 1907,
#   'Annual CO₂ emissions (per capita)': 0.0909625},
#  {'Entity': 'Africa',
#   'Year': 1908,
#   'Annual CO₂ emissions (per capita)': 0.09390756},
#  {'Entity': 'Africa',
#   'Year': 1909,
#   'Annual CO₂ emissions (per capita)': 0.10735923},
#  {'Entity': 'Africa',
#   'Year': 1910,
#   'Annual CO₂ emissions (per capita)': 0.12100435},
#  {'Entity': 'Africa',
#   'Year': 1911,
#   'Annual CO₂ emissions (per capita)': 0.116731},
#  {'Entity': 'Africa',
#   'Year': 1912,
#   'Annual CO₂ emissions (per capita)': 0.123760745},
#  {'Entity': 'Africa',
#   'Year': 1913,
#   'Annual CO₂ emissions (per capita)': 0.13460414},
#  {'Entity': 'Africa',
#   'Year': 1914,
#   'Annual CO₂ emissions (per capita)': 0.13367727},
#  {'Entity': 'Africa',
#   'Year': 1915,
#   'Annual CO₂ emissions (per capita)': 0.13349853},
#  {'Entity': 'Africa',
#   'Year': 1916,
#   'Annual CO₂ emissions (per capita)': 0.15768538},
#  {'Entity': 'Africa',
#   'Year': 1917,
#   'Annual CO₂ emissions (per capita)': 0.17112114},
#  {'Entity': 'Africa',
#   'Year': 1918,
#   'Annual CO₂ emissions (per capita)': 0.16625711},
#  {'Entity': 'Africa',
#   'Year': 1919,
#   'Annual CO₂ emissions (per capita)': 0.17010342},
#  {'Entity': 'Africa',
#   'Year': 1920,
#   'Annual CO₂ emissions (per capita)': 0.18615878},
#  {'Entity': 'Africa',
#   'Year': 1921,
#   'Annual CO₂ emissions (per capita)': 0.18404068},
#  {'Entity': 'Africa',
#   'Year': 1922,
#   'Annual CO₂ emissions (per capita)': 0.15595937},
#  {'Entity': 'Africa',
#   'Year': 1923,
#   'Annual CO₂ emissions (per capita)': 0.18666829},
#  {'Entity': 'Africa',
#   'Year': 1924,
#   'Annual CO₂ emissions (per capita)': 0.19445343},
#  {'Entity': 'Africa',
#   'Year': 1925,
#   'Annual CO₂ emissions (per capita)': 0.20180704},
#  {'Entity': 'Africa',
#   'Year': 1926,
#   'Annual CO₂ emissions (per capita)': 0.21327865},
#  {'Entity': 'Africa',
#   'Year': 1927,
#   'Annual CO₂ emissions (per capita)': 0.2069944},
#  {'Entity': 'Africa',
#   'Year': 1928,
#   'Annual CO₂ emissions (per capita)': 0.21005066},
#  {'Entity': 'Africa',
#   'Year': 1929,
#   'Annual CO₂ emissions (per capita)': 0.21359752},
#  {'Entity': 'Africa',
#   'Year': 1930,
#   'Annual CO₂ emissions (per capita)': 0.19853099},
#  {'Entity': 'Africa',
#   'Year': 1931,
#   'Annual CO₂ emissions (per capita)': 0.17142504},
#  {'Entity': 'Africa',
#   'Year': 1932,
#   'Annual CO₂ emissions (per capita)': 0.15295953},
#  {'Entity': 'Africa',
#   'Year': 1933,
#   'Annual CO₂ emissions (per capita)': 0.16163766},
#  {'Entity': 'Africa',
#   'Year': 1934,
#   'Annual CO₂ emissions (per capita)': 0.18227975},
#  {'Entity': 'Africa',
#   'Year': 1935,
#   'Annual CO₂ emissions (per capita)': 0.19862159},
#  {'Entity': 'Africa',
#   'Year': 1936,
#   'Annual CO₂ emissions (per capita)': 0.21307538},
#  {'Entity': 'Africa',
#   'Year': 1937,
#   'Annual CO₂ emissions (per capita)': 0.22562651},
#  {'Entity': 'Africa',
#   'Year': 1938,
#   'Annual CO₂ emissions (per capita)': 0.23430876},
#  {'Entity': 'Africa',
#   'Year': 1939,
#   'Annual CO₂ emissions (per capita)': 0.24609981},
#  {'Entity': 'Africa',
#   'Year': 1940,
#   'Annual CO₂ emissions (per capita)': 0.25714242},
#  {'Entity': 'Africa',
#   'Year': 1941,
#   'Annual CO₂ emissions (per capita)': 0.27570948},
#  {'Entity': 'Africa',
#   'Year': 1942,
#   'Annual CO₂ emissions (per capita)': 0.2956288},
#  {'Entity': 'Africa',
#   'Year': 1943,
#   'Annual CO₂ emissions (per capita)': 0.29735428},
#  {'Entity': 'Africa',
#   'Year': 1944,
#   'Annual CO₂ emissions (per capita)': 0.3243292},
#  {'Entity': 'Africa',
#   'Year': 1945,
#   'Annual CO₂ emissions (per capita)': 0.32344264},
#  {'Entity': 'Africa',
#   'Year': 1946,
#   'Annual CO₂ emissions (per capita)': 0.32124582},
#  {'Entity': 'Africa',
#   'Year': 1947,
#   'Annual CO₂ emissions (per capita)': 0.31506482},
#  {'Entity': 'Africa',
#   'Year': 1948,
#   'Annual CO₂ emissions (per capita)': 0.32733774},
#  {'Entity': 'Africa',
#   'Year': 1949,
#   'Annual CO₂ emissions (per capita)': 0.34674028},
#  {'Entity': 'Africa',
#   'Year': 1950,
#   'Annual CO₂ emissions (per capita)': 0.41701305},
#  {'Entity': 'Africa',
#   'Year': 1951,
#   'Annual CO₂ emissions (per capita)': 0.43538994},
#  {'Entity': 'Africa',
#   'Year': 1952,
#   'Annual CO₂ emissions (per capita)': 0.4650465},
#  {'Entity': 'Africa',
#   'Year': 1953,
#   'Annual CO₂ emissions (per capita)': 0.46213555},
#  {'Entity': 'Africa',
#   'Year': 1954,
#   'Annual CO₂ emissions (per capita)': 0.47455564},
#  {'Entity': 'Africa',
#   'Year': 1955,
#   'Annual CO₂ emissions (per capita)': 0.511079},
#  {'Entity': 'Africa',
#   'Year': 1956,
#   'Annual CO₂ emissions (per capita)': 0.52181756},
#  {'Entity': 'Africa',
#   'Year': 1957,
#   'Annual CO₂ emissions (per capita)': 0.5348022},
#  {'Entity': 'Africa',
#   'Year': 1958,
#   'Annual CO₂ emissions (per capita)': 0.5492976},
#  {'Entity': 'Africa',
#   'Year': 1959,
#   'Annual CO₂ emissions (per capita)': 0.5339706},
#  {'Entity': 'Africa',
#   'Year': 1960,
#   'Annual CO₂ emissions (per capita)': 0.5522528},
#  {'Entity': 'Africa',
#   'Year': 1961,
#   'Annual CO₂ emissions (per capita)': 0.5578654},
#  {'Entity': 'Africa',
#   'Year': 1962,
#   'Annual CO₂ emissions (per capita)': 0.55908394},
#  {'Entity': 'Africa',
#   'Year': 1963,
#   'Annual CO₂ emissions (per capita)': 0.57831824},
#  {'Entity': 'Africa',
#   'Year': 1964,
#   'Annual CO₂ emissions (per capita)': 0.61948013},
#  {'Entity': 'Africa',
#   'Year': 1965,
#   'Annual CO₂ emissions (per capita)': 0.6665221},
#  {'Entity': 'Africa',
#   'Year': 1966,
#   'Annual CO₂ emissions (per capita)': 0.6725036},
#  {'Entity': 'Africa',
#   'Year': 1967,
#   'Annual CO₂ emissions (per capita)': 0.7027146},
#  {'Entity': 'Africa',
#   'Year': 1968,
#   'Annual CO₂ emissions (per capita)': 0.7429979},
#  {'Entity': 'Africa',
#   'Year': 1969,
#   'Annual CO₂ emissions (per capita)': 0.7812512},
#  {'Entity': 'Africa',
#   'Year': 1970,
#   'Annual CO₂ emissions (per capita)': 0.8285632},
#  {'Entity': 'Africa',
#   'Year': 1971,
#   'Annual CO₂ emissions (per capita)': 0.88492876},
#  {'Entity': 'Africa',
#   'Year': 1972,
#   'Annual CO₂ emissions (per capita)': 0.9141623},
#  {'Entity': 'Africa',
#   'Year': 1973,
#   'Annual CO₂ emissions (per capita)': 0.95599747},
#  {'Entity': 'Africa',
#   'Year': 1974,
#   'Annual CO₂ emissions (per capita)': 0.95552486},
#  {'Entity': 'Africa',
#   'Year': 1975,
#   'Annual CO₂ emissions (per capita)': 0.9262899},
#  {'Entity': 'Africa',
#   'Year': 1976,
#   'Annual CO₂ emissions (per capita)': 0.97684073},
#  {'Entity': 'Africa',
#   'Year': 1977,
#   'Annual CO₂ emissions (per capita)': 0.9794306},
#  {'Entity': 'Africa',
#   'Year': 1978,
#   'Annual CO₂ emissions (per capita)': 1.0164287},
#  {'Entity': 'Africa',
#   'Year': 1979,
#   'Annual CO₂ emissions (per capita)': 1.0650721},
#  {'Entity': 'Africa',
#   'Year': 1980,
#   'Annual CO₂ emissions (per capita)': 1.1113187},
#  {'Entity': 'Africa',
#   'Year': 1981,
#   'Annual CO₂ emissions (per capita)': 1.1046573},
#  {'Entity': 'Africa',
#   'Year': 1982,
#   'Annual CO₂ emissions (per capita)': 1.1166936},
#  {'Entity': 'Africa',
#   'Year': 1983,
#   'Annual CO₂ emissions (per capita)': 1.1277032},
#  {'Entity': 'Africa',
#   'Year': 1984,
#   'Annual CO₂ emissions (per capita)': 1.1966531},
#  {'Entity': 'Africa',
#   'Year': 1985,
#   'Annual CO₂ emissions (per capita)': 1.191995},
#  {'Entity': 'Africa',
#   'Year': 1986,
#   'Annual CO₂ emissions (per capita)': 1.2000366},
#  {'Entity': 'Africa',
#   'Year': 1987,
#   'Annual CO₂ emissions (per capita)': 1.1665251},
#  {'Entity': 'Africa',
#   'Year': 1988,
#   'Annual CO₂ emissions (per capita)': 1.1920505},
#  {'Entity': 'Africa',
#   'Year': 1989,
#   'Annual CO₂ emissions (per capita)': 1.1169115},
#  {'Entity': 'Africa',
#   'Year': 1990,
#   'Annual CO₂ emissions (per capita)': 1.0240961},
#  {'Entity': 'Africa',
#   'Year': 1991,
#   'Annual CO₂ emissions (per capita)': 1.041674},
#  {'Entity': 'Africa',
#   'Year': 1992,
#   'Annual CO₂ emissions (per capita)': 0.9838701},
#  {'Entity': 'Africa',
#   'Year': 1993,
#   'Annual CO₂ emissions (per capita)': 1.0155436},
#  {'Entity': 'Africa',
#   'Year': 1994,
#   'Annual CO₂ emissions (per capita)': 1.1075671},
#  {'Entity': 'Africa',
#   'Year': 1995,
#   'Annual CO₂ emissions (per capita)': 1.154304},
#  {'Entity': 'Africa',
#   'Year': 1996,
#   'Annual CO₂ emissions (per capita)': 1.1624247},
#  {'Entity': 'Africa',
#   'Year': 1997,
#   'Annual CO₂ emissions (per capita)': 1.1620444},
#  {'Entity': 'Africa',
#   'Year': 1998,
#   'Annual CO₂ emissions (per capita)': 1.1567284},
#  {'Entity': 'Africa',
#   'Year': 1999,
#   'Annual CO₂ emissions (per capita)': 1.1124499},
#  {'Entity': 'Africa',
#   'Year': 2000,
#   'Annual CO₂ emissions (per capita)': 1.1223302},
#  {'Entity': 'Africa',
#   'Year': 2001,
#   'Annual CO₂ emissions (per capita)': 1.0824622},
#  {'Entity': 'Africa',
#   'Year': 2002,
#   'Annual CO₂ emissions (per capita)': 1.0319118},
#  {'Entity': 'Africa',
#   'Year': 2003,
#   'Annual CO₂ emissions (per capita)': 1.1064153},
#  {'Entity': 'Africa',
#   'Year': 2004,
#   'Annual CO₂ emissions (per capita)': 1.1397791},
#  {'Entity': 'Africa',
#   'Year': 2005,
#   'Annual CO₂ emissions (per capita)': 1.1255214},
#  {'Entity': 'Africa',
#   'Year': 2006,
#   'Annual CO₂ emissions (per capita)': 1.1300635},
#  {'Entity': 'Africa',
#   'Year': 2007,
#   'Annual CO₂ emissions (per capita)': 1.1274081},
#  {'Entity': 'Africa',
#   'Year': 2008,
#   'Annual CO₂ emissions (per capita)': 1.1555071},
#  {'Entity': 'Africa',
#   'Year': 2009,
#   'Annual CO₂ emissions (per capita)': 1.119719},
#  {'Entity': 'Africa',
#   'Year': 2010,
#   'Annual CO₂ emissions (per capita)': 1.1362721},
#  {'Entity': 'Africa',
#   'Year': 2011,
#   'Annual CO₂ emissions (per capita)': 1.1445001},
#  {'Entity': 'Africa',
#   'Year': 2012,
#   'Annual CO₂ emissions (per capita)': 1.125614},
#  {'Entity': 'Africa',
#   'Year': 2013,
#   'Annual CO₂ emissions (per capita)': 1.1082679},
#  {'Entity': 'Africa',
#   'Year': 2014,
#   'Annual CO₂ emissions (per capita)': 1.1428827},
#  {'Entity': 'Africa',
#   'Year': 2015,
#   'Annual CO₂ emissions (per capita)': 1.0937093},
#  {'Entity': 'Africa',
#   'Year': 2016,
#   'Annual CO₂ emissions (per capita)': 1.1004659},
#  {'Entity': 'Africa',
#   'Year': 2017,
#   'Annual CO₂ emissions (per capita)': 1.0873753},
#  {'Entity': 'Africa',
#   'Year': 2018,
#   'Annual CO₂ emissions (per capita)': 1.0554873},
#  {'Entity': 'Africa',
#   'Year': 2019,
#   'Annual CO₂ emissions (per capita)': 1.0988438},
#  {'Entity': 'Africa',
#   'Year': 2020,
#   'Annual CO₂ emissions (per capita)': 0.98307353},
#  {'Entity': 'Africa',
#   'Year': 2021,
#   'Annual CO₂ emissions (per capita)': 1.0208932},
#  {'Entity': 'Africa',
#   'Year': 2022,
#   'Annual CO₂ emissions (per capita)': 0.99125665},
#  {'Entity': 'Africa',
#   'Year': 2023,
#   'Annual CO₂ emissions (per capita)': 0.95925564},
#  {'Entity': 'Albania',
#   'Year': 1933,
#   'Annual CO₂ emissions (per capita)': 0.007159781},
#  {'Entity': 'Albania',
#   'Year': 1934,
#   'Annual CO₂ emissions (per capita)': 0.0070867664},
#  {'Entity': 'Albania',
#   'Year': 1935,
#   'Annual CO₂ emissions (per capita)': 0.017536236},
#  {'Entity': 'Albania',
#   'Year': 1936,
#   'Annual CO₂ emissions (per capita)': 0.12147333},
#  {'Entity': 'Albania',
#   'Year': 1937,
#   'Annual CO₂ emissions (per capita)': 0.27826673},
#  {'Entity': 'Albania',
#   'Year': 1938,
#   'Annual CO₂ emissions (per capita)': 0.32309836},
#  {'Entity': 'Albania',
#   'Year': 1939,
#   'Annual CO₂ emissions (per capita)': 0.39708453},
#  {'Entity': 'Albania',
#   'Year': 1940,
#   'Annual CO₂ emissions (per capita)': 0.62906545},
#  {'Entity': 'Albania',
#   'Year': 1941,
#   'Annual CO₂ emissions (per capita)': 0.562687},
#  {'Entity': 'Albania',
#   'Year': 1942,
#   'Annual CO₂ emissions (per capita)': 0.66028625},
#  {'Entity': 'Albania',
#   'Year': 1943,
#   'Annual CO₂ emissions (per capita)': 0.4049297},
#  {'Entity': 'Albania',
#   'Year': 1944,
#   'Annual CO₂ emissions (per capita)': 0.13336176},
#  {'Entity': 'Albania',
#   'Year': 1945,
#   'Annual CO₂ emissions (per capita)': 0.10353056},
#  {'Entity': 'Albania',
#   'Year': 1946,
#   'Annual CO₂ emissions (per capita)': 0.40916798},
#  {'Entity': 'Albania',
#   'Year': 1947,
#   'Annual CO₂ emissions (per capita)': 0.774856},
#  {'Entity': 'Albania',
#   'Year': 1948,
#   'Annual CO₂ emissions (per capita)': 0.58099794},
#  {'Entity': 'Albania',
#   'Year': 1949,
#   'Annual CO₂ emissions (per capita)': 0.8254675},
#  {'Entity': 'Albania',
#   'Year': 1950,
#   'Annual CO₂ emissions (per capita)': 0.23778823},
#  {'Entity': 'Albania',
#   'Year': 1951,
#   'Annual CO₂ emissions (per capita)': 0.31572577},
#  {'Entity': 'Albania',
#   'Year': 1952,
#   'Annual CO₂ emissions (per capita)': 0.28559908},
#  {'Entity': 'Albania',
#   'Year': 1953,
#   'Annual CO₂ emissions (per capita)': 0.30811146},
#  {'Entity': 'Albania',
#   'Year': 1954,
#   'Annual CO₂ emissions (per capita)': 0.36341593},
#  {'Entity': 'Albania',
#   'Year': 1955,
#   'Annual CO₂ emissions (per capita)': 0.4672824},
#  {'Entity': 'Albania',
#   'Year': 1956,
#   'Annual CO₂ emissions (per capita)': 0.5757659},
#  {'Entity': 'Albania',
#   'Year': 1957,
#   'Annual CO₂ emissions (per capita)': 1.0051103},
#  {'Entity': 'Albania',
#   'Year': 1958,
#   'Annual CO₂ emissions (per capita)': 0.77816045},
#  {'Entity': 'Albania',
#   'Year': 1959,
#   'Annual CO₂ emissions (per capita)': 0.90488917},
#  {'Entity': 'Albania',
#   'Year': 1960,
#   'Annual CO₂ emissions (per capita)': 1.2260456},
#  {'Entity': 'Albania',
#   'Year': 1961,
#   'Annual CO₂ emissions (per capita)': 1.3412603},
#  {'Entity': 'Albania',
#   'Year': 1962,
#   'Annual CO₂ emissions (per capita)': 1.4117563},
#  {'Entity': 'Albania',
#   'Year': 1963,
#   'Annual CO₂ emissions (per capita)': 1.1615194},
#  {'Entity': 'Albania',
#   'Year': 1964,
#   'Annual CO₂ emissions (per capita)': 1.0940837},
#  {'Entity': 'Albania',
#   'Year': 1965,
#   'Annual CO₂ emissions (per capita)': 1.1466707},
#  {'Entity': 'Albania',
#   'Year': 1966,
#   'Annual CO₂ emissions (per capita)': 1.3074449},
#  {'Entity': 'Albania',
#   'Year': 1967,
#   'Annual CO₂ emissions (per capita)': 1.3330656},
#  {'Entity': 'Albania',
#   'Year': 1968,
#   'Annual CO₂ emissions (per capita)': 1.483537},
#  {'Entity': 'Albania',
#   'Year': 1969,
#   'Annual CO₂ emissions (per capita)': 1.5239673},
#  {'Entity': 'Albania',
#   'Year': 1970,
#   'Annual CO₂ emissions (per capita)': 1.7143956},
#  {'Entity': 'Albania',
#   'Year': 1971,
#   'Annual CO₂ emissions (per capita)': 1.9454293},
#  {'Entity': 'Albania',
#   'Year': 1972,
#   'Annual CO₂ emissions (per capita)': 2.462787},
#  {'Entity': 'Albania',
#   'Year': 1973,
#   'Annual CO₂ emissions (per capita)': 2.2551887},
#  {'Entity': 'Albania',
#   'Year': 1974,
#   'Annual CO₂ emissions (per capita)': 1.8094172},
#  {'Entity': 'Albania',
#   'Year': 1975,
#   'Annual CO₂ emissions (per capita)': 1.8702347},
#  {'Entity': 'Albania',
#   'Year': 1976,
#   'Annual CO₂ emissions (per capita)': 1.9705383},
#  {'Entity': 'Albania',
#   'Year': 1977,
#   'Annual CO₂ emissions (per capita)': 2.2275932},
#  {'Entity': 'Albania',
#   'Year': 1978,
#   'Annual CO₂ emissions (per capita)': 2.4732122},
#  {'Entity': 'Albania',
#   'Year': 1979,
#   'Annual CO₂ emissions (per capita)': 2.828372},
#  {'Entity': 'Albania',
#   'Year': 1980,
#   'Annual CO₂ emissions (per capita)': 1.8903245},
#  {'Entity': 'Albania',
#   'Year': 1981,
#   'Annual CO₂ emissions (per capita)': 2.6302996},
#  {'Entity': 'Albania',
#   'Year': 1982,
#   'Annual CO₂ emissions (per capita)': 2.5668557},
#  {'Entity': 'Albania',
#   'Year': 1983,
#   'Annual CO₂ emissions (per capita)': 2.626668},
#  {'Entity': 'Albania',
#   'Year': 1984,
#   'Annual CO₂ emissions (per capita)': 2.6394625},
#  {'Entity': 'Albania',
#   'Year': 1985,
#   'Annual CO₂ emissions (per capita)': 2.6043959},
#  {'Entity': 'Albania',
#   'Year': 1986,
#   'Annual CO₂ emissions (per capita)': 2.609769},
#  {'Entity': 'Albania',
#   'Year': 1987,
#   'Annual CO₂ emissions (per capita)': 2.3650215},
#  {'Entity': 'Albania',
#   'Year': 1988,
#   'Annual CO₂ emissions (per capita)': 2.2811687},
#  {'Entity': 'Albania',
#   'Year': 1989,
#   'Annual CO₂ emissions (per capita)': 2.7561808},
#  {'Entity': 'Albania',
#   'Year': 1990,
#   'Annual CO₂ emissions (per capita)': 1.6841558},
#  {'Entity': 'Albania',
#   'Year': 1991,
#   'Annual CO₂ emissions (per capita)': 1.3069569},
#  {'Entity': 'Albania',
#   'Year': 1992,
#   'Annual CO₂ emissions (per capita)': 0.7668275},
#  {'Entity': 'Albania',
#   'Year': 1993,
#   'Annual CO₂ emissions (per capita)': 0.71327645},
#  {'Entity': 'Albania',
#   'Year': 1994,
#   'Annual CO₂ emissions (per capita)': 0.5884248},
#  {'Entity': 'Albania',
#   'Year': 1995,
#   'Annual CO₂ emissions (per capita)': 0.64109856},
#  {'Entity': 'Albania',
#   'Year': 1996,
#   'Annual CO₂ emissions (per capita)': 0.62159777},
#  {'Entity': 'Albania',
#   'Year': 1997,
#   'Annual CO₂ emissions (per capita)': 0.47776133},
#  {'Entity': 'Albania',
#   'Year': 1998,
#   'Annual CO₂ emissions (per capita)': 0.54661566},
#  {'Entity': 'Albania',
#   'Year': 1999,
#   'Annual CO₂ emissions (per capita)': 0.9365238},
#  {'Entity': 'Albania',
#   'Year': 2000,
#   'Annual CO₂ emissions (per capita)': 0.9553966},
#  {'Entity': 'Albania',
#   'Year': 2001,
#   'Annual CO₂ emissions (per capita)': 1.0230992},
#  {'Entity': 'Albania',
#   'Year': 2002,
#   'Annual CO₂ emissions (per capita)': 1.1959667},
#  {'Entity': 'Albania',
#   'Year': 2003,
#   'Annual CO₂ emissions (per capita)': 1.3801706},
#  {'Entity': 'Albania',
#   'Year': 2004,
#   'Annual CO₂ emissions (per capita)': 1.3478987},
#  {'Entity': 'Albania',
#   'Year': 2005,
#   'Annual CO₂ emissions (per capita)': 1.385305},
#  {'Entity': 'Albania',
#   'Year': 2006,
#   'Annual CO₂ emissions (per capita)': 1.2818637},
#  {'Entity': 'Albania',
#   'Year': 2007,
#   'Annual CO₂ emissions (per capita)': 1.3063571},
#  {'Entity': 'Albania',
#   'Year': 2008,
#   'Annual CO₂ emissions (per capita)': 1.4691418},
#  {'Entity': 'Albania',
#   'Year': 2009,
#   'Annual CO₂ emissions (per capita)': 1.4879525},
#  {'Entity': 'Albania',
#   'Year': 2010,
#   'Annual CO₂ emissions (per capita)': 1.6334264},
#  {'Entity': 'Albania',
#   'Year': 2011,
#   'Annual CO₂ emissions (per capita)': 1.8254082},
#  {'Entity': 'Albania',
#   'Year': 2012,
#   'Annual CO₂ emissions (per capita)': 1.6666856},
#  {'Entity': 'Albania',
#   'Year': 2013,
#   'Annual CO₂ emissions (per capita)': 1.8185169},
#  {'Entity': 'Albania',
#   'Year': 2014,
#   'Annual CO₂ emissions (per capita)': 2.0661745},
#  {'Entity': 'Albania',
#   'Year': 2015,
#   'Annual CO₂ emissions (per capita)': 1.625643},
#  {'Entity': 'Albania',
#   'Year': 2016,
#   'Annual CO₂ emissions (per capita)': 1.5984093},
#  {'Entity': 'Albania',
#   'Year': 2017,
#   'Annual CO₂ emissions (per capita)': 1.8262929},
#  {'Entity': 'Albania',
#   'Year': 2018,
#   'Annual CO₂ emissions (per capita)': 1.6912793},
#  {'Entity': 'Albania',
#   'Year': 2019,
#   'Annual CO₂ emissions (per capita)': 1.6731106},
#  {'Entity': 'Albania',
#   'Year': 2020,
#   'Annual CO₂ emissions (per capita)': 1.6403989},
#  {'Entity': 'Albania',
#   'Year': 2021,
#   'Annual CO₂ emissions (per capita)': 1.8016713},
#  {'Entity': 'Albania',
#   'Year': 2022,
#   'Annual CO₂ emissions (per capita)': 1.8295882},
#  {'Entity': 'Albania',
#   'Year': 2023,
#   'Annual CO₂ emissions (per capita)': 1.8296235},
#  {'Entity': 'Algeria',
#   'Year': 1916,
#   'Annual CO₂ emissions (per capita)': 0.0006419031},
#  {'Entity': 'Algeria',
#   'Year': 1917,
#   'Annual CO₂ emissions (per capita)': 0.0012771984},
#  {'Entity': 'Algeria',
#   'Year': 1918,
#   'Annual CO₂ emissions (per capita)': 0.0031769325},
#  {'Entity': 'Algeria',
#   'Year': 1919,
#   'Annual CO₂ emissions (per capita)': 0.0031571276},
#  {'Entity': 'Algeria',
#   'Year': 1920,
#   'Annual CO₂ emissions (per capita)': 0.0037603965},
#  {'Entity': 'Algeria',
#   'Year': 1921,
#   'Annual CO₂ emissions (per capita)': 0.0043493058},
#  {'Entity': 'Algeria',
#   'Year': 1922,
#   'Annual CO₂ emissions (per capita)': 0.0043066936},
#  {'Entity': 'Algeria',
#   'Year': 1923,
#   'Annual CO₂ emissions (per capita)': 0.0024340036},
#  {'Entity': 'Algeria',
#   'Year': 1924,
#   'Annual CO₂ emissions (per capita)': 0.00481467},
#  {'Entity': 'Algeria',
#   'Year': 1925,
#   'Annual CO₂ emissions (per capita)': 0.005357156},
#  {'Entity': 'Algeria',
#   'Year': 1926,
#   'Annual CO₂ emissions (per capita)': 0.0064758947},
#  {'Entity': 'Algeria',
#   'Year': 1927,
#   'Annual CO₂ emissions (per capita)': 0.009316276},
#  {'Entity': 'Algeria',
#   'Year': 1928,
#   'Annual CO₂ emissions (per capita)': 0.011485059},
#  {'Entity': 'Algeria',
#   'Year': 1929,
#   'Annual CO₂ emissions (per capita)': 0.012478749},
#  {'Entity': 'Algeria',
#   'Year': 1930,
#   'Annual CO₂ emissions (per capita)': 0.012864212},
#  {'Entity': 'Algeria',
#   'Year': 1931,
#   'Annual CO₂ emissions (per capita)': 0.014877537},
#  {'Entity': 'Algeria',
#   'Year': 1932,
#   'Annual CO₂ emissions (per capita)': 0.016805604},
#  {'Entity': 'Algeria',
#   'Year': 1933,
#   'Annual CO₂ emissions (per capita)': 0.017591037},
#  {'Entity': 'Algeria',
#   'Year': 1934,
#   'Annual CO₂ emissions (per capita)': 0.019898007},
#  {'Entity': 'Algeria',
#   'Year': 1935,
#   'Annual CO₂ emissions (per capita)': 0.018538017},
#  {'Entity': 'Algeria',
#   'Year': 1936,
#   'Annual CO₂ emissions (per capita)': 0.0070609855},
#  {'Entity': 'Algeria',
#   'Year': 1937,
#   'Annual CO₂ emissions (per capita)': 0.009429192},
#  {'Entity': 'Algeria',
#   'Year': 1938,
#   'Annual CO₂ emissions (per capita)': 0.0044057337},
#  {'Entity': 'Algeria',
#   'Year': 1939,
#   'Annual CO₂ emissions (per capita)': 0.021176292},
#  {'Entity': 'Algeria',
#   'Year': 1940,
#   'Annual CO₂ emissions (per capita)': 0.030772531},
#  {'Entity': 'Algeria',
#   'Year': 1941,
#   'Annual CO₂ emissions (per capita)': 0.03960487},
#  {'Entity': 'Algeria',
#   'Year': 1942,
#   'Annual CO₂ emissions (per capita)': 0.06239821},
#  {'Entity': 'Algeria',
#   'Year': 1943,
#   'Annual CO₂ emissions (per capita)': 0.057818197},
#  {'Entity': 'Algeria',
#   'Year': 1944,
#   'Annual CO₂ emissions (per capita)': 0.060518295},
#  {'Entity': 'Algeria',
#   'Year': 1945,
#   'Annual CO₂ emissions (per capita)': 0.0736583},
#  {'Entity': 'Algeria',
#   'Year': 1946,
#   'Annual CO₂ emissions (per capita)': 0.089851215},
#  {'Entity': 'Algeria',
#   'Year': 1947,
#   'Annual CO₂ emissions (per capita)': 0.08638843},
#  {'Entity': 'Algeria',
#   'Year': 1948,
#   'Annual CO₂ emissions (per capita)': 0.09181947},
#  {'Entity': 'Algeria',
#   'Year': 1949,
#   'Annual CO₂ emissions (per capita)': 0.10236545},
#  {'Entity': 'Algeria',
#   'Year': 1950,
#   'Annual CO₂ emissions (per capita)': 0.41954175},
#  {'Entity': 'Algeria',
#   'Year': 1951,
#   'Annual CO₂ emissions (per capita)': 0.44565666},
#  {'Entity': 'Algeria',
#   'Year': 1952,
#   'Annual CO₂ emissions (per capita)': 0.40847814},
#  {'Entity': 'Algeria',
#   'Year': 1953,
#   'Annual CO₂ emissions (per capita)': 0.409204},
#  {'Entity': 'Algeria',
#   'Year': 1954,
#   'Annual CO₂ emissions (per capita)': 0.4146334},
#  {'Entity': 'Algeria',
#   'Year': 1955,
#   'Annual CO₂ emissions (per capita)': 0.44953504},
#  {'Entity': 'Algeria',
#   'Year': 1956,
#   'Annual CO₂ emissions (per capita)': 0.47652793},
#  {'Entity': 'Algeria',
#   'Year': 1957,
#   'Annual CO₂ emissions (per capita)': 0.51663953},
#  {'Entity': 'Algeria',
#   'Year': 1958,
#   'Annual CO₂ emissions (per capita)': 0.47601697},
#  {'Entity': 'Algeria',
#   'Year': 1959,
#   'Annual CO₂ emissions (per capita)': 0.5055593},
#  {'Entity': 'Algeria',
#   'Year': 1960,
#   'Annual CO₂ emissions (per capita)': 0.5384051},
#  {'Entity': 'Algeria',
#   'Year': 1961,
#   'Annual CO₂ emissions (per capita)': 0.5207657},
#  {'Entity': 'Algeria',
#   'Year': 1962,
#   'Annual CO₂ emissions (per capita)': 0.47971538},
#  {'Entity': 'Algeria',
#   'Year': 1963,
#   'Annual CO₂ emissions (per capita)': 0.45227006},
#  {'Entity': 'Algeria',
#   'Year': 1964,
#   'Annual CO₂ emissions (per capita)': 0.46331143},
#  {'Entity': 'Algeria',
#   'Year': 1965,
#   'Annual CO₂ emissions (per capita)': 0.5327951},
#  {'Entity': 'Algeria',
#   'Year': 1966,
#   'Annual CO₂ emissions (per capita)': 0.6688496},
#  {'Entity': 'Algeria',
#   'Year': 1967,
#   'Annual CO₂ emissions (per capita)': 0.6548238},
#  {'Entity': 'Algeria',
#   'Year': 1968,
#   'Annual CO₂ emissions (per capita)': 0.6870493},
#  {'Entity': 'Algeria',
#   'Year': 1969,
#   'Annual CO₂ emissions (per capita)': 0.83578235},
#  {'Entity': 'Algeria',
#   'Year': 1970,
#   'Annual CO₂ emissions (per capita)': 1.0925175},
#  {'Entity': 'Algeria',
#   'Year': 1971,
#   'Annual CO₂ emissions (per capita)': 1.3227613},
#  {'Entity': 'Algeria',
#   'Year': 1972,
#   'Annual CO₂ emissions (per capita)': 1.9631587},
#  {'Entity': 'Algeria',
#   'Year': 1973,
#   'Annual CO₂ emissions (per capita)': 2.591362},
#  {'Entity': 'Algeria',
#   'Year': 1974,
#   'Annual CO₂ emissions (per capita)': 2.106363},
#  {'Entity': 'Algeria',
#   'Year': 1975,
#   'Annual CO₂ emissions (per capita)': 2.0410752},
#  {'Entity': 'Algeria',
#   'Year': 1976,
#   'Annual CO₂ emissions (per capita)': 2.3847072},
#  {'Entity': 'Algeria',
#   'Year': 1977,
#   'Annual CO₂ emissions (per capita)': 2.4591527},
#  {'Entity': 'Algeria',
#   'Year': 1978,
#   'Annual CO₂ emissions (per capita)': 3.5674498},
#  {'Entity': 'Algeria',
#   'Year': 1979,
#   'Annual CO₂ emissions (per capita)': 2.5251663},
#  {'Entity': 'Algeria',
#   'Year': 1980,
#   'Annual CO₂ emissions (per capita)': 3.5694008},
#  {'Entity': 'Algeria',
#   'Year': 1981,
#   'Annual CO₂ emissions (per capita)': 2.4110446},
#  {'Entity': 'Algeria',
#   'Year': 1982,
#   'Annual CO₂ emissions (per capita)': 1.9712327},
#  {'Entity': 'Algeria',
#   'Year': 1983,
#   'Annual CO₂ emissions (per capita)': 2.5539255},
#  {'Entity': 'Algeria',
#   'Year': 1984,
#   'Annual CO₂ emissions (per capita)': 3.3352125},
#  {'Entity': 'Algeria',
#   'Year': 1985,
#   'Annual CO₂ emissions (per capita)': 3.2991316},
#  {'Entity': 'Algeria',
#   'Year': 1986,
#   'Annual CO₂ emissions (per capita)': 3.3448546},
#  {'Entity': 'Algeria',
#   'Year': 1987,
#   'Annual CO₂ emissions (per capita)': 3.5780935},
#  {'Entity': 'Algeria',
#   'Year': 1988,
#   'Annual CO₂ emissions (per capita)': 3.4719887},
#  {'Entity': 'Algeria',
#   'Year': 1989,
#   'Annual CO₂ emissions (per capita)': 3.2239916},
#  {'Entity': 'Algeria',
#   'Year': 1990,
#   'Annual CO₂ emissions (per capita)': 3.0240455},
#  {'Entity': 'Algeria',
#   'Year': 1991,
#   'Annual CO₂ emissions (per capita)': 3.032439},
#  {'Entity': 'Algeria',
#   'Year': 1992,
#   'Annual CO₂ emissions (per capita)': 2.99991},
#  {'Entity': 'Algeria',
#   'Year': 1993,
#   'Annual CO₂ emissions (per capita)': 3.004137},
#  {'Entity': 'Algeria',
#   'Year': 1994,
#   'Annual CO₂ emissions (per capita)': 3.177377},
#  {'Entity': 'Algeria',
#   'Year': 1995,
#   'Annual CO₂ emissions (per capita)': 3.3992364},
#  {'Entity': 'Algeria',
#   'Year': 1996,
#   'Annual CO₂ emissions (per capita)': 3.4457092},
#  {'Entity': 'Algeria',
#   'Year': 1997,
#   'Annual CO₂ emissions (per capita)': 2.9875424},
#  {'Entity': 'Algeria',
#   'Year': 1998,
#   'Annual CO₂ emissions (per capita)': 3.544822},
#  {'Entity': 'Algeria',
#   'Year': 1999,
#   'Annual CO₂ emissions (per capita)': 3.000854},
#  {'Entity': 'Algeria',
#   'Year': 2000,
#   'Annual CO₂ emissions (per capita)': 2.7633605},
#  {'Entity': 'Algeria',
#   'Year': 2001,
#   'Annual CO₂ emissions (per capita)': 2.7716517},
#  {'Entity': 'Algeria',
#   'Year': 2002,
#   'Annual CO₂ emissions (per capita)': 2.856378},
#  {'Entity': 'Algeria',
#   'Year': 2003,
#   'Annual CO₂ emissions (per capita)': 2.9394941},
#  {'Entity': 'Algeria',
#   'Year': 2004,
#   'Annual CO₂ emissions (per capita)': 2.810881},
#  {'Entity': 'Algeria',
#   'Year': 2005,
#   'Annual CO₂ emissions (per capita)': 3.3523104},
#  {'Entity': 'Algeria',
#   'Year': 2006,
#   'Annual CO₂ emissions (per capita)': 3.1494687},
#  {'Entity': 'Algeria',
#   'Year': 2007,
#   'Annual CO₂ emissions (per capita)': 3.214136},
#  {'Entity': 'Algeria',
#   'Year': 2008,
#   'Annual CO₂ emissions (per capita)': 3.1906118},
#  {'Entity': 'Algeria',
#   'Year': 2009,
#   'Annual CO₂ emissions (per capita)': 3.348967},
#  {'Entity': 'Algeria',
#   'Year': 2010,
#   'Annual CO₂ emissions (per capita)': 3.2704897},
#  {'Entity': 'Algeria',
#   'Year': 2011,
#   'Annual CO₂ emissions (per capita)': 3.3897867},
#  {'Entity': 'Algeria',
#   'Year': 2012,
#   'Annual CO₂ emissions (per capita)': 3.603934},
#  {'Entity': 'Algeria',
#   'Year': 2013,
#   'Annual CO₂ emissions (per capita)': 3.6649592},
#  {'Entity': 'Algeria',
#   'Year': 2014,
#   'Annual CO₂ emissions (per capita)': 3.8587592},
#  {'Entity': 'Algeria',
#   'Year': 2015,
#   'Annual CO₂ emissions (per capita)': 4.0002337},
#  {'Entity': 'Algeria',
#   'Year': 2016,
#   'Annual CO₂ emissions (per capita)': 3.879531},
#  {'Entity': 'Algeria',
#   'Year': 2017,
#   'Annual CO₂ emissions (per capita)': 3.9620204},
#  {'Entity': 'Algeria',
#   'Year': 2018,
#   'Annual CO₂ emissions (per capita)': 4.063172},
#  {'Entity': 'Algeria',
#   'Year': 2019,
#   'Annual CO₂ emissions (per capita)': 4.1554093},
#  {'Entity': 'Algeria',
#   'Year': 2020,
#   'Annual CO₂ emissions (per capita)': 3.8185709},
#  {'Entity': 'Algeria',
#   'Year': 2021,
#   'Annual CO₂ emissions (per capita)': 4.01233},
#  {'Entity': 'Algeria',
#   'Year': 2022,
#   'Annual CO₂ emissions (per capita)': 4.058238},
#  {'Entity': 'Algeria',
#   'Year': 2023,
#   'Annual CO₂ emissions (per capita)': 3.858676},
#  {'Entity': 'Andorra',
#   'Year': 1990,
#   'Annual CO₂ emissions (per capita)': 7.729664},
#  {'Entity': 'Andorra',
#   'Year': 1991,
#   'Annual CO₂ emissions (per capita)': 7.173922},
#  {'Entity': 'Andorra',
#   'Year': 1992,
#   'Annual CO₂ emissions (per capita)': 6.754085},
#  {'Entity': 'Andorra',
#   'Year': 1993,
#   'Annual CO₂ emissions (per capita)': 6.483624},
#  {'Entity': 'Andorra',
#   'Year': 1994,
#   'Annual CO₂ emissions (per capita)': 6.292805},
#  {'Entity': 'Andorra',
#   'Year': 1995,
#   'Annual CO₂ emissions (per capita)': 6.647752},
#  {'Entity': 'Andorra',
#   'Year': 1996,
#   'Annual CO₂ emissions (per capita)': 7.0981126},
#  {'Entity': 'Andorra',
#   'Year': 1997,
#   'Annual CO₂ emissions (per capita)': 7.189753},
#  {'Entity': 'Andorra',
#   'Year': 1998,
#   'Annual CO₂ emissions (per capita)': 7.507393},
#  {'Entity': 'Andorra',
#   'Year': 1999,
#   'Annual CO₂ emissions (per capita)': 7.80381},
#  {'Entity': 'Andorra',
#   'Year': 2000,
#   'Annual CO₂ emissions (per capita)': 7.974552},
#  {'Entity': 'Andorra',
#   'Year': 2001,
#   'Annual CO₂ emissions (per capita)': 7.953851},
#  {'Entity': 'Andorra',
#   'Year': 2002,
#   'Annual CO₂ emissions (per capita)': 7.9858103},
#  {'Entity': 'Andorra',
#   'Year': 2003,
#   'Annual CO₂ emissions (per capita)': 7.696261},
#  {'Entity': 'Andorra',
#   'Year': 2004,
#   'Annual CO₂ emissions (per capita)': 7.540717},
#  {'Entity': 'Andorra',
#   'Year': 2005,
#   'Annual CO₂ emissions (per capita)': 7.4286895},
#  {'Entity': 'Andorra',
#   'Year': 2006,
#   'Annual CO₂ emissions (per capita)': 6.857717},
#  {'Entity': 'Andorra',
#   'Year': 2007,
#   'Annual CO₂ emissions (per capita)': 6.5764103},
#  {'Entity': 'Andorra',
#   'Year': 2008,
#   'Annual CO₂ emissions (per capita)': 6.449391},
#  {'Entity': 'Andorra',
#   'Year': 2009,
#   'Annual CO₂ emissions (per capita)': 6.1570287},
#  {'Entity': 'Andorra',
#   'Year': 2010,
#   'Annual CO₂ emissions (per capita)': 6.399722},
#  {'Entity': 'Andorra',
#   'Year': 2011,
#   'Annual CO₂ emissions (per capita)': 6.310664},
#  {'Entity': 'Andorra',
#   'Year': 2012,
#   'Annual CO₂ emissions (per capita)': 6.34042},
#  {'Entity': 'Andorra',
#   'Year': 2013,
#   'Annual CO₂ emissions (per capita)': 6.3323584},
#  {'Entity': 'Andorra',
#   'Year': 2014,
#   'Annual CO₂ emissions (per capita)': 6.2594266},
#  {'Entity': 'Andorra',
#   'Year': 2015,
#   'Annual CO₂ emissions (per capita)': 6.445522},
#  {'Entity': 'Andorra',
#   'Year': 2016,
#   'Annual CO₂ emissions (per capita)': 6.496004},
#  {'Entity': 'Andorra',
#   'Year': 2017,
#   'Annual CO₂ emissions (per capita)': 6.3565416},
#  {'Entity': 'Andorra',
#   'Year': 2018,
#   'Annual CO₂ emissions (per capita)': 6.6279693},
#  {'Entity': 'Andorra',
#   'Year': 2019,
#   'Annual CO₂ emissions (per capita)': 6.418742},
#  {'Entity': 'Andorra',
#   'Year': 2020,
#   'Annual CO₂ emissions (per capita)': 4.9233313},
#  {'Entity': 'Andorra',
#   'Year': 2021,
#   'Annual CO₂ emissions (per capita)': 5.235955},
#  {'Entity': 'Andorra',
#   'Year': 2022,
#   'Annual CO₂ emissions (per capita)': 5.2628007},
#  {'Entity': 'Andorra',
#   'Year': 2023,
#   'Annual CO₂ emissions (per capita)': 5.2415543},
#  {'Entity': 'Angola',
#   'Year': 1950,
#   'Annual CO₂ emissions (per capita)': 0.041052148},
#  {'Entity': 'Angola',
#   'Year': 1951,
#   'Annual CO₂ emissions (per capita)': 0.05413327},
#  {'Entity': 'Angola',
#   'Year': 1952,
#   'Annual CO₂ emissions (per capita)': 0.06695197},
#  {'Entity': 'Angola',
#   'Year': 1953,
#   'Annual CO₂ emissions (per capita)': 0.058363814},
#  {'Entity': 'Angola',
#   'Year': 1954,
#   'Annual CO₂ emissions (per capita)': 0.072986096},
#  {'Entity': 'Angola',
#   'Year': 1955,
#   'Annual CO₂ emissions (per capita)': 0.085610256},
#  {'Entity': 'Angola',
#   'Year': 1956,
#   'Annual CO₂ emissions (per capita)': 0.102280356},
#  {'Entity': 'Angola',
#   'Year': 1957,
#   'Annual CO₂ emissions (per capita)': 0.12421689},
#  {'Entity': 'Angola',
#   'Year': 1958,
#   'Annual CO₂ emissions (per capita)': 0.1171446},
#  {'Entity': 'Angola',
#   'Year': 1959,
#   'Annual CO₂ emissions (per capita)': 0.12022921},
#  {'Entity': 'Angola',
#   'Year': 1960,
#   'Annual CO₂ emissions (per capita)': 0.10492857},
#  {'Entity': 'Angola',
#   'Year': 1961,
#   'Annual CO₂ emissions (per capita)': 0.085579515},
#  {'Entity': 'Angola',
#   'Year': 1962,
#   'Annual CO₂ emissions (per capita)': 0.22022},
#  {'Entity': 'Angola',
#   'Year': 1963,
#   'Annual CO₂ emissions (per capita)': 0.21258354},
#  {'Entity': 'Angola',
#   'Year': 1964,
#   'Annual CO₂ emissions (per capita)': 0.2238053},
#  {'Entity': 'Angola',
#   'Year': 1965,
#   'Annual CO₂ emissions (per capita)': 0.21480599},
#  {'Entity': 'Angola',
#   'Year': 1966,
#   'Annual CO₂ emissions (per capita)': 0.27815032},
#  {'Entity': 'Angola',
#   'Year': 1967,
#   'Annual CO₂ emissions (per capita)': 0.17579734},
#  {'Entity': 'Angola',
#   'Year': 1968,
#   'Annual CO₂ emissions (per capita)': 0.29276264},
#  {'Entity': 'Angola',
#   'Year': 1969,
#   'Annual CO₂ emissions (per capita)': 0.4828663},
#  {'Entity': 'Angola',
#   'Year': 1970,
#   'Annual CO₂ emissions (per capita)': 0.6113181},
#  {'Entity': 'Angola',
#   'Year': 1971,
#   'Annual CO₂ emissions (per capita)': 0.5684056},
#  {'Entity': 'Angola',
#   'Year': 1972,
#   'Annual CO₂ emissions (per capita)': 0.72891736},
#  {'Entity': 'Angola',
#   'Year': 1973,
#   'Annual CO₂ emissions (per capita)': 0.76287675},
#  {'Entity': 'Angola',
#   'Year': 1974,
#   'Annual CO₂ emissions (per capita)': 0.7358424},
#  {'Entity': 'Angola',
#   'Year': 1975,
#   'Annual CO₂ emissions (per capita)': 0.644285},
#  {'Entity': 'Angola',
#   'Year': 1976,
#   'Annual CO₂ emissions (per capita)': 0.46363193},
#  {'Entity': 'Angola',
#   'Year': 1977,
#   'Annual CO₂ emissions (per capita)': 0.4820429},
#  {'Entity': 'Angola',
#   'Year': 1978,
#   'Annual CO₂ emissions (per capita)': 0.71268207},
#  {'Entity': 'Angola',
#   'Year': 1979,
#   'Annual CO₂ emissions (per capita)': 0.6995088},
#  {'Entity': 'Angola',
#   'Year': 1980,
#   'Annual CO₂ emissions (per capita)': 0.65581983},
#  {'Entity': 'Angola',
#   'Year': 1981,
#   'Annual CO₂ emissions (per capita)': 0.62435055},
#  {'Entity': 'Angola',
#   'Year': 1982,
#   'Annual CO₂ emissions (per capita)': 0.5296347},
#  {'Entity': 'Angola',
#   'Year': 1983,
#   'Annual CO₂ emissions (per capita)': 0.56154835},
#  {'Entity': 'Angola',
#   'Year': 1984,
#   'Annual CO₂ emissions (per capita)': 0.5289506},
#  {'Entity': 'Angola',
#   'Year': 1985,
#   'Annual CO₂ emissions (per capita)': 0.47817305},
#  {'Entity': 'Angola',
#   'Year': 1986,
#   'Annual CO₂ emissions (per capita)': 0.45701063},
#  {'Entity': 'Angola',
#   'Year': 1987,
#   'Annual CO₂ emissions (per capita)': 0.5511625},
#  {'Entity': 'Angola',
#   'Year': 1988,
#   'Annual CO₂ emissions (per capita)': 0.46488962},
#  {'Entity': 'Angola',
#   'Year': 1989,
#   'Annual CO₂ emissions (per capita)': 0.43802312},
#  {'Entity': 'Angola',
#   'Year': 1990,
#   'Annual CO₂ emissions (per capita)': 0.43778658},
#  {'Entity': 'Angola',
#   'Year': 1991,
#   'Annual CO₂ emissions (per capita)': 0.42117852},
#  {'Entity': 'Angola',
#   'Year': 1992,
#   'Annual CO₂ emissions (per capita)': 0.41569275},
#  {'Entity': 'Angola',
#   'Year': 1993,
#   'Annual CO₂ emissions (per capita)': 0.44814286},
#  {'Entity': 'Angola',
#   'Year': 1994,
#   'Annual CO₂ emissions (per capita)': 0.8568643},
#  {'Entity': 'Angola',
#   'Year': 1995,
#   'Annual CO₂ emissions (per capita)': 0.92093813},
#  {'Entity': 'Angola',
#   'Year': 1996,
#   'Annual CO₂ emissions (per capita)': 1.0760698},
#  {'Entity': 'Angola',
#   'Year': 1997,
#   'Annual CO₂ emissions (per capita)': 1.0834785},
#  {'Entity': 'Angola',
#   'Year': 1998,
#   'Annual CO₂ emissions (per capita)': 1.0893122},
#  {'Entity': 'Angola',
#   'Year': 1999,
#   'Annual CO₂ emissions (per capita)': 1.1017438},
#  {'Entity': 'Angola',
#   'Year': 2000,
#   'Annual CO₂ emissions (per capita)': 0.987665},
#  {'Entity': 'Angola',
#   'Year': 2001,
#   'Annual CO₂ emissions (per capita)': 0.94991744},
#  {'Entity': 'Angola',
#   'Year': 2002,
#   'Annual CO₂ emissions (per capita)': 0.92799395},
#  {'Entity': 'Angola',
#   'Year': 2003,
#   'Annual CO₂ emissions (per capita)': 0.9744039},
#  {'Entity': 'Angola',
#   'Year': 2004,
#   'Annual CO₂ emissions (per capita)': 0.914801},
#  {'Entity': 'Angola',
#   'Year': 2005,
#   'Annual CO₂ emissions (per capita)': 0.7976098},
#  {'Entity': 'Angola',
#   'Year': 2006,
#   'Annual CO₂ emissions (per capita)': 0.85658747},
#  {'Entity': 'Angola',
#   'Year': 2007,
#   'Annual CO₂ emissions (per capita)': 0.846446},
#  {'Entity': 'Angola',
#   'Year': 2008,
#   'Annual CO₂ emissions (per capita)': 0.86892146},
#  {'Entity': 'Angola',
#   'Year': 2009,
#   'Annual CO₂ emissions (per capita)': 0.9220852},
#  {'Entity': 'Angola',
#   'Year': 2010,
#   'Annual CO₂ emissions (per capita)': 0.9866279},
#  {'Entity': 'Angola',
#   'Year': 2011,
#   'Annual CO₂ emissions (per capita)': 0.9660866},
#  {'Entity': 'Angola',
#   'Year': 2012,
#   'Annual CO₂ emissions (per capita)': 1.0303272},
#  {'Entity': 'Angola',
#   'Year': 2013,
#   'Annual CO₂ emissions (per capita)': 0.9825774},
#  {'Entity': 'Angola',
#   'Year': 2014,
#   'Annual CO₂ emissions (per capita)': 0.96059257},
#  {'Entity': 'Angola',
#   'Year': 2015,
#   'Annual CO₂ emissions (per capita)': 0.9768856},
#  {'Entity': 'Angola',
#   'Year': 2016,
#   'Annual CO₂ emissions (per capita)': 0.87261665},
#  {'Entity': 'Angola',
#   'Year': 2017,
#   'Annual CO₂ emissions (per capita)': 0.78040165},
#  {'Entity': 'Angola',
#   'Year': 2018,
#   'Annual CO₂ emissions (per capita)': 0.7446486},
#  {'Entity': 'Angola',
#   'Year': 2019,
#   'Annual CO₂ emissions (per capita)': 0.6809788},
#  {'Entity': 'Angola',
#   'Year': 2020,
#   'Annual CO₂ emissions (per capita)': 0.49424314},
#  {'Entity': 'Angola',
#   'Year': 2021,
#   'Annual CO₂ emissions (per capita)': 0.55587107},
#  {'Entity': 'Angola',
#   'Year': 2022,
#   'Annual CO₂ emissions (per capita)': 0.56826746},
#  {'Entity': 'Angola',
#   'Year': 2023,
#   'Annual CO₂ emissions (per capita)': 0.5654583},
#  {'Entity': 'Anguilla',
#   'Year': 1990,
#   'Annual CO₂ emissions (per capita)': 5.655664},
#  {'Entity': 'Anguilla',
#   'Year': 1991,
#   'Annual CO₂ emissions (per capita)': 5.4573784},
#  {'Entity': 'Anguilla',
#   'Year': 1992,
#   'Annual CO₂ emissions (per capita)': 5.289506},
#  {'Entity': 'Anguilla',
#   'Year': 1993,
#   'Annual CO₂ emissions (per capita)': 5.940337},
#  {'Entity': 'Anguilla',
#   'Year': 1994,
#   'Annual CO₂ emissions (per capita)': 5.79197},
#  {'Entity': 'Anguilla',
#   'Year': 1995,
#   'Annual CO₂ emissions (per capita)': 6.0201273},
#  {'Entity': 'Anguilla',
#   'Year': 1996,
#   'Annual CO₂ emissions (per capita)': 6.2288},
# ...
#  {'Entity': 'Armenia',
#   'Year': 1876,
#   'Annual CO₂ emissions (per capita)': 0.027936064},
#  {'Entity': 'Armenia',
#   'Year': 1877,
#   'Annual CO₂ emissions (per capita)': 0.028246393},
#  {'Entity': 'Armenia',
#   'Year': 1878,
#   'Annual CO₂ emissions (per capita)': 0.036576033},
#  {'Entity': 'Armenia',
#   'Year': 1879,
#   'Annual CO₂ emissions (per capita)': 0.03718469},
#  {'Entity': 'Armenia',
#   'Year': 1880,
#   'Annual CO₂ emissions (per capita)': 0.043220297},
#  {'Entity': 'Armenia',
#   'Year': 1881,
#   'Annual CO₂ emissions (per capita)': 0.045103792},
#  {'Entity': 'Armenia',
#   'Year': 1882,
#   'Annual CO₂ emissions (per capita)': 0.047072086},
#  {'Entity': 'Armenia',
#   'Year': 1883,
#   'Annual CO₂ emissions (per capita)': 0.053082146},
#  {'Entity': 'Armenia',
#   'Year': 1884,
#   'Annual CO₂ emissions (per capita)': 0.053399507},
#  {'Entity': 'Armenia',
#   'Year': 1885,
#   'Annual CO₂ emissions (per capita)': 0.057628326},
#  {'Entity': 'Armenia',
#   'Year': 1886,
#   'Annual CO₂ emissions (per capita)': 0.05856153},
#  {'Entity': 'Armenia',
#   'Year': 1887,
#   'Annual CO₂ emissions (per capita)': 0.06139699},
#  {'Entity': 'Armenia',
#   'Year': 1888,
#   'Annual CO₂ emissions (per capita)': 0.06345299},
#  {'Entity': 'Armenia',
#   'Year': 1889,
#   'Annual CO₂ emissions (per capita)': 0.06789629},
#  {'Entity': 'Armenia',
#   'Year': 1890,
#   'Annual CO₂ emissions (per capita)': 0.076182574},
#  {'Entity': 'Armenia',
#   'Year': 1891,
#   'Annual CO₂ emissions (per capita)': 0.08310829},
#  {'Entity': 'Armenia',
#   'Year': 1892,
#   'Annual CO₂ emissions (per capita)': 0.08716196},
#  {'Entity': 'Armenia',
#   'Year': 1893,
#   'Annual CO₂ emissions (per capita)': 0.101224035},
#  {'Entity': 'Armenia',
#   'Year': 1894,
#   'Annual CO₂ emissions (per capita)': 0.10214635},
#  {'Entity': 'Armenia',
#   'Year': 1895,
#   'Annual CO₂ emissions (per capita)': 0.11628942},
#  {'Entity': 'Armenia',
#   'Year': 1896,
#   'Annual CO₂ emissions (per capita)': 0.1172928},
#  {'Entity': 'Armenia',
#   'Year': 1897,
#   'Annual CO₂ emissions (per capita)': 0.13436683},
#  {'Entity': 'Armenia',
#   'Year': 1898,
#   'Annual CO₂ emissions (per capita)': 0.14931008},
#  {'Entity': 'Armenia',
#   'Year': 1899,
#   'Annual CO₂ emissions (per capita)': 0.17161825},
#  {'Entity': 'Armenia',
#   'Year': 1900,
#   'Annual CO₂ emissions (per capita)': 0.19262141},
#  {'Entity': 'Armenia',
#   'Year': 1901,
#   'Annual CO₂ emissions (per capita)': 0.1959334},
#  {'Entity': 'Armenia',
#   'Year': 1902,
#   'Annual CO₂ emissions (per capita)': 0.18749787},
#  {'Entity': 'Armenia',
#   'Year': 1903,
#   'Annual CO₂ emissions (per capita)': 0.18172158},
#  {'Entity': 'Armenia',
#   'Year': 1904,
#   'Annual CO₂ emissions (per capita)': 0.20031929},
#  {'Entity': 'Armenia',
#   'Year': 1905,
#   'Annual CO₂ emissions (per capita)': 0.17716438},
#  {'Entity': 'Armenia',
#   'Year': 1906,
#   'Annual CO₂ emissions (per capita)': 0.20021743},
#  {'Entity': 'Armenia',
#   'Year': 1907,
#   'Annual CO₂ emissions (per capita)': 0.22219701},
#  {'Entity': 'Armenia',
#   'Year': 1908,
#   'Annual CO₂ emissions (per capita)': 0.22150344},
#  {'Entity': 'Armenia',
#   'Year': 1909,
#   'Annual CO₂ emissions (per capita)': 0.23167102},
#  {'Entity': 'Armenia',
#   'Year': 1910,
#   'Annual CO₂ emissions (per capita)': 0.22510841},
#  {'Entity': 'Armenia',
#   'Year': 1911,
#   'Annual CO₂ emissions (per capita)': 0.2312406},
#  {'Entity': 'Armenia',
#   'Year': 1912,
#   'Annual CO₂ emissions (per capita)': 0.25953275},
#  {'Entity': 'Armenia',
#   'Year': 1913,
#   'Annual CO₂ emissions (per capita)': 0.27934095},
#  {'Entity': 'Armenia',
#   'Year': 1914,
#   'Annual CO₂ emissions (per capita)': 0.2497916},
#  {'Entity': 'Armenia',
#   'Year': 1915,
#   'Annual CO₂ emissions (per capita)': 0.22716497},
#  {'Entity': 'Armenia',
#   'Year': 1916,
#   'Annual CO₂ emissions (per capita)': 0.23989041},
#  {'Entity': 'Armenia',
#   'Year': 1917,
#   'Annual CO₂ emissions (per capita)': 0.21874508},
#  {'Entity': 'Armenia',
#   'Year': 1918,
#   'Annual CO₂ emissions (per capita)': 0.086444},
#  {'Entity': 'Armenia',
#   'Year': 1919,
#   'Annual CO₂ emissions (per capita)': 0.07316447},
#  {'Entity': 'Armenia',
#   'Year': 1920,
#   'Annual CO₂ emissions (per capita)': 0.066110395},
#  {'Entity': 'Armenia',
#   'Year': 1921,
#   'Annual CO₂ emissions (per capita)': 0.07104394},
#  {'Entity': 'Armenia',
#   'Year': 1922,
#   'Annual CO₂ emissions (per capita)': 0.085854314},
#  {'Entity': 'Armenia',
#   'Year': 1923,
#   'Annual CO₂ emissions (per capita)': 0.09397665},
#  {'Entity': 'Armenia',
#   'Year': 1924,
#   'Annual CO₂ emissions (per capita)': 0.11094613},
#  {'Entity': 'Armenia',
#   'Year': 1925,
#   'Annual CO₂ emissions (per capita)': 0.10850647},
#  {'Entity': 'Armenia',
#   'Year': 1926,
#   'Annual CO₂ emissions (per capita)': 0.15578502},
#  {'Entity': 'Armenia',
#   'Year': 1927,
#   'Annual CO₂ emissions (per capita)': 0.19192174},
#  {'Entity': 'Armenia',
#   'Year': 1928,
#   'Annual CO₂ emissions (per capita)': 0.208783},
#  {'Entity': 'Armenia',
#   'Year': 1929,
#   'Annual CO₂ emissions (per capita)': 0.22284374},
#  {'Entity': 'Armenia',
#   'Year': 1930,
#   'Annual CO₂ emissions (per capita)': 0.30155143},
#  {'Entity': 'Armenia',
#   'Year': 1931,
#   'Annual CO₂ emissions (per capita)': 0.35929063},
#  {'Entity': 'Armenia',
#   'Year': 1932,
#   'Annual CO₂ emissions (per capita)': 0.40053102},
#  {'Entity': 'Armenia',
#   'Year': 1933,
#   'Annual CO₂ emissions (per capita)': 0.444208},
#  {'Entity': 'Armenia',
#   'Year': 1934,
#   'Annual CO₂ emissions (per capita)': 0.5318963},
#  {'Entity': 'Armenia',
#   'Year': 1935,
#   'Annual CO₂ emissions (per capita)': 0.59568447},
#  {'Entity': 'Armenia',
#   'Year': 1936,
#   'Annual CO₂ emissions (per capita)': 0.67567515},
#  {'Entity': 'Armenia',
#   'Year': 1937,
#   'Annual CO₂ emissions (per capita)': 0.6854013},
#  {'Entity': 'Armenia',
#   'Year': 1938,
#   'Annual CO₂ emissions (per capita)': 0.7169203},
#  {'Entity': 'Armenia',
#   'Year': 1939,
#   'Annual CO₂ emissions (per capita)': 0.71914864},
#  {'Entity': 'Armenia',
#   'Year': 1940,
#   'Annual CO₂ emissions (per capita)': 0.85441315},
#  {'Entity': 'Armenia',
#   'Year': 1941,
#   'Annual CO₂ emissions (per capita)': 0.7437685},
#  {'Entity': 'Armenia',
#   'Year': 1942,
#   'Annual CO₂ emissions (per capita)': 0.4043868},
#  {'Entity': 'Armenia',
#   'Year': 1943,
#   'Annual CO₂ emissions (per capita)': 0.4182036},
#  {'Entity': 'Armenia',
#   'Year': 1944,
#   'Annual CO₂ emissions (per capita)': 0.60095894},
#  {'Entity': 'Armenia',
#   'Year': 1945,
#   'Annual CO₂ emissions (per capita)': 0.62768173},
#  {'Entity': 'Armenia',
#   'Year': 1946,
#   'Annual CO₂ emissions (per capita)': 0.6970409},
#  {'Entity': 'Armenia',
#   'Year': 1947,
#   'Annual CO₂ emissions (per capita)': 0.8307709},
#  {'Entity': 'Armenia',
#   'Year': 1948,
#   'Annual CO₂ emissions (per capita)': 0.87428486},
#  {'Entity': 'Armenia',
#   'Year': 1949,
#   'Annual CO₂ emissions (per capita)': 0.9797033},
#  {'Entity': 'Armenia',
#   'Year': 1950,
#   'Annual CO₂ emissions (per capita)': 1.0717827},
#  {'Entity': 'Armenia',
#   'Year': 1951,
#   'Annual CO₂ emissions (per capita)': 1.132164},
#  {'Entity': 'Armenia',
#   'Year': 1952,
#   'Annual CO₂ emissions (per capita)': 1.1814523},
#  {'Entity': 'Armenia',
#   'Year': 1953,
#   'Annual CO₂ emissions (per capita)': 1.2165011},
#  {'Entity': 'Armenia',
#   'Year': 1954,
#   'Annual CO₂ emissions (per capita)': 1.2907404},
#  {'Entity': 'Armenia',
#   'Year': 1955,
#   'Annual CO₂ emissions (per capita)': 1.4212903},
#  {'Entity': 'Armenia',
#   'Year': 1956,
#   'Annual CO₂ emissions (per capita)': 1.5127524},
#  {'Entity': 'Armenia',
#   'Year': 1957,
#   'Annual CO₂ emissions (per capita)': 1.603501},
#  {'Entity': 'Armenia',
#   'Year': 1958,
#   'Annual CO₂ emissions (per capita)': 1.6566873},
#  {'Entity': 'Armenia',
#   'Year': 1959,
#   'Annual CO₂ emissions (per capita)': 1.6836356},
#  {'Entity': 'Armenia',
#   'Year': 1960,
#   'Annual CO₂ emissions (per capita)': 1.6943232},
#  {'Entity': 'Armenia',
#   'Year': 1961,
#   'Annual CO₂ emissions (per capita)': 1.6914318},
#  {'Entity': 'Armenia',
#   'Year': 1962,
#   'Annual CO₂ emissions (per capita)': 1.7206311},
#  {'Entity': 'Armenia',
#   'Year': 1963,
#   'Annual CO₂ emissions (per capita)': 1.789897},
#  {'Entity': 'Armenia',
#   'Year': 1964,
#   'Annual CO₂ emissions (per capita)': 1.8479961},
#  {'Entity': 'Armenia',
#   'Year': 1965,
#   'Annual CO₂ emissions (per capita)': 1.9042565},
#  {'Entity': 'Armenia',
#   'Year': 1966,
#   'Annual CO₂ emissions (per capita)': 1.9558038},
#  {'Entity': 'Armenia',
#   'Year': 1967,
#   'Annual CO₂ emissions (per capita)': 1.9929898},
#  {'Entity': 'Armenia',
#   'Year': 1968,
#   'Annual CO₂ emissions (per capita)': 1.9994712},
#  {'Entity': 'Armenia',
#   'Year': 1969,
#   'Annual CO₂ emissions (per capita)': 2.0352886},
#  {'Entity': 'Armenia',
#   'Year': 1970,
#   'Annual CO₂ emissions (per capita)': 2.095544},
#  {'Entity': 'Armenia',
#   'Year': 1971,
#   'Annual CO₂ emissions (per capita)': 2.1839848},
#  {'Entity': 'Armenia',
#   'Year': 1972,
#   'Annual CO₂ emissions (per capita)': 2.2544599},
#  {'Entity': 'Armenia',
#   'Year': 1973,
#   'Annual CO₂ emissions (per capita)': 2.3049057},
#  {'Entity': 'Armenia',
#   'Year': 1974,
#   'Annual CO₂ emissions (per capita)': 2.3466234},
#  {'Entity': 'Armenia',
#   'Year': 1975,
#   'Annual CO₂ emissions (per capita)': 2.4179263},
#  {'Entity': 'Armenia',
#   'Year': 1976,
#   'Annual CO₂ emissions (per capita)': 2.4453003},
#  {'Entity': 'Armenia',
#   'Year': 1977,
#   'Annual CO₂ emissions (per capita)': 2.4472914},
#  {'Entity': 'Armenia',
#   'Year': 1978,
#   'Annual CO₂ emissions (per capita)': 2.4490037},
#  {'Entity': 'Armenia',
#   'Year': 1979,
#   'Annual CO₂ emissions (per capita)': 2.4165142},
#  {'Entity': 'Armenia',
#   'Year': 1980,
#   'Annual CO₂ emissions (per capita)': 2.4877446},
#  {'Entity': 'Armenia',
#   'Year': 1981,
#   'Annual CO₂ emissions (per capita)': 2.4227333},
#  {'Entity': 'Armenia',
#   'Year': 1982,
#   'Annual CO₂ emissions (per capita)': 2.4471617},
#  {'Entity': 'Armenia',
#   'Year': 1983,
#   'Annual CO₂ emissions (per capita)': 2.4616923},
#  {'Entity': 'Armenia',
#   'Year': 1984,
#   'Annual CO₂ emissions (per capita)': 2.459555},
#  {'Entity': 'Armenia',
#   'Year': 1985,
#   'Annual CO₂ emissions (per capita)': 2.6211855},
#  {'Entity': 'Armenia',
#   'Year': 1986,
#   'Annual CO₂ emissions (per capita)': 2.4698956},
#  {'Entity': 'Armenia',
#   'Year': 1987,
#   'Annual CO₂ emissions (per capita)': 2.4531863},
#  {'Entity': 'Armenia',
#   'Year': 1988,
#   'Annual CO₂ emissions (per capita)': 2.7702122},
#  {'Entity': 'Armenia',
#   'Year': 1989,
#   'Annual CO₂ emissions (per capita)': 2.7342727},
#  {'Entity': 'Armenia',
#   'Year': 1990,
#   'Annual CO₂ emissions (per capita)': 2.5334725},
#  {'Entity': 'Armenia',
#   'Year': 1991,
#   'Annual CO₂ emissions (per capita)': 2.0420172},
#  {'Entity': 'Armenia',
#   'Year': 1992,
#   'Annual CO₂ emissions (per capita)': 1.6024379},
#  {'Entity': 'Armenia',
#   'Year': 1993,
#   'Annual CO₂ emissions (per capita)': 0.7269045},
#  {'Entity': 'Armenia',
#   'Year': 1994,
#   'Annual CO₂ emissions (per capita)': 0.7979213},
#  {'Entity': 'Armenia',
#   'Year': 1995,
#   'Annual CO₂ emissions (per capita)': 1.0166614},
#  {'Entity': 'Armenia',
#   'Year': 1996,
#   'Annual CO₂ emissions (per capita)': 0.7625837},
#  {'Entity': 'Armenia',
#   'Year': 1997,
#   'Annual CO₂ emissions (per capita)': 1.0019927},
#  {'Entity': 'Armenia',
#   'Year': 1998,
#   'Annual CO₂ emissions (per capita)': 1.0656695},
#  {'Entity': 'Armenia',
#   'Year': 1999,
#   'Annual CO₂ emissions (per capita)': 0.9598779},
#  {'Entity': 'Armenia',
#   'Year': 2000,
#   'Annual CO₂ emissions (per capita)': 1.117025},
#  {'Entity': 'Armenia',
#   'Year': 2001,
#   'Annual CO₂ emissions (per capita)': 1.1453632},
#  {'Entity': 'Armenia',
#   'Year': 2002,
#   'Annual CO₂ emissions (per capita)': 1.0069243},
#  {'Entity': 'Armenia',
#   'Year': 2003,
#   'Annual CO₂ emissions (per capita)': 1.1370804},
#  {'Entity': 'Armenia',
#   'Year': 2004,
#   'Annual CO₂ emissions (per capita)': 1.2212219},
#  {'Entity': 'Armenia',
#   'Year': 2005,
#   'Annual CO₂ emissions (per capita)': 1.4556371},
#  {'Entity': 'Armenia',
#   'Year': 2006,
#   'Annual CO₂ emissions (per capita)': 1.4719211},
#  {'Entity': 'Armenia',
#   'Year': 2007,
#   'Annual CO₂ emissions (per capita)': 1.7144572},
#  {'Entity': 'Armenia',
#   'Year': 2008,
#   'Annual CO₂ emissions (per capita)': 1.8833776},
#  {'Entity': 'Armenia',
#   'Year': 2009,
#   'Annual CO₂ emissions (per capita)': 1.4813462},
#  {'Entity': 'Armenia',
#   'Year': 2010,
#   'Annual CO₂ emissions (per capita)': 1.4509143},
#  {'Entity': 'Armenia',
#   'Year': 2011,
#   'Annual CO₂ emissions (per capita)': 1.6997688},
#  {'Entity': 'Armenia',
#   'Year': 2012,
#   'Annual CO₂ emissions (per capita)': 1.9668766},
#  {'Entity': 'Armenia',
#   'Year': 2013,
#   'Annual CO₂ emissions (per capita)': 1.8939097},
#  {'Entity': 'Armenia',
#   'Year': 2014,
#   'Annual CO₂ emissions (per capita)': 1.917619},
#  {'Entity': 'Armenia',
#   'Year': 2015,
#   'Annual CO₂ emissions (per capita)': 1.8722998},
#  {'Entity': 'Armenia',
#   'Year': 2016,
#   'Annual CO₂ emissions (per capita)': 1.7825894},
#  {'Entity': 'Armenia',
#   'Year': 2017,
#   'Annual CO₂ emissions (per capita)': 1.9005886},
#  {'Entity': 'Armenia',
#   'Year': 2018,
#   'Annual CO₂ emissions (per capita)': 2.0008013},
#  {'Entity': 'Armenia',
#   'Year': 2019,
#   'Annual CO₂ emissions (per capita)': 2.1639683},
#  {'Entity': 'Armenia',
#   'Year': 2020,
#   'Annual CO₂ emissions (per capita)': 2.3506079},
#  {'Entity': 'Armenia',
#   'Year': 2021,
#   'Annual CO₂ emissions (per capita)': 2.5840561},
#  {'Entity': 'Armenia',
#   'Year': 2022,
#   'Annual CO₂ emissions (per capita)': 2.4869328},
#  {'Entity': 'Armenia',
#   'Year': 2023,
#   'Annual CO₂ emissions (per capita)': 2.58488},
#  {'Entity': 'Aruba', 'Year': 1930, 'Annual CO₂ emissions (per capita)': 0.0},
#  {'Entity': 'Aruba', 'Year': 1940, 'Annual CO₂ emissions (per capita)': 0.0},
#  {'Entity': 'Aruba',
#   'Year': 1950,
#   'Annual CO₂ emissions (per capita)': 9.577883},
#  {'Entity': 'Aruba',
#   'Year': 1951,
#   'Annual CO₂ emissions (per capita)': 14.721103},
#  {'Entity': 'Aruba',
#   'Year': 1952,
#   'Annual CO₂ emissions (per capita)': 8.278811},
#  {'Entity': 'Aruba',
#   'Year': 1953,
#   'Annual CO₂ emissions (per capita)': 9.329421},
#  {'Entity': 'Aruba',
#   'Year': 1954,
#   'Annual CO₂ emissions (per capita)': 18.375748},
#  {'Entity': 'Aruba',
#   'Year': 1955,
#   'Annual CO₂ emissions (per capita)': 14.804124},
#  {'Entity': 'Aruba',
#   'Year': 1956,
#   'Annual CO₂ emissions (per capita)': 18.6506},
#  {'Entity': 'Aruba',
#   'Year': 1957,
#   'Annual CO₂ emissions (per capita)': 12.416305},
#  {'Entity': 'Aruba',
#   'Year': 1958,
#   'Annual CO₂ emissions (per capita)': 10.60722},
#  {'Entity': 'Aruba',
#   'Year': 1959,
#   'Annual CO₂ emissions (per capita)': 13.320945},
#  {'Entity': 'Aruba',
#   'Year': 1960,
#   'Annual CO₂ emissions (per capita)': 11.259256},
#  {'Entity': 'Aruba',
#   'Year': 1961,
#   'Annual CO₂ emissions (per capita)': 11.611501},
#  {'Entity': 'Aruba',
#   'Year': 1962,
#   'Annual CO₂ emissions (per capita)': 12.584397},
#  {'Entity': 'Aruba',
#   'Year': 1963,
#   'Annual CO₂ emissions (per capita)': 11.910064},
#  {'Entity': 'Aruba',
#   'Year': 1964,
#   'Annual CO₂ emissions (per capita)': 11.455749},
#  {'Entity': 'Aruba',
#   'Year': 1965,
#   'Annual CO₂ emissions (per capita)': 10.177072},
#  {'Entity': 'Aruba',
#   'Year': 1966,
#   'Annual CO₂ emissions (per capita)': 9.43574},
#  {'Entity': 'Aruba',
#   'Year': 1967,
#   'Annual CO₂ emissions (per capita)': 11.563251},
#  {'Entity': 'Aruba',
#   'Year': 1968,
#   'Annual CO₂ emissions (per capita)': 10.738753},
#  {'Entity': 'Aruba',
#   'Year': 1969,
#   'Annual CO₂ emissions (per capita)': 14.058458},
#  {'Entity': 'Aruba',
#   'Year': 1970,
#   'Annual CO₂ emissions (per capita)': 15.750522},
#  {'Entity': 'Aruba',
#   'Year': 1971,
#   'Annual CO₂ emissions (per capita)': 13.747423},
#  {'Entity': 'Aruba',
#   'Year': 1972,
#   'Annual CO₂ emissions (per capita)': 13.304301},
#  {'Entity': 'Aruba',
#   'Year': 1973,
#   'Annual CO₂ emissions (per capita)': 14.623604},
#  {'Entity': 'Aruba',
#   'Year': 1974,
#   'Annual CO₂ emissions (per capita)': 13.103169},
#  {'Entity': 'Aruba',
#   'Year': 1975,
#   'Annual CO₂ emissions (per capita)': 9.382853},
#  {'Entity': 'Aruba',
#   'Year': 1976,
#   'Annual CO₂ emissions (per capita)': 19.890474},
#  {'Entity': 'Aruba',
#   'Year': 1977,
#   'Annual CO₂ emissions (per capita)': 10.348436},
#  ...]

# %% [markdown]
# ### Importing Data into MongoDB

# %%
carbon_emissions_db=carbon_emissions_client['CO2_Renew_Life_DB']

# %%
carbon_emissions_db.carbon_emissions.insert_many(carbon_emissions_data)
# Out:
# InsertManyResult([ObjectId('67f8bef4a4ad31e09201b659'), ObjectId('67f8bef4a4ad31e09201b65a'), ObjectId('67f8bef4a4ad31e09201b65b'), ObjectId('67f8bef4a4ad31e09201b65c'), ObjectId('67f8bef4a4ad31e09201b65d'), ObjectId('67f8bef4a4ad31e09201b65e'), ObjectId('67f8bef4a4ad31e09201b65f'), ObjectId('67f8bef4a4ad31e09201b660'), ObjectId('67f8bef4a4ad31e09201b661'), ObjectId('67f8bef4a4ad31e09201b662'), ObjectId('67f8bef4a4ad31e09201b663'), ObjectId('67f8bef4a4ad31e09201b664'), ObjectId('67f8bef4a4ad31e09201b665'), ObjectId('67f8bef4a4ad31e09201b666'), ObjectId('67f8bef4a4ad31e09201b667'), ObjectId('67f8bef4a4ad31e09201b668'), ObjectId('67f8bef4a4ad31e09201b669'), ObjectId('67f8bef4a4ad31e09201b66a'), ObjectId('67f8bef4a4ad31e09201b66b'), ObjectId('67f8bef4a4ad31
09201b6aa'), ObjectId('67f8bef4a4ad31e09201b6ab'), ObjectId('67f8bef4a4ad31e09201b6ac'), ObjectId('67f8bef4a4ad31e09201b6ad'), ObjectId('67f8bef4a4ad31e09201b6ae'), ObjectId('67f8bef4a4ad31e09201b6af'), ObjectId('67f8bef4a4ad31e09201b6b0'), ObjectId('67f8bef4a4ad31e09201b6b1'), ObjectId('67f8bef4a4ad31e09201b6b2'), ObjectId('67f8bef4a4ad31e09201b6b3'), ObjectId('67f8bef4a4ad31e09201b6b4'), ObjectId('67f8bef4a4ad31e09201b6b5'), ObjectId('67f8bef4a4ad31e09201b6b6'), ObjectId('67f8bef4a4ad31e09201b6b7'), ObjectId('67f8bef4a4ad31e09201b6b8'), ObjectId('67f8bef4a4ad31e09201b6b9'), ObjectId('67f8bef4a4ad31e09201b6ba'), ObjectId('67f8bef4a4ad31e09201b6bb'), ObjectId('67f8bef4a4ad31e09201b6bc'), ObjectId('67f8bef4a4ad31e09201b6bd'), ObjectId('67f8bef4a4ad31e09201b6be'), ObjectId('67f8bef4a4ad31e09201b6bf'), ObjectId('67f8bef4a4ad31e09201b6c0'), ObjectId('67f8bef4a4ad31e09201 ...

# %% [markdown]
# ### Connecting to MongoDB Server

# %%
renewable_energy_client = pymongo.MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# ### Loading Data for Renewable Energy

# %%
renewable_energy_df = pd.read_csv("renewable-share-energy.csv")

# %%
renewable_energy_df.shape
# Out:
# (4903, 4)

# %%
renewable_energy_df.head()
# Out:
#    Entity Code  Year  Renewables (% equivalent primary energy)
# 0  Africa  NaN  1965                                  5.740281
# 1  Africa  NaN  1966                                  6.113969
# 2  Africa  NaN  1967                                  6.316580
# 3  Africa  NaN  1968                                  6.994845
# 4  Africa  NaN  1969                                  7.943916

# %%
renewable_energy_df.tail()
# Out:
#      Entity      Code  Year  Renewables (% equivalent primary energy)
# 4898  World  OWID_WRL  2019                                 12.228147
# 4899  World  OWID_WRL  2020                                 13.404395
# 4900  World  OWID_WRL  2021                                 13.469198
# 4901  World  OWID_WRL  2022                                 14.119935
# 4902  World  OWID_WRL  2023                                 14.562141

# %%
renewable_energy_data = renewable_energy_df.to_dict(orient="records")

# %%
renewable_energy_data
# Out:
# [{'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 5.7402806},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 6.1139693},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.31658},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.994845},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 7.9439163},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 9.148895},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 8.124994},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 8.747272},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 8.54162},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 9.252387},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 9.228769},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 9.41638},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 9.803094},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 9.518462},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 9.349527},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 8.481442},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 7.8527517},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 7.3734274},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 6.456112},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 6.1585774},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 6.5793424},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 6.7159667},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 6.243963},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 6.3621163},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 6.66546},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 6.5857716},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 6.9810143},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 6.5694675},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 6.43179},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 6.3092456},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 6.306244},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 6.4332542},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 6.465725},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 6.676159},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 6.858631},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 7.2029395},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 7.4362373},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 7.671944},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 7.105203},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 6.980063},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 7.0285006},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 7.1611776},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 7.0572457},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 6.761787},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 6.810709},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 7.1290402},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 7.2594023},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.9972486},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 7.189637},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.5156765},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.527505},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 7.404274},
#  {'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)':
67f8bef5a4ad31e092021cf0'), ObjectId('67f8bef5a4ad31e092021cf1'), ObjectId('67f8bef5a4ad31e092021cf2'), ObjectId('67f8bef5a4ad31e092021cf3'), ObjectId('67f8bef5a4ad31e092021cf4'), ObjectId('67f8bef5a4ad31e092021cf5'), ObjectId('67f8bef5a4ad31e092021cf6'), ObjectId('67f8bef5a4ad31e092021cf7'), ObjectId('67f8bef5a4ad31e092021cf8'), ObjectId('67f8bef5a4ad31e092021cf9'), ObjectId('67f8bef5a4ad31e092021cfa'), ObjectId('67f8bef5a4ad31e092021cfb'), ObjectId('67f8bef5a4ad31e092021cfc'), ObjectId('67f8bef5a4ad31e092021cfd'), ObjectId('67f8bef5a4ad31e092021cfe'), ObjectId('67f8bef5a4ad31e092021cff'), ObjectId('67f8bef5a4ad31e092021d00'), ObjectId('67f8bef5a4ad31e092021d01'), ObjectId('67f8bef5a4ad31e092021d02'), ObjectId('67f8bef5a4ad31e092021d03'), ObjectId('67f8bef5a4ad31e092021d04'), ObjectId('67f8bef5a4ad31e092021d05'), ObjectId('67f8bef5a4ad31e092021d06'), ObjectId('67f8bef5a4ad31e092021d07'), ObjectId('67f8bef5a4ad31e09202 ...

# %% [markdown]
# ### Connecting to MongoDB Server

# %%
life_expectancy_client = pymongo.MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# ### Loading Data for Life Expentancy

# %%
life_expentancy_df = pd.read_csv("life_expentancy.csv")

# %%
life_expentancy_df.shape
# Out:
# (21565, 3)

# %%
life_expentancy_df.head()
# Out:
#        Country  Year  Life Expectancy
# 0  Afghanistan  1950          28.1563
# 1  Afghanistan  1951          28.5836
# 2  Afghanistan  1952          29.0138
# 3  Afghanistan  1953          29.4521
# 4  Afghanistan  1954          29.6975

# %%
life_expentancy_df.tail()
# Out:
#         Country  Year  Life Expectancy
# 21560  Zimbabwe  2019          61.0603
# 21561  Zimbabwe  2020          61.5300
# 21562  Zimbabwe  2021          60.1347
# 21563  Zimbabwe  2022          62.3601
# 21564  Zimbabwe  2023          62.7748

# %%
life_expentancy_data = life_expentancy_df.to_dict(orient="records")

# %%
life_expentancy_data
# Out:
# [{'Country': 'Afghanistan', 'Year': 1950, 'Life Expectancy': 28.1563},
#  {'Country': 'Afghanistan', 'Year': 1951, 'Life Expectancy': 28.5836},
#  {'Country': 'Afghanistan', 'Year': 1952, 'Life Expectancy': 29.0138},
#  {'Country': 'Afghanistan', 'Year': 1953, 'Life Expectancy': 29.4521},
#  {'Country': 'Afghanistan', 'Year': 1954, 'Life Expectancy': 29.6975},
#  {'Country': 'Afghanistan', 'Year': 1955, 'Life Expectancy': 30.366},
#  {'Country': 'Afghanistan', 'Year': 1956, 'Life Expectancy': 30.8303},
#  {'Country': 'Afghanistan', 'Year': 1957, 'Life Expectancy': 31.3451},
#  {'Country': 'Afghanistan', 'Year': 1958, 'Life Expectancy': 31.84},
#  {'Country': 'Afghanistan', 'Year': 1959, 'Life Expectancy': 32.3365},
#  {'Country': 'Afghanistan', 'Year': 1960, 'Life Expectancy': 32.7987},
#  {'Country': 'Albania', 'Year': 1963, 'Life Expectancy': 59.4792},
#  {'Country': 'Albania', 'Year': 1964, 'Life Expectancy': 60.4035},
#  {'Country': 'Albania', 'Year': 1965, 'Life Expectancy': 61.2735},
#  {'Country': 'Albania', 'Year': 1966, 'Life Expectancy': 62.149},
#  {'Country': 'Albania', 'Year': 1967, 'Life Expectancy': 62.976},
#  {'Country': 'Albania', 'Year': 1968, 'Life Expectancy': 63.7876},
#  {'Country': 'Albania', 'Year': 1969, 'Life Expectancy': 64.5384},
#  {'Country': 'Albania', 'Year': 1970, 'Life Expectancy': 65.2343},
#  {'Country': 'Albania', 'Year': 1971, 'Life Expectancy': 65.8959},
#  {'Country': 'Albania', 'Year': 1972, 'Life Expectancy': 66.5263},
#  {'Country': 'Albania', 'Year': 1973, 'Life Expectancy': 67.1066},
#  {'Country': 'Albania', 'Year': 1974, 'Life Expectancy': 67.6334},
#  {'Country': 'Albania', 'Year': 1975, 'Life Expectancy': 68.1198},
#  {'Country': 'Albania', 'Year': 1976, 'Life Expectancy': 68.5695},
#  {'Country': 'Albania', 'Year': 1977, 'Life Expectancy': 68.9918},
#  {'Country': 'Albania', 'Year': 1978, 'Life Expectancy': 69.3665},
#  {'Country': 'Albania', 'Year': 1979, 'Life Expectancy': 69.6169},
#  {'Country': 'Albania', 'Year': 1980, 'Life Expectancy': 69.903},
#  {'Country': 'Albania', 'Year': 1981, 'Life Expectancy': 70.1446},
#  {'Country': 'Albania', 'Year': 1982, 'Life Expectancy': 70.4249},
#  {'Country': 'Albania', 'Year': 1983, 'Life Expectancy': 70.7051},
#  {'Country': 'Albania', 'Year': 1984, 'Life Expectancy': 70.9838},
#  {'Country': 'Albania', 'Year': 1985, 'Life Expectancy': 71.2816},
#  {'Country': 'Albania', 'Year': 1986, 'Life Expectancy': 71.6651},
#  {'Country': 'Albania', 'Year': 1987, 'Life Expectancy': 71.9814},
#  {'Country': 'Albania', 'Year': 1988, 'Life Expectancy': 72.2167},
#  {'Country': 'Albania', 'Year': 1989, 'Life Expectancy': 72.4573},
#  {'Country': 'Albania', 'Year': 1990, 'Life Expectancy': 72.7096},
#  {'Country': 'Albania', 'Year': 1991, 'Life Expectancy': 73.0011},
#  {'Country': 'Albania', 'Year': 1992, 'Life Expectancy': 73.303},
#  {'Country': 'Albania', 'Year': 1993, 'Life Expectancy': 73.6377},
#  {'Country': 'Albania', 'Year': 1994, 'Life Expectancy': 73.8367},
#  {'Country': 'Albania', 'Year': 1995, 'Life Expectancy': 74.0218},
#  {'Country': 'Albania', 'Year': 1996, 'Life Expectancy': 74.1134},
#  {'Country': 'Albania', 'Year': 1997, 'Life Expectancy': 73.3832},
#  {'Country': 'Albania', 'Year': 1998, 'Life Expectancy': 74.3572},
#  {'Country': 'Albania', 'Year': 1999, 'Life Expectancy': 74.5684},
#  {'Country': 'Albania', 'Year': 2000, 'Life Expectancy': 74.8262},
#  {'Country': 'Albania', 'Year': 2001, 'Life Expectancy': 75.083},
#  {'Country': 'Albania', 'Year': 2002, 'Life Expectancy': 75.2987},
#  {'Country': 'Albania', 'Year': 2003, 'Life Expectancy': 75.5566},
#  {'Country': 'Albania', 'Year': 2004, 'Life Expectancy': 75.9515},
#  {'Country': 'Albania', 'Year': 2005, 'Life Expectancy': 76.4266},
#  {'Country': 'Albania', 'Year': 2006, 'Life Expectancy': 76.9943},
#  {'Country': 'Albania', 'Year': 2007, 'Life Expectancy': 77.6907},
#  {'Country': 'Albania', 'Year': 2008, 'Life Expectancy': 78.2484},
#  {'Country': 'Albania', 'Year': 2009, 'Life Expectancy': 78.5088},
#  {'Country': 'Albania', 'Year': 2010, 'Life Expectancy': 78.4141},
#  {'Country': 'Albania', 'Year': 2011, 'Life Expectancy': 78.3029},
#  {'Country': 'Albania', 'Year': 2012, 'Life Expectancy': 78.0836},
#  {'Country': 'Albania', 'Year': 2013, 'Life Expectancy': 77.9951},
#  {'Country': 'Albania', 'Year': 2014, 'Life Expectancy': 78.0291},
#  {'Country': 'Albania', 'Year': 2015, 'Life Expectancy': 78.358},
#  {'Country': 'Albania', 'Year': 2016, 'Life Expectancy': 78.6433},
#  {'Country': 'Albania', 'Year': 2017, 'Life Expectancy': 78.9003},
#  {'Country': 'Albania', 'Year': 2018, 'Life Expectancy': 79.2377},
#  {'Country': 'Albania', 'Year': 2019, 'Life Expectancy': 79.4669},
#  {'Country': 'Albania', 'Year': 2020, 'Life Expectancy': 77.8241},
#  {'Country': 'Albania', 'Year': 2021, 'Life Expectancy': 76.8442},
#  {'Country': 'Albania', 'Year': 2022, 'Life Expectancy': 78.7688},
#  {'Country': 'Albania', 'Year': 2023, 'Life Expectancy': 79.6019},
#  {'Country': 'Algeria', 'Year': 1923, 'Life Expectancy': 28.822},
#  {'Country': 'Algeria', 'Year': 1933, 'Life Expectancy': 31.22},
#  {'Country': 'Algeria', 'Year': 1943, 'Life Expectancy': 33.72},
#  {'Country': 'Algeria', 'Year': 1950, 'Life Expectancy': 42.6787},
#  {'Country': 'Algeria', 'Year': 1951, 'Life Expectancy': 43.3012},
#  {'Country': 'Algeria', 'Year': 1952, 'Life Expectancy': 43.4651},
#  {'Country': 'Algeria', 'Year': 1953, 'Life Expectancy': 43.6004},
#  {'Country': 'Algeria', 'Year': 1954, 'Life Expectancy': 40.6404},
#  {'Country': 'Algeria', 'Year': 1955, 'Life Expectancy': 40.8697},
#  {'Country': 'Algeria', 'Year': 1956, 'Life Expectancy': 40.9093},
#  {'Country': 'Algeria', 'Year': 1957, 'Life Expectancy': 40.9191},
#  {'Country': 'Algeria', 'Year': 1958, 'Life Expectancy': 40.9028},
#  {'Country': 'Algeria', 'Year': 1959, 'Life Expectancy': 40.8828},
#  {'Country': 'Algeria', 'Year': 1960, 'Life Expectancy': 40.8388},
#  {'Country': 'Algeria', 'Year': 1961, 'Life Expectancy': 40.7916},
#  {'Country': 'Algeria', 'Year': 1962, 'Life Expectancy': 39.5266},
#  {'Country': 'Algeria', 'Year': 1963, 'Life Expectancy': 43.1431},
#  {'Country': 'Algeria', 'Year': 1964, 'Life Expectancy': 42.9867},
#  {'Country': 'Algeria', 'Year': 1965, 'Life Expectancy': 42.8455},
#  {'Country': 'Algeria', 'Year': 1966, 'Life Expectancy': 42.7454},
#  {'Country': 'Algeria', 'Year': 1967, 'Life Expectancy': 42.7307},
#  {'Country': 'Algeria', 'Year': 1968, 'Life Expectancy': 42.806},
#  {'Country': 'Algeria', 'Year': 1969, 'Life Expectancy': 42.991},
#  {'Country': 'Algeria', 'Year': 1970, 'Life Expectancy': 43.328},
#  {'Country': 'Algeria', 'Year': 1971, 'Life Expectancy': 43.7823},
#  {'Country': 'Algeria', 'Year': 1972, 'Life Expectancy': 44.384},
#  {'Country': 'Algeria', 'Year': 1973, 'Life Expectancy': 45.1016},
#  {'Country': 'Algeria', 'Year': 1974, 'Life Expectancy': 45.9531},
#  {'Country': 'Algeria', 'Year': 1975, 'Life Expectancy': 46.9211},
#  {'Country': 'Algeria', 'Year': 1976, 'Life Expectancy': 48.0338},
#  {'Country': 'Algeria', 'Year': 1977, 'Life Expectancy': 49.2492},
#  {'Country': 'Algeria', 'Year': 1978, 'Life Expectancy': 50.6152},
#  {'Country': 'Algeria', 'Year': 1979, 'Life Expectancy': 52.409},
#  {'Country': 'Algeria', 'Year': 1980, 'Life Expectancy': 54.5124},
#  {'Country': 'Algeria', 'Year': 1981, 'Life Expectancy': 57.4223},
#  {'Country': 'Algeria', 'Year': 1982, 'Life Expectancy': 59.5944},
#  {'Country': 'Algeria', 'Year': 1983, 'Life Expectancy': 61.2511},
#  {'Country': 'Algeria', 'Year': 1984, 'Life Expectancy': 62.7219},
#  {'Country': 'Algeria', 'Year': 1985, 'Life Expectancy': 64.155},
#  {'Country': 'Algeria', 'Year': 1986, 'Life Expectancy': 65.2728},
#  {'Country': 'Algeria', 'Year': 1987, 'Life Expectancy': 66.13},
#  {'Country': 'Algeria', 'Year': 1988, 'Life Expectancy': 66.9097},
#  {'Country': 'Algeria', 'Year': 1989, 'Life Expectancy': 67.4609},
#  {'Country': 'Algeria', 'Year': 1990, 'Life Expectancy': 67.6584},
#  {'Country': 'Algeria', 'Year': 1991, 'Life Expectancy': 67.6919},
#  {'Country': 'Algeria', 'Year': 1992, 'Life Expectancy': 67.7245},
#  {'Country': 'Algeria', 'Year': 1993, 'Life Expectancy': 67.7974},
#  {'Country': 'Algeria', 'Year': 1994, 'Life Expectancy': 67.2844},
#  {'Country': 'Algeria', 'Year': 1995, 'Life Expectancy': 67.6914},
#  {'Country': 'Algeria', 'Year': 1996, 'Life Expectancy': 68.2186},
#  {'Country': 'Algeria', 'Year': 1997, 'Life Expectancy': 68.8594},
#  {'Country': 'Algeria', 'Year': 1998, 'Life Expectancy': 69.3271},
#  {'Country': 'Algeria', 'Year': 1999, 'Life Expectancy': 70.0881},
#  {'Country': 'Algeria', 'Year': 2000, 'Life Expectancy': 70.5759},
#  {'Country': 'Algeria', 'Year': 2001, 'Life Expectancy': 71.0245},
#  {'Country': 'Algeria', 'Year': 2002, 'Life Expectancy': 71.6437},
#  {'Country': 'Americas', 'Year': 1963, 'Life Expectancy': 61.5399},
#  {'Country': 'Americas', 'Year': 1964, 'Life Expectancy': 61.9124},
#  {'Country': 'Americas', 'Year': 1965, 'Life Expectancy': 62.1123},
#  {'Country': 'Americas', 'Year': 1966, 'Life Expectancy': 62.3322},
#  {'Country': 'Americas', 'Year': 1967, 'Life Expectancy': 62.67},
#  {'Country': 'Americas', 'Year': 1968, 'Life Expectancy': 62.7056},
#  {'Country': 'Americas', 'Year': 1969, 'Life Expectancy': 63.0295},
#  {'Country': 'Americas', 'Year': 1970, 'Life Expectancy': 63.1495},
#  {'Country': 'Americas', 'Year': 1971, 'Life Expectancy': 63.8157},
#  {'Country': 'Americas', 'Year': 1972, 'Life Expectancy': 64.0001},
#  {'Country': 'Americas', 'Year': 1973, 'Life Expectancy': 64.3473},
#  {'Country': 'Americas', 'Year': 1974, 'Life Expectancy': 64.8219},
#  {'Country': 'Americas', 'Year': 1975, 'Life Expectancy': 65.4098},
#  {'Country': 'Americas', 'Year': 1976, 'Life Expectancy': 65.7058},
#  {'Country': 'Americas', 'Year': 1977, 'Life Expectancy': 66.2896},
#  {'Country': 'Americas', 'Year': 1978, 'Life Expectancy': 66.6343},
#  {'Country': 'Americas', 'Year': 1979, 'Life Expectancy': 67.0668},
#  {'Country': 'Americas', 'Year': 1980, 'Life Expectancy': 67.247},
#  {'Country': 'Americas', 'Year': 1981, 'Life Expectancy': 67.6911},
#  {'Country': 'Americas', 'Year': 1982, 'Life Expectancy': 68.0177},
#  {'Country': 'Americas', 'Year': 1983, 'Life Expectancy': 68.4306},
#  {'Country': 'Americas', 'Year': 1984, 'Life Expectancy': 68.7457},
#  {'Country': 'Americas', 'Year': 1985, 'Life Expectancy': 68.8882},
#  {'Country': 'Americas', 'Year': 1986, 'Life Expectancy': 69.3281},
#  {'Country': 'Americas', 'Year': 1987, 'Life Expectancy': 69.6289},
#  {'Country': 'Americas', 'Year': 1988, 'Life Expectancy': 69.8726},
#  {'Country': 'Americas', 'Year': 1989, 'Life Expectancy': 70.2467},
#  {'Country': 'Americas', 'Year': 1990, 'Life Expectancy': 70.5909},
#  {'Country': 'Americas', 'Year': 1991, 'Life Expectancy': 70.8608},
#  {'Country': 'Americas', 'Year': 1992, 'Life Expectancy': 71.146},
#  {'Country': 'Americas', 'Year': 1993, 'Life Expectancy': 71.251},
#  {'Country': 'Americas', 'Year': 1994, 'Life Expectancy': 71.5582},
#  {'Country': 'Americas', 'Year': 1995, 'Life Expectancy': 71.8289},
#  {'Country': 'Americas', 'Year': 1996, 'Life Expectancy': 72.1831},
#  {'Country': 'Americas', 'Year': 1997, 'Life Expectancy': 72.5468},
#  {'Country': 'Americas', 'Year': 1998, 'Life Expectancy': 72.7124},
#  {'Country': 'Americas', 'Year': 1999, 'Life Expectancy': 72.981},
#  {'Country': 'Americas', 'Year': 2000, 'Life Expectancy': 73.247},
#  {'Country': 'Americas', 'Year': 2001, 'Life Expectancy': 73.4795},
#  {'Country': 'Angola', 'Year': 1970, 'Life Expectancy': 39.6882},
#  {'Country': 'Angola', 'Year': 1971, 'Life Expectancy': 40.0762},
#  {'Country': 'Angola', 'Year': 1972, 'Life Expectancy': 40.4686},
#  {'Country': 'Angola', 'Year': 1973, 'Life Expectancy': 40.8714},
#  {'Country': 'Angola', 'Year': 1974, 'Life Expectancy': 41.2597},
#  {'Country': 'Angola', 'Year': 1975, 'Life Expectancy': 40.8174},
#  {'Country': 'Angola', 'Year': 1976, 'Life Expectancy': 40.8116},
#  {'Country': 'Angola', 'Year': 1977, 'Life Expectancy': 41.2146},
#  {'Country': 'Angola', 'Year': 1978, 'Life Expectancy': 41.5731},
#  {'Country': 'Angola', 'Year': 1979, 'Life Expectancy': 41.9129},
#  {'Country': 'Angola', 'Year': 1980, 'Life Expectancy': 42.2415},
#  {'Country': 'Angola', 'Year': 1981, 'Life Expectancy': 42.5556},
#  {'Country': 'Angola', 'Year': 1982, 'Life Expectancy': 42.8569},
#  {'Country': 'Angola', 'Year': 1983, 'Life Expectancy': 41.9717},
#  {'Country': 'Angola', 'Year': 1984, 'Life Expectancy': 42.2455},
#  {'Country': 'Angola', 'Year': 1985, 'Life Expectancy': 42.495},
#  {'Country': 'Angola', 'Year': 1986, 'Life Expectancy': 42.7391},
#  {'Country': 'Angola', 'Year': 1987, 'Life Expectancy': 40.7857},
#  {'Country': 'Angola', 'Year': 1988, 'Life Expectancy': 41.4711},
#  {'Country': 'Angola', 'Year': 1989, 'Life Expectancy': 41.6977},
#  {'Country': 'Angola', 'Year': 1990, 'Life Expectancy': 41.8542},
#  {'Country': 'Angola', 'Year': 1991, 'Life Expectancy': 43.8116},
#  {'Country': 'Angola', 'Year': 1992, 'Life Expectancy': 42.2673},
#  {'Country': 'Angola', 'Year': 1993, 'Life Expectancy': 42.1902},
#  {'Country': 'Angola', 'Year': 1994, 'Life Expectancy': 43.5671},
#  {'Country': 'Angola', 'Year': 1995, 'Life Expectancy': 46.1391},
#  {'Country': 'Angola', 'Year': 1996, 'Life Expectancy': 46.4177},
#  {'Country': 'Angola', 'Year': 1997, 'Life Expectancy': 46.6882},
#  {'Country': 'Angola', 'Year': 1998, 'Life Expectancy': 45.4515},
#  {'Country': 'Angola', 'Year': 1999, 'Life Expectancy': 45.8077},
#  {'Country': 'Angola', 'Year': 2000, 'Life Expectancy': 46.5005},
#  {'Country': 'Angola', 'Year': 2001, 'Life Expectancy': 47.0323},
#  {'Country': 'Angola', 'Year': 2002, 'Life Expectancy': 47.8736},
#  {'Country': 'Angola', 'Year': 2003, 'Life Expectancy': 50.218},
#  {'Country': 'Angola', 'Year': 2004, 'Life Expectancy': 51.1225},
#  {'Country': 'Angola', 'Year': 2005, 'Life Expectancy': 52.1295},
#  {'Country': 'Angola', 'Year': 2006, 'Life Expectancy': 52.9647},
#  {'Country': 'Angola', 'Year': 2007, 'Life Expectancy': 54.2001},
#  {'Country': 'Angola', 'Year': 2008, 'Life Expectancy': 55.2809},
#  {'Country': 'Asia', 'Year': 1770, 'Life Expectancy': 27.5},
#  {'Country': 'Asia', 'Year': 1885, 'Life Expectancy': 27.5},
#  {'Country': 'Asia', 'Year': 1900, 'Life Expectancy': 28.0},
#  {'Country': 'Asia', 'Year': 1913, 'Life Expectancy': 28.1},
#  {'Country': 'Asia', 'Year': 1950, 'Life Expectancy': 41.9565},
#  {'Country': 'Asia', 'Year': 1951, 'Life Expectancy': 42.9587},
#  {'Country': 'Asia', 'Year': 1952, 'Life Expectancy': 44.2413},
#  {'Country': 'Asia', 'Year': 1953, 'Life Expectancy': 44.8721},
#  {'Country': 'Asia', 'Year': 1954, 'Life Expectancy': 45.8386},
#  {'Country': 'Asia', 'Year': 1955, 'Life Expectancy': 46.432},
#  {'Country': 'Asia', 'Year': 1956, 'Life Expectancy': 46.9368},
#  ...]

# %% [markdown]
# ### Importing Data into MongoDB

# %%
life_expentancy_db=life_expectancy_client['CO2_Renew_Life_DB']

# %%
life_expentancy_db.life_expentancy.insert_many(life_expentancy_data)
# Out:
# InsertManyResult([ObjectId('67f8bef5a4ad31e092022fc8'), ObjectId('67f8bef5a4ad31e092022fc9'), ObjectId('67f8bef5a4ad31e092022fca'), ObjectId('67f8bef5a4ad31e092022fcb'), ObjectId('67f8bef5a4ad31e092022fcc'), ObjectId('67f8bef5a4ad31e092022fcd'), ObjectId('67f8bef5a4ad31e092022fce'), ObjectId('67f8bef5a4ad31e092022fcf'), ObjectId('67f8bef5a4ad31e092022fd0'), ObjectId('67f8bef5a4ad31e092022fd1'), ObjectId('67f8bef5a4ad31e092022fd2'), ObjectId('67f8bef5a4ad31e092022fd3'), ObjectId('67f8bef5a4ad31e092022fd4'), ObjectId('67f8bef5a4ad31e092022fd5'), ObjectId('67f8bef5a4ad31e092022fd6'), ObjectId('67f8bef5a4ad31e092022fd7'), ObjectId('67f8bef5a4ad31e092022fd8'), ObjectId('67f8bef5a4ad31e092022fd9'), ObjectId('67f8bef5a4ad31e092022fda'), ObjectId('67f8bef5a4ad31e092022fdb'), ObjectId('67f8bef5a4ad31e092022fdc'), ObjectId('67f8bef5a4ad31e092022fdd'), ObjectId('67f8bef5a4ad31e092022fde'), ObjectId('67f8bef5a4ad31e092022fdf'), ObjectId('67f8bef5a4ad31e092022fe0'), ObjectId('67f8bef5a4ad31e092022fe1'), ObjectId('67f8bef5a4ad31e092022fe2'), ObjectId('67f8bef5a4ad31e092022fe3'), ObjectId('67f8bef5a4ad31e092022fe4'), ObjectId('67f8bef5a4ad31e092022fe5'), ObjectId('67f8bef5a4ad31e092022fe6'), ObjectId('67f8bef5a4ad31e092022fe7'), ObjectId('67f8bef5a4ad31e092022fe8'), ObjectId('67f8bef5a4ad31e092022fe9'), ObjectId('67f8bef5a4ad31e092022fea'), ObjectId('67f8bef5a4ad31e092022feb'), ObjectId('67f8bef5a4ad31e092022fec'), ObjectId('67f8bef5a4ad31e092022fed'), ObjectId('67f8bef5a4ad31e092022fee'), ObjectId('67f8bef5a4ad31e092022fef'), ObjectId('67f8bef5a